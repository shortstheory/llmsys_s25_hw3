# %%
# %%
import minitorch
from minitorch.cuda_kernel_ops import CudaKernelOps
backend = minitorch.TensorBackend(CudaKernelOps)
import time
import numpy as np

# %%
# %%
rows = 10
hidden_dim = 8

def rand(shape):
    return np.random.rand(*shape)

inp = rand((rows, hidden_dim))
out_grad = rand((rows,hidden_dim))
gamma = rand((hidden_dim,))
beta = rand((hidden_dim,))


def custom():
    inp_mt = minitorch.tensor_from_numpy(inp, backend=backend, requires_grad=True)
    gamma_mt = minitorch.tensor_from_numpy(gamma, backend=backend, requires_grad=True)
    beta_mt = minitorch.tensor_from_numpy(beta, backend=backend, requires_grad=True)
    out_grad_mt = minitorch.tensor_from_numpy(out_grad, backend=backend, requires_grad=True)

    out_mt = inp_mt.layernorm(gamma_mt, beta_mt)
    out_mt.backward(out_grad_mt)

    return inp_mt.grad, gamma_mt.grad, beta_mt.grad, inp_mt, gamma_mt, beta_mt

def baseline():
    f_input = minitorch.tensor_from_numpy(inp, backend=backend, requires_grad=True)
    f_gamma = minitorch.tensor_from_numpy(gamma, backend=backend, requires_grad=True)
    f_out_grad = minitorch.tensor_from_numpy(out_grad, backend=backend, requires_grad=True)

    f_means = f_input.mean(dim=1)
    f_vars = f_input.var(dim=1)
    f_stds = minitorch.tensor(np.sqrt(f_vars.to_numpy()).reshape(-1, 1).tolist(), backend=backend, requires_grad=True)

    xhat = (f_input - f_means) / f_stds
    print(xhat)
    dxhat = f_out_grad * f_gamma
    f_betta_grad = f_out_grad.sum(dim=0)
    f_gamma_grad = (f_out_grad * xhat).sum(dim=0)
    dinp = dxhat.sum(dim=1) + xhat * (dxhat * xhat).sum(dim=1)
    dinp = dxhat - dinp / hidden_dim
    dinp = dinp / f_stds
    return dinp, f_gamma_grad, f_betta_grad




#     return res


# %%


# %%
inp_grad_mt, gamma_mt, beta_mt, my_inp,g,b = custom()
dinp, f_gamma_grad, f_betta_grad = baseline()
# print(c-b)
# Out:
# threadIdx.x 0 threadIdx.y 5 grad 0.543178 xhat -0.217824
# threadIdx.x 1 threadIdx.y 5 grad 0.385468 xhat -1.434813
# threadIdx.x 2 threadIdx.y 5 grad 0.525705 xhat 1.047936
# threadIdx.x 3 threadIdx.y 5 grad 0.666638 xhat -0.050897
# threadIdx.x 4 threadIdx.y 5 grad 0.261627 xhat -1.056524
# threadIdx.x 5 threadIdx.y 5 grad 0.643332 xhat 1.060521
# threadIdx.x 6 threadIdx.y 5 grad 0.825854 xhat -1.744264
# threadIdx.x 7 threadIdx.y 5 grad 0.571875 xhat 0.903770
# threadIdx.x 8 threadIdx.y 5 grad 0.340838 xhat -1.139682
# threadIdx.x 9 threadIdx.y 5 grad 0.844239 xhat -0.885539
# threadIdx.x 10 threadIdx.y 5 grad 0.680327 xhat -0.949953
# threadIdx.x 11 threadIdx.y 5 grad 0.576928 xhat 0.490689
# threadIdx.x 12 threadIdx.y 5 grad 0.512862 xhat 0.841667
# threadIdx.x 13 threadIdx.y 5 grad 0.361639 xhat 0.997924
# threadIdx.x 14 threadIdx.y 5 grad 0.157931 xhat 0.956473
# threadIdx.x 15 threadIdx.y 5 grad 0.884688 xhat 1.711830
# threadIdx.x 16 threadIdx.y 5 grad 0.174743 xhat -1.261787
# threadIdx.x 17 threadIdx.y 5 grad 0.241763 xhat -1.333730
# threadIdx.x 18 threadIdx.y 5 grad 0.665941 xhat -0.563385
# threadIdx.x 19 threadIdx.y 5 grad 0.482536 xhat 1.731783
# threadIdx.x 20 threadIdx.y 5 grad 0.735098 xhat 0.505221
# threadIdx.x 21 threadIdx.y 5 grad 0.473063 xhat 0.318541
# threadIdx.x 22 threadIdx.y 5 grad 0.135756 xhat 1.538088
# threadIdx.x 23 threadIdx.y 5 grad 0.192067 xhat 1.652375
# threadIdx.x 24 threadIdx.y 5 grad 0.321091 xhat -1.632575
# threadIdx.x 25 threadIdx.y 5 grad 0.262225 xhat -0.346260
# threadIdx.x 26 threadIdx.y 5 grad 0.448502 xhat -0.204794
# threadIdx.x 27 threadIdx.y 5 grad 0.779978 xhat -0.675918
# threadIdx.x 28 threadIdx.y 5 grad 0.274066 xhat -1.222235
# threadIdx.x 29 threadIdx.y 5 grad 0.214506 xhat -0.561743
# threadIdx.x 30 threadIdx.y 5 grad 0.824081 xhat -0.079154
# threadIdx.x 31 threadIdx.y 5 grad 0.694326 xhat 0.567974
# threadIdx.x 0 threadIdx.y 8 grad 0.233866 xhat 0.418962
# threadIdx.x 1 threadIdx.y 8 grad 0.038421 xhat -0.261721
# threadIdx.x 2 threadIdx.y 8 grad 0.012031 xhat 1.370640
# threadIdx.x 3 threadIdx.y 8 grad 0.228310 xhat -0.643986
# threadIdx.x 4 threadIdx.y 8 grad 0.483008 xhat 1.355887
# threadIdx.x 5 threadIdx.y 8 grad 0.636694 xhat 1.472439
# threadIdx.x 6 threadIdx.y 8 grad 0.999370 xhat 0.837926
# threadIdx.x 7 threadIdx.y 8 grad 0.697700 xhat 1.469144
# threadIdx.x 8 threadIdx.y 8 grad 0.385709 xhat -1.007486
# threadIdx.x 9 threadIdx.y 8 grad 0.041923 xhat -1.164822
# threadIdx.x 10 threadIdx.y 8 grad 0.371087 xhat -1.478776
# threadIdx.x 11 threadIdx.y 8 grad 0.872662 xhat 0.300590
# threadIdx.x 12 threadIdx.y 8 grad 0.671553 xhat -1.643218
# threadIdx.x 13 threadIdx.y 8 grad 0.899463 xhat -0.698579
# threadIdx.x 14 threadIdx.y 8 grad 0.375232 xhat 1.650829
# threadIdx.x 15 threadIdx.y 8 grad 0.332741 xhat -1.023369
# threadIdx.x 16 threadIdx.y 8 grad 0.598053 xhat 0.018460
# threadIdx.x 17 threadIdx.y 8 grad 0.986131 xhat 0.679523
# threadIdx.x 18 threadIdx.y 8 grad 0.883021 xhat 0.427401
# threadIdx.x 19 threadIdx.y 8 grad 0.939011 xhat -1.424656
# threadIdx.x 20 threadIdx.y 8 grad 0.084491 xhat -0.732258
# threadIdx.x 21 threadIdx.y 8 grad 0.109836 xhat -1.256626
# threadIdx.x 22 threadIdx.y 8 grad 0.508304 xhat -1.055966
# threadIdx.x 23 threadIdx.y 8 grad 0.535928 xhat 1.689550
# threadIdx.x 24 threadIdx.y 8 grad 0.262405 xhat -0.541020
# threadIdx.x 25 threadIdx.y 8 grad 0.060518 xhat 1.208076
# threadIdx.x 26 threadIdx.y 8 grad 0.140697 xhat -0.446628
# threadIdx.x 27 threadIdx.y 8 grad 0.290030 xhat 1.072852
# threadIdx.x 28 threadIdx.y 8 grad 0.779131 xhat -1.164867
# threadIdx.x 29 threadIdx.y 8 grad 0.117857 xhat -1.410602
# threadIdx.x 30 threadIdx.y 8 grad 0.471126 xhat 1.035474
# threadIdx.x 31 threadIdx.y 8 grad 0.262876 xhat -0.403594
# threadIdx.x 0 threadIdx.y 9 grad 0.292081 xhat 0.631904
# threadIdx.x 1 threadIdx.y 9 grad 0.640647 xhat -1.228635
# threadIdx.x 2 threadIdx.y 9 grad 0.941647 xhat 0.807830
# threadIdx.x 3 threadIdx.y 9 grad 0.815619 xhat -0.400048
# threadIdx.x 4 threadIdx.y 9 grad 0.707965 xhat -1.230143
# threadIdx.x 5 threadIdx.y 9 grad 0.371583 xhat 0.275657
# threadIdx.x 6 threadIdx.y 9 grad 0.235479 xhat 0.234998
# threadIdx.x 7 threadIdx.y 9 grad 0.193931 xhat 0.766421
# threadIdx.x 8 threadIdx.y 9 grad 0.440197 xhat -1.252996
# threadIdx.x 9 threadIdx.y 9 grad 0.686208 xhat 1.450886
# threadIdx.x 10 threadIdx.y 9 grad 0.404629 xhat 1.105204
# threadIdx.x 11 threadIdx.y 9 grad 0.407641 xhat -0.791966
# threadIdx.x 12 threadIdx.y 9 grad 0.823563 xhat -0.330774
# threadIdx.x 13 threadIdx.y 9 grad 0.179908 xhat 1.595118
# threadIdx.x 14 threadIdx.y 9 grad 0.844409 xhat -1.572198
# threadIdx.x 15 threadIdx.y 9 grad 0.476730 xhat 1.330794
# threadIdx.x 16 threadIdx.y 9 grad 0.183578 xhat -0.666097
# threadIdx.x 17 threadIdx.y 9 grad 0.403670 xhat 0.773760
# threadIdx.x 18 threadIdx.y 9 grad 0.512345 xhat -1.199747
# threadIdx.x 19 threadIdx.y 9 grad 0.588210 xhat 0.677454
# threadIdx.x 20 threadIdx.y 9 grad 0.764963 xhat -1.628866
# threadIdx.x 21 threadIdx.y 9 grad 0.054489 xhat -0.165618
# threadIdx.x 22 threadIdx.y 9 grad 0.481838 xhat 0.652566
# threadIdx.x 23 threadIdx.y 9 grad 0.500585 xhat -1.339716
# threadIdx.x 24 threadIdx.y 9 grad 0.041550 xhat 1.077160
# threadIdx.x 25 threadIdx.y 9 grad 0.266853 xhat 0.916936
# threadIdx.x 26 threadIdx.y 9 grad 0.939154 xhat -1.192003
# threadIdx.x 27 threadIdx.y 9 grad 0.922057 xhat 0.279362
# threadIdx.x 28 threadIdx.y 9 grad 0.181662 xhat -1.156340
# threadIdx.x 29 threadIdx.y 9 grad 0.525774 xhat -1.025737
# threadIdx.x 30 threadIdx.y 9 grad 0.889931 xhat 1.116079
# threadIdx.x 31 threadIdx.y 9 grad 0.210315 xhat 1.628134
# threadIdx.x 0 threadIdx.y 7 grad 0.683089 xhat 0.414966
# threadIdx.x 1 threadIdx.y 7 grad 0.062505 xhat -0.329987
# threadIdx.x 2 threadIdx.y 7 grad 0.857892 xhat -0.112820
# threadIdx.x 3 threadIdx.y 7 grad 0.711482 xhat 0.485781
# threadIdx.x 4 threadIdx.y 7 grad 0.644511 xhat 1.593749
# threadIdx.x 5 threadIdx.y 7 grad 0.384610 xhat 1.038432
# threadIdx.x 6 threadIdx.y 7 grad 0.731755 xhat 0.978729
# threadIdx.x 7 threadIdx.y 7 grad 0.130442 xhat -1.308867
# threadIdx.x 8 threadIdx.y 7 grad 0.724838 xhat -0.515044
# threadIdx.x 9 threadIdx.y 7 grad 0.498776 xhat -0.950331
# threadIdx.x 10 threadIdx.y 7 grad 0.777648 xhat -0.682070
# threadIdx.x 11 threadIdx.y 7 grad 0.767526 xhat -1.745824
# threadIdx.x 12 threadIdx.y 7 grad 0.832681 xhat 0.319866
# threadIdx.x 13 threadIdx.y 7 grad 0.689449 xhat 0.106972
# threadIdx.x 14 threadIdx.y 7 grad 0.808110 xhat -1.646670
# threadIdx.x 15 threadIdx.y 7 grad 0.434674 xhat 0.302177
# threadIdx.x 16 threadIdx.y 7 grad 0.240313 xhat -0.509066
# threadIdx.x 17 threadIdx.y 7 grad 0.067201 xhat 0.172688
# threadIdx.x 18 threadIdx.y 7 grad 0.668755 xhat 0.365886
# threadIdx.x 19 threadIdx.y 7 grad 0.047407 xhat 0.109746
# threadIdx.x 20 threadIdx.y 7 grad 0.695773 xhat -0.161640
# threadIdx.x 21 threadIdx.y 7 grad 0.968423 xhat -1.736823
# threadIdx.x 22 threadIdx.y 7 grad 0.766527 xhat -0.594773
# threadIdx.x 23 threadIdx.y 7 grad 0.520231 xhat 1.335873
# threadIdx.x 24 threadIdx.y 7 grad 0.117037 xhat 0.690294
# threadIdx.x 25 threadIdx.y 7 grad 0.229951 xhat 0.655818
# threadIdx.x 26 threadIdx.y 7 grad 0.050423 xhat 0.907918
# threadIdx.x 27 threadIdx.y 7 grad 0.085450 xhat 1.211688
# threadIdx.x 28 threadIdx.y 7 grad 0.228423 xhat -1.093498
# threadIdx.x 29 threadIdx.y 7 grad 0.540045 xhat 0.709987
# threadIdx.x 30 threadIdx.y 7 grad 0.649833 xhat -0.973228
# threadIdx.x 31 threadIdx.y 7 grad 0.491792 xhat 1.454853
# threadIdx.x 0 threadIdx.y 6 grad 0.257829 xhat -0.166394
# threadIdx.x 1 threadIdx.y 6 grad 0.694567 xhat 0.965735
# threadIdx.x 2 threadIdx.y 6 grad 0.431480 xhat -0.367632
# threadIdx.x 3 threadIdx.y 6 grad 0.004482 xhat -0.400191
# threadIdx.x 4 threadIdx.y 6 grad 0.109551 xhat -1.521032
# threadIdx.x 5 threadIdx.y 6 grad 0.940354 xhat -0.700503
# threadIdx.x 6 threadIdx.y 6 grad 0.188322 xhat -1.606916
# threadIdx.x 7 threadIdx.y 6 grad 0.163411 xhat 1.702726
# threadIdx.x 8 threadIdx.y 6 grad 0.479951 xhat 0.737549
# threadIdx.x 9 threadIdx.y 6 grad 0.554269 xhat 1.200663
# threadIdx.x 10 threadIdx.y 6 grad 0.278256 xhat -1.232184
# threadIdx.x 11 threadIdx.y 6 grad 0.338245 xhat -0.276216
# threadIdx.x 12 threadIdx.y 6 grad 0.886882 xhat 0.653192
# threadIdx.x 13 threadIdx.y 6 grad 0.303392 xhat -1.571905
# threadIdx.x 14 threadIdx.y 6 grad 0.980039 xhat -0.026855
# threadIdx.x 15 threadIdx.y 6 grad 0.336705 xhat -0.607074
# threadIdx.x 16 threadIdx.y 6 grad 0.729450 xhat -0.072959
# threadIdx.x 17 threadIdx.y 6 grad 0.162227 xhat -1.325279
# threadIdx.x 18 threadIdx.y 6 grad 0.798111 xhat 1.419453
# threadIdx.x 19 threadIdx.y 6 grad 0.539505 xhat -0.147865
# threadIdx.x 20 threadIdx.y 6 grad 0.846642 xhat -0.263945
# threadIdx.x 21 threadIdx.y 6 grad 0.313168 xhat -1.479518
# threadIdx.x 22 threadIdx.y 6 grad 0.700093 xhat 0.968046
# threadIdx.x 23 threadIdx.y 6 grad 0.613231 xhat 1.792704
# threadIdx.x 24 threadIdx.y 6 grad 0.704598 xhat -0.203810
# threadIdx.x 25 threadIdx.y 6 grad 0.875699 xhat 0.908214
# threadIdx.x 26 threadIdx.y 6 grad 0.611194 xhat -0.086219
# threadIdx.x 27 threadIdx.y 6 grad 0.878614 xhat -1.193709
# threadIdx.x 28 threadIdx.y 6 grad 0.678803 xhat 1.033086
# threadIdx.x 29 threadIdx.y 6 grad 0.495474 xhat 1.295308
# threadIdx.x 30 threadIdx.y 6 grad 0.309242 xhat 0.710832
# threadIdx.x 31 threadIdx.y 6 grad 0.737935 xhat 0.709939
# threadIdx.x 0 threadIdx.y 9 grad 0.802256 xhat 0.703191
# threadIdx.x 1 threadIdx.y 9 grad 0.251085 xhat 1.520266
# threadIdx.x 2 threadIdx.y 9 grad 0.084331 xhat 0.158825
# threadIdx.x 3 threadIdx.y 9 grad 0.608961 xhat -0.596738
# threadIdx.x 4 threadIdx.y 9 grad 0.441123 xhat -0.108589
# threadIdx.x 5 threadIdx.y 9 grad 0.695036 xhat -0.119871
# threadIdx.x 6 threadIdx.y 9 grad 0.188210 xhat 0.460592
# threadIdx.x 7 threadIdx.y 9 grad 0.777972 xhat -1.264759
# threadIdx.x 8 threadIdx.y 9 grad 0.642561 xhat 0.516856
# threadIdx.x 9 threadIdx.y 9 grad 0.937021 xhat -0.788877
# threadIdx.x 10 threadIdx.y 9 grad 0.223793 xhat 1.641686
# threadIdx.x 11 threadIdx.y 9 grad 0.154514 xhat 1.648899
# threadIdx.x 12 threadIdx.y 9 grad 0.788149 xhat 0.784114
# threadIdx.x 13 threadIdx.y 9 grad 0.736552 xhat -0.951623
# threadIdx.x 14 threadIdx.y 9 grad 0.938744 xhat -0.463852
# threadIdx.x 15 threadIdx.y 9 grad 0.168350 xhat -0.748566
# threadIdx.x 16 threadIdx.y 9 grad 0.212018 xhat -0.438805
# threadIdx.x 17 threadIdx.y 9 grad 0.915411 xhat 1.438053
# threadIdx.x 18 threadIdx.y 9 grad 0.554643 xhat 0.013011
# threadIdx.x 19 threadIdx.y 9 grad 0.812042 xhat 1.370844
# threadIdx.x 20 threadIdx.y 9 grad 0.529017 xhat -1.199425
# threadIdx.x 21 threadIdx.y 9 grad 0.558838 xhat 0.091023
# threadIdx.x 22 threadIdx.y 9 grad 0.802427 xhat -1.533699
# threadIdx.x 23 threadIdx.y 9 grad 0.932264 xhat 0.622501
# threadIdx.x 24 threadIdx.y 9 grad 0.815640 xhat 0.363895
# threadIdx.x 25 threadIdx.y 9 grad 0.610287 xhat 1.659390
# threadIdx.x 26 threadIdx.y 9 grad 0.671484 xhat 1.329257
# threadIdx.x 27 threadIdx.y 9 grad 0.093434 xhat 0.248383
# threadIdx.x 28 threadIdx.y 9 grad 0.455921 xhat -1.574778
# threadIdx.x 29 threadIdx.y 9 grad 0.110288 xhat -0.399592
# threadIdx.x 30 threadIdx.y 9 grad 0.343115 xhat -1.057123
# threadIdx.x 31 threadIdx.y 9 grad 0.066402 xhat -1.572864
# threadIdx.x 0 threadIdx.y 1 grad 0.345160 xhat -1.289965
# threadIdx.x 1 threadIdx.y 1 grad 0.939528 xhat -1.660138
# threadIdx.x 2 threadIdx.y 1 grad 0.152802 xhat 1.578793
# threadIdx.x 3 threadIdx.y 1 grad 0.676133 xhat -0.023017
# threadIdx.x 4 threadIdx.y 1 grad 0.286590 xhat 0.902465
# threadIdx.x 5 threadIdx.y 1 grad 0.480339 xhat -0.537684
# threadIdx.x 6 threadIdx.y 1 grad 0.608602 xhat -0.178752
# threadIdx.x 7 threadIdx.y 1 grad 0.278480 xhat 0.372295
# threadIdx.x 8 threadIdx.y 1 grad 0.844984 xhat -0.929685
# threadIdx.x 9 threadIdx.y 1 grad 0.001379 xhat 1.423025
# threadIdx.x 10 threadIdx.y 1 grad 0.048655 xhat 0.471041
# threadIdx.x 11 threadIdx.y 1 grad 0.219346 xhat 0.882131
# threadIdx.x 12 threadIdx.y 1 grad 0.339529 xhat -0.401626
# threadIdx.x 13 threadIdx.y 1 grad 0.942777 xhat 1.163317
# threadIdx.x 14 threadIdx.y 1 grad 0.489561 xhat 0.733645
# threadIdx.x 15 threadIdx.y 1 grad 0.567717 xhat 0.222770
# threadIdx.x 16 threadIdx.y 1 grad 0.656519 xhat 1.604549
# threadIdx.x 17 threadIdx.y 1 grad 0.166397 xhat 0.230269
# threadIdx.x 18 threadIdx.y 1 grad 0.123544 xhat -0.220340
# threadIdx.x 19 threadIdx.y 1 grad 0.355179 xhat 1.603797
# threadIdx.x 20 threadIdx.y 1 grad 0.937002 xhat 0.663393
# threadIdx.x 21 threadIdx.y 1 grad 0.650519 xhat 1.283824
# threadIdx.x 22 threadIdx.y 1 grad 0.823106 xhat -1.397403
# threadIdx.x 23 threadIdx.y 1 grad 0.962443 xhat -1.542004
# threadIdx.x 24 threadIdx.y 1 grad 0.270654 xhat 1.410768
# threadIdx.x 25 threadIdx.y 1 grad 0.645331 xhat 0.490325
# threadIdx.x 26 threadIdx.y 1 grad 0.837248 xhat -1.630497
# threadIdx.x 27 threadIdx.y 1 grad 0.163349 xhat -1.602227
# threadIdx.x 28 threadIdx.y 1 grad 0.238278 xhat -0.113368
# threadIdx.x 29 threadIdx.y 1 grad 0.618729 xhat -1.296179
# threadIdx.x 30 threadIdx.y 1 grad 0.413780 xhat 1.578792
# threadIdx.x 31 threadIdx.y 1 grad 0.276853 xhat 1.293369
# threadIdx.x 0 threadIdx.y 8 grad 0.748408 xhat -0.377009
# threadIdx.x 1 threadIdx.y 8 grad 0.445434 xhat -0.358242
# threadIdx.x 2 threadIdx.y 8 grad 0.536809 xhat 0.626210
# threadIdx.x 3 threadIdx.y 8 grad 0.676206 xhat 0.228990
# threadIdx.x 4 threadIdx.y 8 grad 0.453223 xhat -0.482640
# threadIdx.x 5 threadIdx.y 8 grad 0.203375 xhat 0.257229
# threadIdx.x 6 threadIdx.y 8 grad 0.308379 xhat -0.288025
# threadIdx.x 7 threadIdx.y 8 grad 0.762072 xhat 1.468184
# threadIdx.x 8 threadIdx.y 8 grad 0.852308 xhat -1.352150
# threadIdx.x 9 threadIdx.y 8 grad 0.269436 xhat -0.672817
# threadIdx.x 10 threadIdx.y 8 grad 0.114422 xhat -0.355657
# threadIdx.x 11 threadIdx.y 8 grad 0.016887 xhat 0.646764
# threadIdx.x 12 threadIdx.y 8 grad 0.229871 xhat -0.317224
# threadIdx.x 13 threadIdx.y 8 grad 0.871542 xhat -0.158786
# threadIdx.x 14 threadIdx.y 8 grad 0.304639 xhat -0.868025
# threadIdx.x 15 threadIdx.y 8 grad 0.309022 xhat 1.282958
# threadIdx.x 16 threadIdx.y 8 grad 0.734378 xhat 0.090847
# threadIdx.x 17 threadIdx.y 8 grad 0.525828 xhat 1.346087
# threadIdx.x 18 threadIdx.y 8 grad 0.463799 xhat 1.681503
# threadIdx.x 19 threadIdx.y 8 grad 0.071105 xhat -0.899699
# threadIdx.x 20 threadIdx.y 8 grad 0.837710 xhat -1.173720
# threadIdx.x 21 threadIdx.y 8 grad 0.759859 xhat -0.180380
# threadIdx.x 22 threadIdx.y 8 grad 0.856435 xhat 1.007963
# threadIdx.x 23 threadIdx.y 8 grad 0.571152 xhat 1.275985
# threadIdx.x 24 threadIdx.y 8 grad 0.650653 xhat 1.412803
# threadIdx.x 25 threadIdx.y 8 grad 0.067123 xhat -1.519138
# threadIdx.x 26 threadIdx.y 8 grad 0.509760 xhat 0.068298
# threadIdx.x 27 threadIdx.y 8 grad 0.905635 xhat 0.383177
# threadIdx.x 28 threadIdx.y 8 grad 0.202445 xhat -0.515962
# threadIdx.x 29 threadIdx.y 8 grad 0.606259 xhat -1.657826
# threadIdx.x 30 threadIdx.y 8 grad 0.206544 xhat -1.397762
# threadIdx.x 31 threadIdx.y 8 grad 0.893666 xhat 0.611061
# threadIdx.x 0 threadIdx.y 9 grad 0.942647 xhat -0.188618
# threadIdx.x 1 threadIdx.y 9 grad 0.893963 xhat -1.429525
# threadIdx.x 2 threadIdx.y 9 grad 0.256613 xhat 1.240335
# threadIdx.x 3 threadIdx.y 9 grad 0.030360 xhat 1.086297
# threadIdx.x 4 threadIdx.y 9 grad 0.464842 xhat 1.122507
# threadIdx.x 5 threadIdx.y 9 grad 0.505204 xhat -0.054951
# threadIdx.x 6 threadIdx.y 9 grad 0.303380 xhat 0.716122
# threadIdx.x 7 threadIdx.y 9 grad 0.188088 xhat 0.283333
# threadIdx.x 8 threadIdx.y 9 grad 0.479215 xhat 1.527059
# threadIdx.x 9 threadIdx.y 9 grad 0.103477 xhat -1.494433
# threadIdx.x 10 threadIdx.y 9 grad 0.247947 xhat 1.026518
# threadIdx.x 11 threadIdx.y 9 grad 0.231125 xhat 0.800286
# threadIdx.x 12 threadIdx.y 9 grad 0.050443 xhat -0.464972
# threadIdx.x 13 threadIdx.y 9 grad 0.960822 xhat -1.240656
# threadIdx.x 14 threadIdx.y 9 grad 0.455654 xhat -0.410788
# threadIdx.x 15 threadIdx.y 9 grad 0.664272 xhat 0.985947
# threadIdx.x 16 threadIdx.y 9 grad 0.540620 xhat -0.162435
# threadIdx.x 17 threadIdx.y 9 grad 0.112209 xhat 1.488423
# threadIdx.x 18 threadIdx.y 9 grad 0.046907 xhat -1.081416
# threadIdx.x 19 threadIdx.y 9 grad 0.728028 xhat 0.681591
# threadIdx.x 20 threadIdx.y 9 grad 0.799062 xhat 1.430696
# threadIdx.x 21 threadIdx.y 9 grad 0.509928 xhat -1.274897
# threadIdx.x 22 threadIdx.y 9 grad 0.120992 xhat -1.436147
# threadIdx.x 23 threadIdx.y 9 grad 0.671492 xhat 0.520823
# threadIdx.x 24 threadIdx.y 9 grad 0.325138 xhat -1.611816
# threadIdx.x 25 threadIdx.y 9 grad 0.916855 xhat 0.626019
# threadIdx.x 26 threadIdx.y 9 grad 0.828340 xhat 0.358930
# threadIdx.x 27 threadIdx.y 9 grad 0.626147 xhat 1.654410
# threadIdx.x 28 threadIdx.y 9 grad 0.582521 xhat -1.520834
# threadIdx.x 29 threadIdx.y 9 grad 0.641367 xhat -1.308381
# threadIdx.x 30 threadIdx.y 9 grad 0.455386 xhat -1.313405
# threadIdx.x 31 threadIdx.y 9 grad 0.442834 xhat 1.250472
# threadIdx.x 0 threadIdx.y 1 grad 0.227992 xhat 0.042691
# threadIdx.x 1 threadIdx.y 1 grad 0.993203 xhat -0.587901
# threadIdx.x 2 threadIdx.y 1 grad 0.282996 xhat -1.246568
# threadIdx.x 3 threadIdx.y 1 grad 0.861079 xhat -1.417067
# threadIdx.x 4 threadIdx.y 1 grad 0.432498 xhat 0.280006
# threadIdx.x 5 threadIdx.y 1 grad 0.123340 xhat 0.624961
# threadIdx.x 6 threadIdx.y 1 grad 0.850601 xhat 1.116477
# threadIdx.x 7 threadIdx.y 1 grad 0.145480 xhat 0.615734
# threadIdx.x 8 threadIdx.y 1 grad 0.615909 xhat -0.447760
# threadIdx.x 9 threadIdx.y 1 grad 0.679345 xhat 0.524774
# threadIdx.x 10 threadIdx.y 1 grad 0.321299 xhat 0.710388
# threadIdx.x 11 threadIdx.y 1 grad 0.979599 xhat -0.949236
# threadIdx.x 12 threadIdx.y 1 grad 0.254805 xhat 1.121791
# threadIdx.x 13 threadIdx.y 1 grad 0.449016 xhat 1.471850
# threadIdx.x 14 threadIdx.y 1 grad 0.147644 xhat -0.901569
# threadIdx.x 15 threadIdx.y 1 grad 0.523103 xhat -0.335892
# threadIdx.x 16 threadIdx.y 1 grad 0.892200 xhat -0.009167
# threadIdx.x 17 threadIdx.y 1 grad 0.899171 xhat 0.900431
# threadIdx.x 18 threadIdx.y 1 grad 0.194752 xhat -1.137052
# threadIdx.x 19 threadIdx.y 1 grad 0.907165 xhat -0.837627
# threadIdx.x 20 threadIdx.y 1 grad 0.898763 xhat 0.248027
# threadIdx.x 21 threadIdx.y 1 grad 0.864910 xhat -0.269879
# threadIdx.x 22 threadIdx.y 1 grad 0.798224 xhat -0.387764
# threadIdx.x 23 threadIdx.y 1 grad 0.216989 xhat 0.144146
# threadIdx.x 24 threadIdx.y 1 grad 0.469281 xhat 0.058721
# threadIdx.x 25 threadIdx.y 1 grad 0.309592 xhat 1.351570
# threadIdx.x 26 threadIdx.y 1 grad 0.751854 xhat 1.048665
# threadIdx.x 27 threadIdx.y 1 grad 0.190887 xhat 0.960892
# threadIdx.x 28 threadIdx.y 1 grad 0.271168 xhat -1.246902
# threadIdx.x 29 threadIdx.y 1 grad 0.792771 xhat -0.821844
# threadIdx.x 30 threadIdx.y 1 grad 0.739277 xhat 1.071929
# threadIdx.x 31 threadIdx.y 1 grad 0.582524 xhat 0.543989
# threadIdx.x 0 threadIdx.y 3 grad 0.288709 xhat 0.647290
# threadIdx.x 1 threadIdx.y 3 grad 0.450635 xhat 0.545982
# threadIdx.x 2 threadIdx.y 3 grad 0.316329 xhat 1.020984
# threadIdx.x 3 threadIdx.y 3 grad 0.435909 xhat 1.599309
# threadIdx.x 4 threadIdx.y 3 grad 0.819701 xhat 0.849339
# threadIdx.x 5 threadIdx.y 3 grad 0.390919 xhat 0.662128
# threadIdx.x 6 threadIdx.y 3 grad 0.855890 xhat -0.279176
# threadIdx.x 7 threadIdx.y 3 grad 0.416291 xhat -0.674158
# threadIdx.x 8 threadIdx.y 3 grad 0.437359 xhat -1.497347
# threadIdx.x 9 threadIdx.y 3 grad 0.434937 xhat 1.380008
# threadIdx.x 10 threadIdx.y 3 grad 0.593923 xhat 0.215260
# threadIdx.x 11 threadIdx.y 3 grad 0.523158 xhat -0.675896
# threadIdx.x 12 threadIdx.y 3 grad 0.268849 xhat -1.647677
# threadIdx.x 13 threadIdx.y 3 grad 0.680147 xhat 0.094951
# threadIdx.x 14 threadIdx.y 3 grad 0.903140 xhat 0.195304
# threadIdx.x 15 threadIdx.y 3 grad 0.855836 xhat 1.283466
# threadIdx.x 16 threadIdx.y 3 grad 0.164661 xhat 1.489780
# threadIdx.x 17 threadIdx.y 3 grad 0.902376 xhat -0.894231
# threadIdx.x 18 threadIdx.y 3 grad 0.186548 xhat 1.682482
# threadIdx.x 19 threadIdx.y 3 grad 0.602613 xhat -1.288795
# threadIdx.x 20 threadIdx.y 3 grad 0.107727 xhat 1.328398
# threadIdx.x 21 threadIdx.y 3 grad 0.914229 xhat -0.590091
# threadIdx.x 22 threadIdx.y 3 grad 0.728570 xhat 1.323336
# threadIdx.x 23 threadIdx.y 3 grad 0.715155 xhat -0.678765
# threadIdx.x 24 threadIdx.y 3 grad 0.644204 xhat -1.435700
# threadIdx.x 25 threadIdx.y 3 grad 0.827909 xhat 0.612556
# threadIdx.x 26 threadIdx.y 3 grad 0.814747 xhat -1.275315
# threadIdx.x 27 threadIdx.y 3 grad 0.567333 xhat 1.071697
# threadIdx.x 28 threadIdx.y 3 grad 0.462028 xhat -0.608879
# threadIdx.x 29 threadIdx.y 3 grad 0.854160 xhat -0.338866
# threadIdx.x 30 threadIdx.y 3 grad 0.181857 xhat 1.099924
# threadIdx.x 31 threadIdx.y 3 grad 0.741491 xhat 1.427416
# threadIdx.x 0 threadIdx.y 7 grad 0.522478 xhat 1.111079
# threadIdx.x 1 threadIdx.y 7 grad 0.080568 xhat 1.450429
# threadIdx.x 2 threadIdx.y 7 grad 0.479881 xhat -0.242188
# threadIdx.x 3 threadIdx.y 7 grad 0.125437 xhat -0.631742
# threadIdx.x 4 threadIdx.y 7 grad 0.232068 xhat 0.533524
# threadIdx.x 5 threadIdx.y 7 grad 0.105487 xhat 0.284690
# threadIdx.x 6 threadIdx.y 7 grad 0.070452 xhat 1.042596
# threadIdx.x 7 threadIdx.y 7 grad 0.826271 xhat -0.648613
# threadIdx.x 8 threadIdx.y 7 grad 0.657221 xhat -1.455379
# threadIdx.x 9 threadIdx.y 7 grad 0.981293 xhat -1.602235
# threadIdx.x 10 threadIdx.y 7 grad 0.784708 xhat 0.706786
# threadIdx.x 11 threadIdx.y 7 grad 0.085587 xhat -1.391651
# threadIdx.x 12 threadIdx.y 7 grad 0.684030 xhat -0.050072
# threadIdx.x 13 threadIdx.y 7 grad 0.173341 xhat 0.099230
# threadIdx.x 14 threadIdx.y 7 grad 0.728753 xhat -1.515466
# threadIdx.x 15 threadIdx.y 7 grad 0.070028 xhat 0.107695
# threadIdx.x 16 threadIdx.y 7 grad 0.787599 xhat -0.996186
# threadIdx.x 17 threadIdx.y 7 grad 0.478231 xhat -0.404463
# threadIdx.x 18 threadIdx.y 7 grad 0.029888 xhat 0.682580
# threadIdx.x 19 threadIdx.y 7 grad 0.423065 xhat 1.150733
# threadIdx.x 20 threadIdx.y 7 grad 0.882468 xhat -0.699418
# threadIdx.x 21 threadIdx.y 7 grad 0.705993 xhat -0.189896
# threadIdx.x 22 threadIdx.y 7 grad 0.332767 xhat -0.328637
# threadIdx.x 23 threadIdx.y 7 grad 0.976999 xhat 0.059659
# threadIdx.x 24 threadIdx.y 7 grad 0.496696 xhat -1.287702
# threadIdx.x 25 threadIdx.y 7 grad 0.656156 xhat 1.246307
# threadIdx.x 26 threadIdx.y 7 grad 0.619415 xhat 0.878141
# threadIdx.x 27 threadIdx.y 7 grad 0.537631 xhat 0.099371
# threadIdx.x 28 threadIdx.y 7 grad 0.970954 xhat 1.139490
# threadIdx.x 29 threadIdx.y 7 grad 0.655592 xhat 0.338984
# threadIdx.x 30 threadIdx.y 7 grad 0.915819 xhat 0.109528
# threadIdx.x 31 threadIdx.y 7 grad 0.201575 xhat 0.255285
# threadIdx.x 0 threadIdx.y 1 grad 0.158021 xhat 1.236616
# threadIdx.x 1 threadIdx.y 1 grad 0.064723 xhat 1.185902
# threadIdx.x 2 threadIdx.y 1 grad 0.054577 xhat -0.799752
# threadIdx.x 3 threadIdx.y 1 grad 0.501779 xhat 1.407610
# threadIdx.x 4 threadIdx.y 1 grad 0.636355 xhat -1.309921
# threadIdx.x 5 threadIdx.y 1 grad 0.671903 xhat 0.447439
# threadIdx.x 6 threadIdx.y 1 grad 0.492795 xhat -1.476816
# threadIdx.x 7 threadIdx.y 1 grad 0.998361 xhat 0.189577
# threadIdx.x 8 threadIdx.y 1 grad 0.944408 xhat -0.221701
# threadIdx.x 9 threadIdx.y 1 grad 0.346309 xhat -0.628291
# threadIdx.x 10 threadIdx.y 1 grad 0.538263 xhat -0.578209
# threadIdx.x 11 threadIdx.y 1 grad 0.145074 xhat 0.032276
# threadIdx.x 12 threadIdx.y 1 grad 0.606991 xhat 0.332016
# threadIdx.x 13 threadIdx.y 1 grad 0.280002 xhat 0.788049
# threadIdx.x 14 threadIdx.y 1 grad 0.156060 xhat -1.049669
# threadIdx.x 15 threadIdx.y 1 grad 0.152537 xhat 1.681474
# threadIdx.x 16 threadIdx.y 1 grad 0.924599 xhat -1.401471
# threadIdx.x 17 threadIdx.y 1 grad 0.616162 xhat 0.023724
# threadIdx.x 18 threadIdx.y 1 grad 0.213814 xhat 0.249877
# threadIdx.x 19 threadIdx.y 1 grad 0.020518 xhat -0.511563
# threadIdx.x 20 threadIdx.y 1 grad 0.963205 xhat -1.163502
# threadIdx.x 21 threadIdx.y 1 grad 0.780627 xhat -0.338778
# threadIdx.x 22 threadIdx.y 1 grad 0.678043 xhat 1.201802
# threadIdx.x 23 threadIdx.y 1 grad 0.148312 xhat -0.029555
# threadIdx.x 24 threadIdx.y 1 grad 0.665253 xhat -1.741134
# threadIdx.x 25 threadIdx.y 1 grad 0.903284 xhat 0.728282
# threadIdx.x 26 threadIdx.y 1 grad 0.944840 xhat 1.165478
# threadIdx.x 27 threadIdx.y 1 grad 0.486237 xhat -1.340532
# threadIdx.x 28 threadIdx.y 1 grad 0.669762 xhat -0.987202
# threadIdx.x 29 threadIdx.y 1 grad 0.318050 xhat -0.868343
# threadIdx.x 30 threadIdx.y 1 grad 0.290860 xhat 0.193310
# threadIdx.x 31 threadIdx.y 1 grad 0.183749 xhat -0.296681
# threadIdx.x 0 threadIdx.y 9 grad 0.181036 xhat -1.139506
# threadIdx.x 1 threadIdx.y 9 grad 0.855983 xhat -1.025003
# threadIdx.x 2 threadIdx.y 9 grad 0.189700 xhat 0.459389
# threadIdx.x 3 threadIdx.y 9 grad 0.249326 xhat 1.213498
# threadIdx.x 4 threadIdx.y 9 grad 0.820159 xhat 1.057559
# threadIdx.x 5 threadIdx.y 9 grad 0.198365 xhat -0.477479
# threadIdx.x 6 threadIdx.y 9 grad 0.800210 xhat -0.281916
# threadIdx.x 7 threadIdx.y 9 grad 0.846642 xhat -0.261473
# threadIdx.x 8 threadIdx.y 9 grad 0.716579 xhat -0.517726
# threadIdx.x 9 threadIdx.y 9 grad 0.682714 xhat -1.488129
# threadIdx.x 10 threadIdx.y 9 grad 0.364153 xhat 0.001688
# threadIdx.x 11 threadIdx.y 9 grad 0.578475 xhat 1.376634
# threadIdx.x 12 threadIdx.y 9 grad 0.377205 xhat 0.891720
# threadIdx.x 13 threadIdx.y 9 grad 0.091921 xhat -0.534100
# threadIdx.x 14 threadIdx.y 9 grad 0.353437 xhat 1.327276
# threadIdx.x 15 threadIdx.y 9 grad 0.549157 xhat -1.131653
# threadIdx.x 16 threadIdx.y 9 grad 0.137418 xhat -0.742244
# threadIdx.x 17 threadIdx.y 9 grad 0.145823 xhat 0.287508
# threadIdx.x 18 threadIdx.y 9 grad 0.952400 xhat -0.627805
# threadIdx.x 19 threadIdx.y 9 grad 0.725802 xhat -0.373567
# threadIdx.x 20 threadIdx.y 9 grad 0.573763 xhat 0.026272
# threadIdx.x 21 threadIdx.y 9 grad 0.924197 xhat -0.439277
# threadIdx.x 22 threadIdx.y 9 grad 0.986789 xhat -0.232468
# threadIdx.x 23 threadIdx.y 9 grad 0.526551 xhat -0.880756
# threadIdx.x 24 threadIdx.y 9 grad 0.879584 xhat 1.215868
# threadIdx.x 25 threadIdx.y 9 grad 0.295420 xhat 0.929187
# threadIdx.x 26 threadIdx.y 9 grad 0.444103 xhat 1.275962
# threadIdx.x 27 threadIdx.y 9 grad 0.617824 xhat 1.223493
# threadIdx.x 28 threadIdx.y 9 grad 0.777979 xhat 0.357133
# threadIdx.x 29 threadIdx.y 9 grad 0.273947 xhat 1.617631
# threadIdx.x 30 threadIdx.y 9 grad 0.804753 xhat -1.481596
# threadIdx.x 31 threadIdx.y 9 grad 0.410400 xhat -0.090724
# threadIdx.x 0 threadIdx.y 5 grad 0.782831 xhat -0.554894
# threadIdx.x 1 threadIdx.y 5 grad 0.570965 xhat 1.449832
# threadIdx.x 2 threadIdx.y 5 grad 0.319647 xhat 0.284278
# threadIdx.x 3 threadIdx.y 5 grad 0.179926 xhat 1.476568
# threadIdx.x 4 threadIdx.y 5 grad 0.667750 xhat 0.409705
# threadIdx.x 5 threadIdx.y 5 grad 0.171966 xhat 0.584516
# threadIdx.x 6 threadIdx.y 5 grad 0.640858 xhat 1.548018
# threadIdx.x 7 threadIdx.y 5 grad 0.898432 xhat -0.009536
# threadIdx.x 8 threadIdx.y 5 grad 0.988878 xhat 1.329128
# threadIdx.x 9 threadIdx.y 5 grad 0.529575 xhat -1.004295
# threadIdx.x 10 threadIdx.y 5 grad 0.117048 xhat -0.537209
# threadIdx.x 11 threadIdx.y 5 grad 0.535280 xhat 1.050690
# threadIdx.x 12 threadIdx.y 5 grad 0.716379 xhat 1.274316
# threadIdx.x 13 threadIdx.y 5 grad 0.969064 xhat -1.578297
# threadIdx.x 14 threadIdx.y 5 grad 0.700460 xhat 0.112182
# threadIdx.x 15 threadIdx.y 5 grad 0.314784 xhat -0.016477
# threadIdx.x 16 threadIdx.y 5 grad 0.024686 xhat 0.949918
# threadIdx.x 17 threadIdx.y 5 grad 0.858898 xhat 0.044707
# threadIdx.x 18 threadIdx.y 5 grad 0.983105 xhat -0.244038
# threadIdx.x 19 threadIdx.y 5 grad 0.130513 xhat -1.246533
# threadIdx.x 20 threadIdx.y 5 grad 0.701096 xhat -0.969980
# threadIdx.x 21 threadIdx.y 5 grad 0.740774 xhat -0.488160
# threadIdx.x 22 threadIdx.y 5 grad 0.954406 xhat -0.221226
# threadIdx.x 23 threadIdx.y 5 grad 0.841033 xhat 1.120601
# threadIdx.x 24 threadIdx.y 5 grad 0.930247 xhat 0.825875
# threadIdx.x 25 threadIdx.y 5 grad 0.434542 xhat 0.104186
# threadIdx.x 26 threadIdx.y 5 grad 0.857785 xhat -1.253909
# threadIdx.x 27 threadIdx.y 5 grad 0.895613 xhat 1.252918
# threadIdx.x 28 threadIdx.y 5 grad 0.493335 xhat 1.640179
# threadIdx.x 29 threadIdx.y 5 grad 0.061936 xhat 0.457765
# threadIdx.x 30 threadIdx.y 5 grad 0.687255 xhat -0.500915
# threadIdx.x 31 threadIdx.y 5 grad 0.197143 xhat -0.827015
# threadIdx.x 0 threadIdx.y 2 grad 0.549256 xhat -1.712117
# threadIdx.x 1 threadIdx.y 2 grad 0.736285 xhat -0.032792
# threadIdx.x 2 threadIdx.y 2 grad 0.084625 xhat 1.213114
# threadIdx.x 3 threadIdx.y 2 grad 0.543956 xhat -0.887588
# threadIdx.x 4 threadIdx.y 2 grad 0.964366 xhat 0.447578
# threadIdx.x 5 threadIdx.y 2 grad 0.494768 xhat 1.119937
# threadIdx.x 6 threadIdx.y 2 grad 0.048664 xhat 1.387122
# threadIdx.x 7 threadIdx.y 2 grad 0.511506 xhat 0.675490
# threadIdx.x 8 threadIdx.y 2 grad 0.991766 xhat 0.397377
# threadIdx.x 9 threadIdx.y 2 grad 0.178504 xhat -0.669018
# threadIdx.x 10 threadIdx.y 2 grad 0.762914 xhat -0.517000
# threadIdx.x 11 threadIdx.y 2 grad 0.567575 xhat -1.666702
# threadIdx.x 12 threadIdx.y 2 grad 0.862342 xhat 0.144066
# threadIdx.x 13 threadIdx.y 2 grad 0.780332 xhat 1.436758
# threadIdx.x 14 threadIdx.y 2 grad 0.990842 xhat -0.682817
# threadIdx.x 15 threadIdx.y 2 grad 0.074064 xhat 1.068901
# threadIdx.x 16 threadIdx.y 2 grad 0.679000 xhat -1.488720
# threadIdx.x 17 threadIdx.y 2 grad 0.920417 xhat -1.448762
# threadIdx.x 18 threadIdx.y 2 grad 0.637617 xhat 0.516186
# threadIdx.x 19 threadIdx.y 2 grad 0.372904 xhat 0.110911
# threadIdx.x 20 threadIdx.y 2 grad 0.482461 xhat 0.391988
# threadIdx.x 21 threadIdx.y 2 grad 0.890931 xhat -0.431335
# threadIdx.x 22 threadIdx.y 2 grad 0.647934 xhat 0.195988
# threadIdx.x 23 threadIdx.y 2 grad 0.799400 xhat 0.374457
# threadIdx.x 24 threadIdx.y 2 grad 0.171765 xhat -0.501300
# threadIdx.x 25 threadIdx.y 2 grad 0.135701 xhat -0.825745
# threadIdx.x 26 threadIdx.y 2 grad 0.184466 xhat 0.277823
# threadIdx.x 27 threadIdx.y 2 grad 0.091525 xhat -1.734362
# threadIdx.x 28 threadIdx.y 2 grad 0.889801 xhat -1.591759
# threadIdx.x 29 threadIdx.y 2 grad 0.337216 xhat 1.393480
# threadIdx.x 30 threadIdx.y 2 grad 0.834223 xhat 1.217375
# threadIdx.x 31 threadIdx.y 2 grad 0.728948 xhat -1.076440
# threadIdx.x 0 threadIdx.y 1 grad 0.489484 xhat 0.799855
# threadIdx.x 1 threadIdx.y 1 grad 0.183434 xhat 1.394802
# threadIdx.x 2 threadIdx.y 1 grad 0.661271 xhat -1.100566
# threadIdx.x 3 threadIdx.y 1 grad 0.670995 xhat 1.099301
# threadIdx.x 4 threadIdx.y 1 grad 0.583928 xhat 0.495960
# threadIdx.x 5 threadIdx.y 1 grad 0.087580 xhat -0.699377
# threadIdx.x 6 threadIdx.y 1 grad 0.983317 xhat 0.266646
# threadIdx.x 7 threadIdx.y 1 grad 0.442986 xhat 0.447048
# threadIdx.x 8 threadIdx.y 1 grad 0.461265 xhat -1.175335
# threadIdx.x 9 threadIdx.y 1 grad 0.675465 xhat 1.158393
# threadIdx.x 10 threadIdx.y 1 grad 0.051239 xhat -1.144512
# threadIdx.x 11 threadIdx.y 1 grad 0.709143 xhat -1.555697
# threadIdx.x 12 threadIdx.y 1 grad 0.879442 xhat -0.587016
# threadIdx.x 13 threadIdx.y 1 grad 0.484022 xhat 0.965666
# threadIdx.x 14 threadIdx.y 1 grad 0.451962 xhat -0.965373
# threadIdx.x 15 threadIdx.y 1 grad 0.296623 xhat 0.354760
# threadIdx.x 16 threadIdx.y 1 grad 0.424864 xhat -0.556587
# threadIdx.x 17 threadIdx.y 1 grad 0.874416 xhat -1.261516
# threadIdx.x 18 threadIdx.y 1 grad 0.458122 xhat -1.644053
# threadIdx.x 19 threadIdx.y 1 grad 0.118598 xhat 0.443070
# threadIdx.x 20 threadIdx.y 1 grad 0.044472 xhat 0.141200
# threadIdx.x 21 threadIdx.y 1 grad 0.151505 xhat -1.268437
# threadIdx.x 22 threadIdx.y 1 grad 0.858408 xhat -0.143007
# threadIdx.x 23 threadIdx.y 1 grad 0.715703 xhat 0.868812
# threadIdx.x 24 threadIdx.y 1 grad 0.306461 xhat -1.219928
# threadIdx.x 25 threadIdx.y 1 grad 0.252366 xhat 1.151007
# threadIdx.x 26 threadIdx.y 1 grad 0.250807 xhat -1.215608
# threadIdx.x 27 threadIdx.y 1 grad 0.805735 xhat 0.532738
# threadIdx.x 28 threadIdx.y 1 grad 0.415141 xhat -1.494227
# threadIdx.x 29 threadIdx.y 1 grad 0.966811 xhat -0.572646
# threadIdx.x 30 threadIdx.y 1 grad 0.270086 xhat 1.152853
# threadIdx.x 31 threadIdx.y 1 grad 0.993425 xhat 0.134898
# threadIdx.x 0 threadIdx.y 5 grad 0.638573 xhat -0.041199
# threadIdx.x 1 threadIdx.y 5 grad 0.644622 xhat 0.794805
# threadIdx.x 2 threadIdx.y 5 grad 0.857688 xhat -1.245669
# threadIdx.x 3 threadIdx.y 5 grad 0.868701 xhat -0.090398
# threadIdx.x 4 threadIdx.y 5 grad 0.833258 xhat 0.250460
# threadIdx.x 5 threadIdx.y 5 grad 0.330697 xhat 0.796825
# threadIdx.x 6 threadIdx.y 5 grad 0.323076 xhat 0.719158
# threadIdx.x 7 threadIdx.y 5 grad 0.789370 xhat 0.432944
# threadIdx.x 8 threadIdx.y 5 grad 0.892781 xhat 0.150942
# threadIdx.x 9 threadIdx.y 5 grad 0.154225 xhat 1.536146
# threadIdx.x 10 threadIdx.y 5 grad 0.546476 xhat 1.076596
# threadIdx.x 11 threadIdx.y 5 grad 0.608700 xhat -0.562425
# threadIdx.x 12 threadIdx.y 5 grad 0.709742 xhat 1.001727
# threadIdx.x 13 threadIdx.y 5 grad 0.840044 xhat -0.987594
# threadIdx.x 14 threadIdx.y 5 grad 0.588835 xhat 0.789015
# threadIdx.x 15 threadIdx.y 5 grad 0.798173 xhat -1.447454
# threadIdx.x 16 threadIdx.y 5 grad 0.148916 xhat -0.973613
# threadIdx.x 17 threadIdx.y 5 grad 0.828967 xhat -0.744984
# threadIdx.x 18 threadIdx.y 5 grad 0.899496 xhat 0.925845
# threadIdx.x 19 threadIdx.y 5 grad 0.195002 xhat 0.784281
# threadIdx.x 20 threadIdx.y 5 grad 0.830952 xhat -0.717338
# threadIdx.x 21 threadIdx.y 5 grad 0.825182 xhat -0.531101
# threadIdx.x 22 threadIdx.y 5 grad 0.010194 xhat 0.713680
# threadIdx.x 23 threadIdx.y 5 grad 0.287216 xhat -1.061299
# threadIdx.x 24 threadIdx.y 5 grad 0.213985 xhat -1.058965
# threadIdx.x 25 threadIdx.y 5 grad 0.241062 xhat -0.011208
# threadIdx.x 26 threadIdx.y 5 grad 0.467555 xhat -0.852545
# threadIdx.x 27 threadIdx.y 5 grad 0.127592 xhat -0.953600
# threadIdx.x 28 threadIdx.y 5 grad 0.604633 xhat 0.655479
# threadIdx.x 29 threadIdx.y 5 grad 0.881673 xhat -1.442052
# threadIdx.x 30 threadIdx.y 5 grad 0.222927 xhat 1.381129
# threadIdx.x 31 threadIdx.y 5 grad 0.696308 xhat -0.571124
# threadIdx.x 0 threadIdx.y 5 grad 0.015859 xhat 0.830024
# threadIdx.x 1 threadIdx.y 5 grad 0.799709 xhat -1.345650
# threadIdx.x 2 threadIdx.y 5 grad 0.499856 xhat 0.764157
# threadIdx.x 3 threadIdx.y 5 grad 0.843155 xhat -0.070155
# threadIdx.x 4 threadIdx.y 5 grad 0.807514 xhat 0.888580
# threadIdx.x 5 threadIdx.y 5 grad 0.679269 xhat -0.974222
# threadIdx.x 6 threadIdx.y 5 grad 0.105121 xhat 1.581101
# threadIdx.x 7 threadIdx.y 5 grad 0.075368 xhat 0.912188
# threadIdx.x 8 threadIdx.y 5 grad 0.630525 xhat -0.605777
# threadIdx.x 9 threadIdx.y 5 grad 0.489633 xhat 1.171214
# threadIdx.x 10 threadIdx.y 5 grad 0.743998 xhat 1.297715
# threadIdx.x 11 threadIdx.y 5 grad 0.636885 xhat -1.062054
# threadIdx.x 12 threadIdx.y 5 grad 0.326855 xhat 0.100623
# threadIdx.x 13 threadIdx.y 5 grad 0.177976 xhat -1.534699
# threadIdx.x 14 threadIdx.y 5 grad 0.319201 xhat -1.638489
# threadIdx.x 15 threadIdx.y 5 grad 0.195857 xhat 0.283046
# threadIdx.x 16 threadIdx.y 5 grad 0.035892 xhat -0.140129
# threadIdx.x 17 threadIdx.y 5 grad 0.685548 xhat 0.716926
# threadIdx.x 18 threadIdx.y 5 grad 0.252263 xhat 0.467853
# threadIdx.x 19 threadIdx.y 5 grad 0.821631 xhat -1.135211
# threadIdx.x 20 threadIdx.y 5 grad 0.459131 xhat -0.652346
# threadIdx.x 21 threadIdx.y 5 grad 0.810230 xhat 0.828180
# threadIdx.x 22 threadIdx.y 5 grad 0.885477 xhat -1.125491
# threadIdx.x 23 threadIdx.y 5 grad 0.029479 xhat -1.542411
# threadIdx.x 24 threadIdx.y 5 grad 0.611801 xhat -1.235048
# threadIdx.x 25 threadIdx.y 5 grad 0.192058 xhat -0.039918
# threadIdx.x 26 threadIdx.y 5 grad 0.263471 xhat -0.645945
# threadIdx.x 27 threadIdx.y 5 grad 0.290482 xhat -0.116223
# threadIdx.x 28 threadIdx.y 5 grad 0.099020 xhat 1.551192
# threadIdx.x 29 threadIdx.y 5 grad 0.231853 xhat 0.217726
# threadIdx.x 30 threadIdx.y 5 grad 0.655859 xhat 1.739846
# threadIdx.x 31 threadIdx.y 5 grad 0.766540 xhat 1.370926
# threadIdx.x 0 threadIdx.y 7 grad 0.554150 xhat -0.841181
# threadIdx.x 1 threadIdx.y 7 grad 0.103031 xhat -1.674066
# threadIdx.x 2 threadIdx.y 7 grad 0.039530 xhat -0.822988
# threadIdx.x 3 threadIdx.y 7 grad 0.720416 xhat 0.363111
# threadIdx.x 4 threadIdx.y 7 grad 0.920213 xhat 1.610410
# threadIdx.x 5 threadIdx.y 7 grad 0.509701 xhat -1.823797
# threadIdx.x 6 threadIdx.y 7 grad 0.547812 xhat 0.380290
# threadIdx.x 7 threadIdx.y 7 grad 0.388605 xhat -0.289689
# threadIdx.x 8 threadIdx.y 7 grad 0.812674 xhat 0.764354
# threadIdx.x 9 threadIdx.y 7 grad 0.143966 xhat 0.251562
# threadIdx.x 10 threadIdx.y 7 grad 0.183002 xhat -0.727444
# threadIdx.x 11 threadIdx.y 7 grad 0.400034 xhat -0.912269
# threadIdx.x 12 threadIdx.y 7 grad 0.242909 xhat 1.601137
# threadIdx.x 13 threadIdx.y 7 grad 0.597671 xhat 0.980444
# threadIdx.x 14 threadIdx.y 7 grad 0.351434 xhat 0.797347
# threadIdx.x 15 threadIdx.y 7 grad 0.246710 xhat -0.553492
# threadIdx.x 16 threadIdx.y 7 grad 0.178295 xhat -0.031037
# threadIdx.x 17 threadIdx.y 7 grad 0.969299 xhat -0.011421
# threadIdx.x 18 threadIdx.y 7 grad 0.107002 xhat -1.680193
# threadIdx.x 19 threadIdx.y 7 grad 0.902553 xhat -1.241346
# threadIdx.x 20 threadIdx.y 7 grad 0.346940 xhat 0.968194
# threadIdx.x 21 threadIdx.y 7 grad 0.195226 xhat 1.615111
# threadIdx.x 22 threadIdx.y 7 grad 0.887002 xhat -0.722550
# threadIdx.x 23 threadIdx.y 7 grad 0.416459 xhat -0.806048
# threadIdx.x 24 threadIdx.y 7 grad 0.372881 xhat -1.135538
# threadIdx.x 25 threadIdx.y 7 grad 0.370718 xhat -0.570414
# threadIdx.x 26 threadIdx.y 7 grad 0.066070 xhat 1.571706
# threadIdx.x 27 threadIdx.y 7 grad 0.533951 xhat 1.123739
# threadIdx.x 28 threadIdx.y 7 grad 0.638065 xhat -0.516761
# threadIdx.x 29 threadIdx.y 7 grad 0.720324 xhat 0.953074
# threadIdx.x 30 threadIdx.y 7 grad 0.315870 xhat -0.207482
# threadIdx.x 31 threadIdx.y 7 grad 0.693192 xhat 0.299360
# threadIdx.x 0 threadIdx.y 7 grad 0.265274 xhat 0.977885
# threadIdx.x 1 threadIdx.y 7 grad 0.234161 xhat -0.627369
# threadIdx.x 2 threadIdx.y 7 grad 0.449166 xhat -1.542354
# threadIdx.x 3 threadIdx.y 7 grad 0.313621 xhat -0.056005
# threadIdx.x 4 threadIdx.y 7 grad 0.019456 xhat -0.086749
# threadIdx.x 5 threadIdx.y 7 grad 0.872831 xhat 1.381065
# threadIdx.x 6 threadIdx.y 7 grad 0.708981 xhat -1.002026
# threadIdx.x 7 threadIdx.y 7 grad 0.095075 xhat -0.253638
# threadIdx.x 8 threadIdx.y 7 grad 0.141385 xhat -0.438906
# threadIdx.x 9 threadIdx.y 7 grad 0.082468 xhat -1.634104
# threadIdx.x 10 threadIdx.y 7 grad 0.554984 xhat -1.338708
# threadIdx.x 11 threadIdx.y 7 grad 0.562979 xhat -0.087489
# threadIdx.x 12 threadIdx.y 7 grad 0.932967 xhat -1.112281
# threadIdx.x 13 threadIdx.y 7 grad 0.799967 xhat -0.047418
# threadIdx.x 14 threadIdx.y 7 grad 0.685719 xhat -0.642510
# threadIdx.x 15 threadIdx.y 7 grad 0.997795 xhat 1.462245
# threadIdx.x 16 threadIdx.y 7 grad 0.758438 xhat 1.517660
# threadIdx.x 17 threadIdx.y 7 grad 0.754214 xhat 0.570429
# threadIdx.x 18 threadIdx.y 7 grad 0.607721 xhat 1.065402
# threadIdx.x 19 threadIdx.y 7 grad 0.686280 xhat 0.126179
# threadIdx.x 20 threadIdx.y 7 grad 0.074029 xhat -0.128023
# threadIdx.x 21 threadIdx.y 7 grad 0.967097 xhat 0.172580
# threadIdx.x 22 threadIdx.y 7 grad 0.358105 xhat -0.573205
# threadIdx.x 23 threadIdx.y 7 grad 0.976553 xhat 0.069133
# threadIdx.x 24 threadIdx.y 7 grad 0.443857 xhat -0.598380
# threadIdx.x 25 threadIdx.y 7 grad 0.853284 xhat -1.829140
# threadIdx.x 26 threadIdx.y 7 grad 0.219427 xhat 0.346962
# threadIdx.x 27 threadIdx.y 7 grad 0.300657 xhat 1.146645
# threadIdx.x 28 threadIdx.y 7 grad 0.391859 xhat 1.481879
# threadIdx.x 29 threadIdx.y 7 grad 0.912350 xhat -1.761063
# threadIdx.x 30 threadIdx.y 7 grad 0.571184 xhat -0.801011
# threadIdx.x 31 threadIdx.y 7 grad 0.757554 xhat -0.812818
# threadIdx.x 0 threadIdx.y 1 grad 0.374382 xhat 0.903730
# threadIdx.x 1 threadIdx.y 1 grad 0.768916 xhat 0.486043
# threadIdx.x 2 threadIdx.y 1 grad 0.757322 xhat -0.849535
# threadIdx.x 3 threadIdx.y 1 grad 0.082800 xhat -0.286537
# threadIdx.x 4 threadIdx.y 1 grad 0.865261 xhat 0.283259
# threadIdx.x 5 threadIdx.y 1 grad 0.835540 xhat -1.676088
# threadIdx.x 6 threadIdx.y 1 grad 0.133925 xhat 1.067820
# threadIdx.x 7 threadIdx.y 1 grad 0.546778 xhat 1.597546
# threadIdx.x 8 threadIdx.y 1 grad 0.385391 xhat 0.075861
# threadIdx.x 9 threadIdx.y 1 grad 0.817089 xhat -1.487050
# threadIdx.x 10 threadIdx.y 1 grad 0.850122 xhat 0.062971
# threadIdx.x 11 threadIdx.y 1 grad 0.339072 xhat 1.465098
# threadIdx.x 12 threadIdx.y 1 grad 0.333575 xhat -0.076328
# threadIdx.x 13 threadIdx.y 1 grad 0.778959 xhat -1.567579
# threadIdx.x 14 threadIdx.y 1 grad 0.648168 xhat 0.684825
# threadIdx.x 15 threadIdx.y 1 grad 0.252031 xhat 0.555813
# threadIdx.x 16 threadIdx.y 1 grad 0.115677 xhat 1.333314
# threadIdx.x 17 threadIdx.y 1 grad 0.291342 xhat 1.432668
# threadIdx.x 18 threadIdx.y 1 grad 0.314238 xhat -0.583966
# threadIdx.x 19 threadIdx.y 1 grad 0.021426 xhat 1.018086
# threadIdx.x 20 threadIdx.y 1 grad 0.209631 xhat -0.840098
# threadIdx.x 21 threadIdx.y 1 grad 0.751594 xhat 1.413097
# threadIdx.x 22 threadIdx.y 1 grad 0.236076 xhat 0.255375
# threadIdx.x 23 threadIdx.y 1 grad 0.837807 xhat 0.017543
# threadIdx.x 24 threadIdx.y 1 grad 0.291974 xhat 1.068148
# threadIdx.x 25 threadIdx.y 1 grad 0.448608 xhat 0.392000
# threadIdx.x 26 threadIdx.y 1 grad 0.805752 xhat -1.299103
# threadIdx.x 27 threadIdx.y 1 grad 0.861259 xhat 1.591642
# threadIdx.x 28 threadIdx.y 1 grad 0.578596 xhat 0.445763
# threadIdx.x 29 threadIdx.y 1 grad 0.006148 xhat 0.054868
# threadIdx.x 30 threadIdx.y 1 grad 0.190822 xhat 0.809735
# threadIdx.x 31 threadIdx.y 1 grad 0.990285 xhat 1.145844
# threadIdx.x 0 threadIdx.y 6 grad 0.286371 xhat -0.716483
# threadIdx.x 1 threadIdx.y 6 grad 0.024485 xhat -1.582307
# threadIdx.x 2 threadIdx.y 6 grad 0.562770 xhat -0.306457
# threadIdx.x 3 threadIdx.y 6 grad 0.192202 xhat 0.216553
# threadIdx.x 4 threadIdx.y 6 grad 0.486271 xhat -1.508215
# threadIdx.x 5 threadIdx.y 6 grad 0.859851 xhat -1.628264
# threadIdx.x 6 threadIdx.y 6 grad 0.724931 xhat 0.842462
# threadIdx.x 7 threadIdx.y 6 grad 0.484585 xhat -0.979146
# threadIdx.x 8 threadIdx.y 6 grad 0.319569 xhat -0.074705
# threadIdx.x 9 threadIdx.y 6 grad 0.313086 xhat -0.863924
# threadIdx.x 10 threadIdx.y 6 grad 0.159423 xhat 0.140307
# threadIdx.x 11 threadIdx.y 6 grad 0.012516 xhat -1.443974
# threadIdx.x 12 threadIdx.y 6 grad 0.216022 xhat -1.021633
# threadIdx.x 13 threadIdx.y 6 grad 0.272667 xhat 0.000112
# threadIdx.x 14 threadIdx.y 6 grad 0.228542 xhat 0.097544
# threadIdx.x 15 threadIdx.y 6 grad 0.332089 xhat 1.541633
# threadIdx.x 16 threadIdx.y 6 grad 0.741340 xhat -0.887910
# threadIdx.x 17 threadIdx.y 6 grad 0.971122 xhat 1.300886
# threadIdx.x 18 threadIdx.y 6 grad 0.079214 xhat -0.534093
# threadIdx.x 19 threadIdx.y 6 grad 0.199511 xhat 0.143359
# threadIdx.x 20 threadIdx.y 6 grad 0.454711 xhat -0.768432
# threadIdx.x 21 threadIdx.y 6 grad 0.978416 xhat 0.776778
# threadIdx.x 22 threadIdx.y 6 grad 0.961019 xhat 1.100783
# threadIdx.x 23 threadIdx.y 6 grad 0.830676 xhat -0.849364
# threadIdx.x 24 threadIdx.y 6 grad 0.579172 xhat 0.247447
# threadIdx.x 25 threadIdx.y 6 grad 0.309720 xhat 0.362587
# threadIdx.x 26 threadIdx.y 6 grad 0.525741 xhat 0.829417
# threadIdx.x 27 threadIdx.y 6 grad 0.435322 xhat -1.600857
# threadIdx.x 28 threadIdx.y 6 grad 0.684237 xhat -0.430558
# threadIdx.x 29 threadIdx.y 6 grad 0.917830 xhat -1.038513
# threadIdx.x 30 threadIdx.y 6 grad 0.742582 xhat 1.413288
# threadIdx.x 31 threadIdx.y 6 grad 0.259641 xhat 1.742116
# threadIdx.x 0 threadIdx.y 1 grad 0.974519 xhat -1.211075
# threadIdx.x 1 threadIdx.y 1 grad 0.132960 xhat 1.239479
# threadIdx.x 2 threadIdx.y 1 grad 0.214952 xhat 0.971114
# threadIdx.x 3 threadIdx.y 1 grad 0.751781 xhat 0.305205
# threadIdx.x 4 threadIdx.y 1 grad 0.401875 xhat -0.432184
# threadIdx.x 5 threadIdx.y 1 grad 0.712318 xhat 0.489633
# threadIdx.x 6 threadIdx.y 1 grad 0.519834 xhat 0.159521
# threadIdx.x 7 threadIdx.y 1 grad 0.901293 xhat -1.417007
# threadIdx.x 8 threadIdx.y 1 grad 0.481065 xhat -0.486643
# threadIdx.x 9 threadIdx.y 1 grad 0.349842 xhat 1.503447
# threadIdx.x 10 threadIdx.y 1 grad 0.205068 xhat -1.426068
# threadIdx.x 11 threadIdx.y 1 grad 0.692764 xhat 0.265589
# threadIdx.x 12 threadIdx.y 1 grad 0.916840 xhat -1.071557
# threadIdx.x 13 threadIdx.y 1 grad 0.961987 xhat -0.480804
# threadIdx.x 14 threadIdx.y 1 grad 0.512238 xhat 0.920716
# threadIdx.x 15 threadIdx.y 1 grad 0.215820 xhat -0.087941
# threadIdx.x 16 threadIdx.y 1 grad 0.392135 xhat -0.309316
# threadIdx.x 17 threadIdx.y 1 grad 0.137202 xhat 1.666000
# threadIdx.x 18 threadIdx.y 1 grad 0.217054 xhat 0.181481
# threadIdx.x 19 threadIdx.y 1 grad 0.973240 xhat -0.600953
# threadIdx.x 20 threadIdx.y 1 grad 0.461339 xhat -0.997650
# threadIdx.x 21 threadIdx.y 1 grad 0.142207 xhat 0.984223
# threadIdx.x 22 threadIdx.y 1 grad 0.815854 xhat 0.048260
# threadIdx.x 23 threadIdx.y 1 grad 0.896920 xhat -0.150134
# threadIdx.x 24 threadIdx.y 1 grad 0.492891 xhat 0.534046
# threadIdx.x 25 threadIdx.y 1 grad 0.514502 xhat 0.213987
# threadIdx.x 26 threadIdx.y 1 grad 0.362774 xhat 1.583519
# threadIdx.x 27 threadIdx.y 1 grad 0.544000 xhat 0.628079
# threadIdx.x 28 threadIdx.y 1 grad 0.676703 xhat -0.445853
# threadIdx.x 29 threadIdx.y 1 grad 0.607614 xhat 0.974070
# threadIdx.x 30 threadIdx.y 1 grad 0.543752 xhat 0.555456
# threadIdx.x 31 threadIdx.y 1 grad 0.973930 xhat 0.339780
# threadIdx.x 0 threadIdx.y 4 grad 0.591923 xhat -0.756815
# threadIdx.x 1 threadIdx.y 4 grad 0.986480 xhat 1.466089
# threadIdx.x 2 threadIdx.y 4 grad 0.161797 xhat -0.464468
# threadIdx.x 3 threadIdx.y 4 grad 0.031116 xhat 0.076163
# threadIdx.x 4 threadIdx.y 4 grad 0.258710 xhat -1.463819
# threadIdx.x 5 threadIdx.y 4 grad 0.393837 xhat -0.998904
# threadIdx.x 6 threadIdx.y 4 grad 0.190302 xhat -1.584578
# threadIdx.x 7 threadIdx.y 4 grad 0.833217 xhat -1.345203
# threadIdx.x 8 threadIdx.y 4 grad 0.282392 xhat -1.709733
# threadIdx.x 9 threadIdx.y 4 grad 0.512452 xhat -1.653126
# threadIdx.x 10 threadIdx.y 4 grad 0.457681 xhat 1.385365
# threadIdx.x 11 threadIdx.y 4 grad 0.654034 xhat -0.003282
# threadIdx.x 12 threadIdx.y 4 grad 0.087175 xhat -1.646052
# threadIdx.x 13 threadIdx.y 4 grad 0.497516 xhat -0.622760
# threadIdx.x 14 threadIdx.y 4 grad 0.785665 xhat 1.661846
# threadIdx.x 15 threadIdx.y 4 grad 0.998163 xhat 1.317161
# threadIdx.x 16 threadIdx.y 4 grad 0.439387 xhat 0.057168
# threadIdx.x 17 threadIdx.y 4 grad 0.102296 xhat -1.733781
# threadIdx.x 18 threadIdx.y 4 grad 0.232061 xhat -0.148414
# threadIdx.x 19 threadIdx.y 4 grad 0.694748 xhat -1.389941
# threadIdx.x 20 threadIdx.y 4 grad 0.475357 xhat -1.066520
# threadIdx.x 21 threadIdx.y 4 grad 0.815781 xhat 0.054007
# threadIdx.x 22 threadIdx.y 4 grad 0.728512 xhat -1.252568
# threadIdx.x 23 threadIdx.y 4 grad 0.246048 xhat -1.735798
# threadIdx.x 24 threadIdx.y 4 grad 0.926316 xhat 0.811683
# threadIdx.x 25 threadIdx.y 4 grad 0.421732 xhat -1.705406
# threadIdx.x 26 threadIdx.y 4 grad 0.082844 xhat 0.529809
# threadIdx.x 27 threadIdx.y 4 grad 0.302397 xhat 0.623357
# threadIdx.x 28 threadIdx.y 4 grad 0.891161 xhat -0.859495
# threadIdx.x 29 threadIdx.y 4 grad 0.360219 xhat -0.219041
# threadIdx.x 30 threadIdx.y 4 grad 0.749398 xhat -0.676113
# threadIdx.x 31 threadIdx.y 4 grad 0.660018 xhat -0.790366
# threadIdx.x 0 threadIdx.y 3 grad 0.541373 xhat -1.369889
# threadIdx.x 1 threadIdx.y 3 grad 0.080309 xhat -0.872921
# threadIdx.x 2 threadIdx.y 3 grad 0.000296 xhat 0.004446
# threadIdx.x 3 threadIdx.y 3 grad 0.075299 xhat 0.778475
# threadIdx.x 4 threadIdx.y 3 grad 0.834057 xhat 0.428656
# threadIdx.x 5 threadIdx.y 3 grad 0.999376 xhat 1.410942
# threadIdx.x 6 threadIdx.y 3 grad 0.434528 xhat -0.178972
# threadIdx.x 7 threadIdx.y 3 grad 0.861584 xhat 1.653142
# threadIdx.x 8 threadIdx.y 3 grad 0.567743 xhat 1.244444
# threadIdx.x 9 threadIdx.y 3 grad 0.777504 xhat -1.706790
# threadIdx.x 10 threadIdx.y 3 grad 0.724147 xhat 1.134585
# threadIdx.x 11 threadIdx.y 3 grad 0.974298 xhat -1.684182
# threadIdx.x 12 threadIdx.y 3 grad 0.506672 xhat -0.075170
# threadIdx.x 13 threadIdx.y 3 grad 0.626001 xhat 0.797777
# threadIdx.x 14 threadIdx.y 3 grad 0.625725 xhat 1.567721
# threadIdx.x 15 threadIdx.y 3 grad 0.379159 xhat -1.045410
# threadIdx.x 16 threadIdx.y 3 grad 0.704524 xhat -1.058768
# threadIdx.x 17 threadIdx.y 3 grad 0.638706 xhat 0.308548
# threadIdx.x 18 threadIdx.y 3 grad 0.041733 xhat -0.031684
# threadIdx.x 19 threadIdx.y 3 grad 0.709974 xhat -1.144848
# threadIdx.x 20 threadIdx.y 3 grad 0.302135 xhat 1.353556
# threadIdx.x 21 threadIdx.y 3 grad 0.433490 xhat -1.228559
# threadIdx.x 22 threadIdx.y 3 grad 0.885437 xhat 0.255176
# threadIdx.x 23 threadIdx.y 3 grad 0.507793 xhat 0.445199
# threadIdx.x 24 threadIdx.y 3 grad 0.154177 xhat -0.178108
# threadIdx.x 25 threadIdx.y 3 grad 0.146598 xhat -1.391434
# threadIdx.x 26 threadIdx.y 3 grad 0.411379 xhat 0.078011
# threadIdx.x 27 threadIdx.y 3 grad 0.928312 xhat 0.037391
# threadIdx.x 28 threadIdx.y 3 grad 0.475726 xhat -1.592065
# threadIdx.x 29 threadIdx.y 3 grad 0.297423 xhat 1.424350
# threadIdx.x 30 threadIdx.y 3 grad 0.180340 xhat -1.111690
# threadIdx.x 31 threadIdx.y 3 grad 0.021447 xhat 1.058999
# threadIdx.x 0 threadIdx.y 6 grad 0.290943 xhat 1.704777
# threadIdx.x 1 threadIdx.y 6 grad 0.946918 xhat -0.722014
# threadIdx.x 2 threadIdx.y 6 grad 0.158637 xhat 1.366263
# threadIdx.x 3 threadIdx.y 6 grad 0.079283 xhat -1.415058
# threadIdx.x 4 threadIdx.y 6 grad 0.528176 xhat 0.585894
# threadIdx.x 5 threadIdx.y 6 grad 0.887806 xhat 0.800909
# threadIdx.x 6 threadIdx.y 6 grad 0.196661 xhat -1.413580
# ...
# 	[-1.393011 -0.714294 0.354107 -0.247573 -0.875834 -1.671420 -1.239217 1.194428 -0.464247 1.381665 0.924027 1.280965 1.184365 -0.216430 -0.531739 -0.500383 0.734346 -0.702435 -0.404590 -0.631926 -1.770973 0.421719 0.973851 0.455360 -1.649041 -1.137786 0.496417 -1.535729 -1.010621 1.023797 1.150504 1.255871 0.346035 1.117662 0.286751 -0.942836 1.236308 1.034898 -0.304952 0.894586 -1.505063 -1.209460 1.425567 -0.345248 1.200229 -1.609515 1.476780 0.739134 0.652717 1.497084 0.685434 0.414177 1.586090 -1.382921 -0.060786 -0.234687 0.372120 -0.335299 1.563970 -0.721462 0.909158 0.728654 -1.647493 0.801279 -1.162763 -1.354247 1.038043 -0.326922 -1.139743 -0.327218 -1.158617 -0.452485 1.170179 -0.449921 0.797867 1.229814 -0.447208 -1.574957 0.482348 1.517592 0.989201 -0.098141 -0.074683 -0.193227 -0.302311 -1.605082 1.577108 1.188760 0.453707 -1.589143 0.866277 -0.310286 -0.127411 -0.407740 -1.343427 0.454802 0.116008 1.544937 0.856932 1.264570 -0.344907 0.721802 0.862909 -0.067134 1.182661 0.340232 1.028860 0.338964 -1.041297 0.972559 0.568558 -1.451248 -0.009992 0.984194 -0.737849 -1.712036 -0.399731 1.242531 -0.832966 -1.566492 1.525272 0.118058 1.226165 0.336500 1.347887 1.035456 1.170929 -1.377584 1.128889 -0.938856 1.243843 -1.381936 -1.051797 0.099029 0.417503 -1.242453 1.015526 0.857259 -1.071806 0.805406 0.348385 -1.825199 1.397527 1.443559 -0.731868 -1.459369 0.420371 1.158737 -0.215482 -1.380413 -1.068302 0.696198 -0.708762 0.619004 1.261473 -1.042744 0.700723 -0.536148 -1.796790 -0.206326 -1.448966 0.741919 -0.296906 0.268668 0.628834 0.943193 0.269852 0.267103 -1.335288 -0.746164 -1.429707 -0.395066 1.588768 0.569913 1.351276 -0.669356 0.124739 0.099023 0.252633 -1.024274 1.083232 0.248495 1.407796 -1.073423 0.084893 1.581639 -1.340523 0.517085 -1.128690 -0.407821 0.129128 1.376403 1.111080 1.450430 -0.242187 -0.631741 0.533525 0.284691 1.042597 -0.648612 -1.455378 -1.602234 0.706787 -1.391650 -0.050071 0.099231 -1.515465 0.107695 -0.996185 -0.404462 0.682580 1.150734 -0.699418 -0.189895 -0.328636 0.059660 -1.287701 1.246308 0.878142 0.099372 1.139491 0.338985 0.109529 0.255286 0.414967 -0.329987 -0.112819 0.485782 1.593750 1.038433 0.978729 -1.308866 -0.515043 -0.950326 -0.682069 -1.745823 0.319866 0.106973 -1.646667 0.302178 -0.509066 0.172688 0.365887 0.109747 -0.161639 -1.736822 -0.594772 1.335874 0.690295 0.655818 0.907919 1.211689 -1.093497 0.709988 -0.973227 1.454854 0.505381 1.630970 0.113913 -0.727513 0.985811 0.102724 -0.610105 1.629197 0.393622 0.766636 -0.991359 -0.498064 1.583429 -0.666413 -0.866848 -1.580793 1.064752 -0.534387 -1.321615 -1.298906 -0.841988 -0.690415 -1.382365 -0.980463 -1.575969 0.078818 -0.042335 0.309445 0.985998 0.998121 0.815623 1.175434 -0.130639 -0.122172 -0.702783 1.508850 1.248669 0.745535 -0.638888 1.507810 -0.438222 1.032913 -1.638883 -0.688925 0.563239 -0.160184 -0.561694 -0.024996 -0.904447 1.179799 -0.977675 -1.107257 1.029427 1.071883 0.037120 -0.048379 1.348243 1.059789 -0.208380 -1.776891 -0.838738 0.181196 -1.516080 -0.882867 -0.341439 1.502101 -0.574375 -1.421422 0.721072 0.751569 0.985041 0.280331 -1.676304 0.044687 -0.505325 0.513443 0.297925 0.581116 -1.565460 1.314451 -1.274136 -0.793904 0.542515 -0.660801 1.184468 0.537558 0.340779 1.126559 -0.805273 0.055101 1.421946 -1.230896 0.364121 0.867019 -1.564595 1.402457 -0.101839 1.018069 -1.741849 1.123566 0.812109 0.760501 0.131002 1.209653 -0.383067 -1.330205 -0.786826 0.368851 0.735337 -1.765380 0.778142 -1.605563 0.540273 0.747257 -0.069261 -1.474913 0.492726 1.277238 0.833128 -0.870600 -0.176460 -0.368385 -0.328846 -0.033003 1.409733 1.515153 0.462540 -0.959860 -0.753602 0.869615 1.388407 -1.642013 -0.989816 1.306414 0.960029 0.898385 -1.746209 -0.491391 -1.280134 -1.824126 0.041548 0.866300 -0.730027 -0.492577 -1.084925 1.307110 1.265318 -0.349025 0.383068 -0.392868 0.599864 0.700512 0.284307 0.140490 -1.619225 0.511384 0.254898 -0.326489 -0.989223 -1.564252 -0.192761 -0.661569 1.348170 0.756171 1.635526 -1.344419 0. ...
# 	[1.363436 -1.633494 -0.303497 -0.686187 -1.500886 -0.329433 -0.574768 0.002229 1.343013 -1.355601 1.642406 -1.551160 0.088998 1.167993 -0.643584 -0.619928 1.542331 0.562691 -1.374717 -0.875529 0.757262 0.269643 1.191247 -1.120279 1.664649 -1.116627 0.359305 -0.189794 1.213954 -0.850705 -1.083588 1.383029 -1.643310 -0.313005 -0.065296 0.468270 1.307529 -1.607271 -0.575232 0.526986 -0.862100 -0.391024 -1.433733 -1.036345 0.828500 1.448338 0.245294 -0.630977 -0.469503 -1.114828 -0.378232 1.087850 -0.395879 1.194581 0.765962 -0.143609 1.441458 0.234887 0.719495 0.612122 0.305469 -1.521181 -1.594316 0.122282 1.658438 -1.355520 -0.421139 -0.677615 -1.433040 -1.095505 -0.793731 1.054365 1.203016 1.688410 0.379308 0.411670 -0.832079 1.626066 1.401523 -0.325315 -1.292378 0.434053 -0.202147 -0.003964 1.432100 0.753055 -0.974660 0.327556 0.273557 -0.142730 -0.959185 0.164735 0.167960 -1.415186 1.226197 -1.675850 -1.638155 1.538638 1.646497 1.339393 -0.636368 -0.268836 1.054892 -0.323457 -0.465394 -0.071252 -0.573713 0.675859 1.615734 -1.363080 -0.901376 -1.161952 1.360735 1.423619 0.907202 0.761091 0.460954 -1.509663 0.143149 0.962537 1.477314 -1.394656 -0.919859 1.274762 1.650522 1.266315 0.694355 0.458957 -1.636699 0.037394 1.413920 0.860251 0.741026 -1.011529 0.300547 -0.535618 -0.217919 0.448607 -1.310624 -0.303591 1.589530 0.992803 1.450238 0.597996 -1.180453 -1.361830 1.001499 0.990331 0.900244 -0.085871 0.013434 0.457499 -0.095363 -0.613763 0.395622 -0.780081 1.262708 1.276950 0.897510 1.525932 0.996885 -0.714903 -1.304608 1.614647 -0.625267 0.940867 1.168663 0.536363 -0.102322 -1.098030 -0.292204 -0.060969 0.613953 -0.161337 -0.836582 1.143520 -0.241279 -0.496708 -0.475302 -1.598470 -1.094746 -0.680693 1.525844 1.214077 0.834767 1.152737 -0.873209 1.598723 -1.416118 -1.082599 0.768992 1.622425 -0.377008 -0.358242 0.626211 0.228991 -0.482639 0.257229 -0.288024 1.468184 -1.352149 -0.672816 -0.355656 0.646765 -0.317224 -0.158786 -0.868024 1.282958 0.090848 1.346088 1.681503 -0.899698 -1.173719 -0.180379 1.007964 1.275985 1.412803 -1.519137 0.068299 0.383177 -0.515961 -1.657825 -1.397761 0.611062 -0.169120 -1.233144 0.643657 0.959805 1.224608 1.120441 1.112756 -0.039327 1.155590 0.554210 -0.544948 0.923107 -0.172772 -0.009959 -1.094283 0.061316 1.671128 -0.288481 -0.373818 -0.778309 -1.675498 -1.669510 -0.962506 0.718082 -1.375200 0.801494 0.013172 0.546117 -1.416389 -1.490147 -0.980382 -1.320708 -1.044408 -1.302694 1.560084 -1.474830 -1.236838 -0.759612 -1.120239 -1.414073 0.300234 1.325802 -0.929435 -1.497423 -0.448801 1.347052 -1.064718 0.720830 -0.959667 0.581133 -0.419961 -0.557529 -0.439983 -0.659199 0.410036 -0.455440 -0.624769 1.380138 -0.725034 -1.536725 1.132373 -1.532108 -0.037763 -1.105055 -0.221546 -1.029028 1.516889 -0.661021 0.593464 1.588415 0.008784 -0.730232 -0.294486 -0.883700 -0.322109 0.633132 0.371713 0.161395 -1.336851 0.092517 0.850592 0.635726 -1.487723 1.042561 -0.773978 -1.080605 -0.695649 -0.169136 -0.604097 1.363957 -0.350201 -0.269574 0.046916 -1.312409 -0.104073 1.026595 -0.842979 1.107876 1.449388 -0.955165 0.948503 -0.023834 1.593389 1.234349 1.031677 -1.605417 -0.253537 -0.172452 0.099064 1.647739 -0.835477 -0.930904 0.264775 -0.638730 1.605093 -1.393757 0.317318 0.403791 1.649980 -0.376081 -0.592465 1.076660 -1.129932 0.912777 0.997330 0.624337 -1.572716 0.644648 -0.675583 -0.638862 1.520066 -0.590336 -1.258795 -1.395322 1.635745 -1.274686 1.387605 -0.707982 -0.629571 0.421029 -1.080637 -1.290438 -0.487407 -1.116344 -1.230208 -1.146223 -0.127768 0.299260 -0.210550 -1.193239 1.211784 -0.819233 -1.045370 -0.036737 0.515756 1.531239 0.753257 1.169315 1.197044 -1.109567 0.418963 -0.261721 1.370640 -0.643986 1.355888 1.472439 0.837926 1.469144 -1.007485 -1.164821 -1.478775 0.300590 -1.643217 -0.698578 1.650829 -1.023368 0.018461 0.679524 0.427402 -1.424655 -0.732257 -1.256625 -1.055965 1.689551 -0.541019 1.208076 -0.446627 1.072853 -1.164866 -1.410601 1.035474 -0.403593 1.688906 -0.842466 0.816614 0.201 ...
# 	[1.040757 -0.907134 1.500603 0.067791 -0.537001 0.187580 1.043288 0.033183 -1.078494 1.619174 -0.742227 0.163789 1.486861 -0.409013 -1.452479 0.562542 1.067920 0.887873 0.454556 -1.055339 -0.310681 1.406770 -0.923246 0.117171 0.403391 -0.931989 -0.900432 1.627732 0.824650 -0.380080 -0.990447 0.325936 1.586743 0.219341 -1.430078 -0.055809 -1.167662 -0.297971 -0.688294 -0.955172 -0.887115 -1.559194 -0.541403 -1.195117 -1.637256 1.030320 0.338719 0.857406 0.956737 0.896130 -0.867226 1.425511 0.793490 -1.540199 0.129703 0.865157 -1.238386 -1.550054 0.535761 0.894686 1.293018 0.300654 0.784094 0.303344 -1.216920 -1.384871 -0.486422 0.715169 1.324734 -0.422497 0.143232 1.104586 -0.535300 0.617186 -0.183878 1.226523 0.941218 -1.691945 -0.070463 -0.804728 1.262804 -0.086187 -1.409485 -1.507028 -0.827224 1.454097 0.592798 -1.147464 -1.021016 -1.621297 1.010755 1.073250 -0.504645 -0.245778 -0.028531 -0.593150 0.818418 -1.053969 0.204100 -0.396172 -0.561869 1.480594 1.182441 -0.843445 1.472906 -1.088953 -1.522575 0.838850 0.585622 0.552100 -1.077538 0.252865 -0.814673 0.897157 -0.579078 -0.545389 1.416056 0.304075 0.689627 -1.009179 -0.316841 -0.125122 1.087004 -0.560820 1.247773 0.184161 -0.684734 -1.561647 -0.464811 -0.938198 -1.069241 0.660220 -0.316758 -1.183809 0.285049 0.371327 1.617790 -0.181522 -1.068321 0.845968 -0.050421 -0.889511 0.382251 1.632990 1.160454 -0.209185 1.128058 1.390303 -1.209023 -0.325423 0.595099 1.420282 -1.355871 1.035471 0.165386 -0.450445 -0.858391 -0.038674 -0.103675 -0.200271 -0.083201 1.471644 1.318546 0.264736 1.015647 -0.369594 0.969312 -0.917627 0.104557 -0.693288 -0.761476 -0.298672 -1.313362 0.532600 1.174877 0.811367 0.692150 -0.167076 0.716287 -0.411703 1.526172 1.253772 1.629609 -0.224572 0.810178 1.033797 -0.498197 1.390255 1.254304 1.154635 1.448391 -0.893968 -1.160822 1.271587 -0.496917 0.418970 -0.927466 1.338979 -0.719884 -1.138243 -0.489444 -0.766177 -1.558452 0.053288 -1.126067 -0.405610 -1.319412 0.033602 -0.868180 1.237456 0.748007 0.576959 1.067243 1.186242 0.627286 0.370640 1.238491 1.584273 -1.387884 -0.062712 -0.210855 -0.462101 1.131193 -0.334006 -0.188618 -1.429525 1.240334 1.086296 1.122506 -0.054951 0.716121 0.283332 1.527058 -1.494426 1.026518 0.800285 -0.464972 -1.240655 -0.410788 0.985947 -0.162435 1.488422 -1.081417 0.681590 1.430696 -1.274896 -1.436146 0.520823 -1.611816 0.626018 0.358930 1.654409 -1.520833 -1.308380 -1.313405 1.250472 -1.139506 -1.025003 0.459389 1.213497 1.057558 -0.477479 -0.281916 -0.261473 -0.517726 -1.488129 0.001687 1.376633 0.891719 -0.534101 1.327275 -1.131653 -0.742243 0.287508 -0.627805 -0.373567 0.026271 -0.439277 -0.232468 -0.880756 1.215867 0.929186 1.275962 1.223492 0.357133 1.617630 -1.481596 -0.090724 -1.040875 -1.027192 0.693373 -0.992281 -0.218344 0.748346 -1.566442 0.671696 -1.021081 -0.525263 1.233642 1.030383 -0.873659 -1.147359 -0.740441 -0.033115 0.049992 -0.800144 -1.190563 -0.287543 -1.080540 -0.506210 1.630424 0.764513 1.337587 -0.502302 -0.072829 -0.330530 1.268064 -0.724984 -1.227045 -0.185160 -0.838831 0.361849 0.159544 -1.678719 -1.263214 0.646979 1.300480 0.561500 0.664802 1.441591 -0.472296 -0.324110 1.039716 0.622561 -1.328676 -1.487909 1.185357 -1.682986 0.232944 -1.713270 0.285504 0.856074 -0.299338 -0.678672 -0.876277 0.397380 -1.687965 -0.880128 1.631176 0.979701 -0.882618 -1.106509 1.316115 1.440436 1.290304 0.233677 -0.279772 -0.426634 1.428642 1.375806 -1.593526 0.919165 -1.388265 1.260396 -0.804118 -1.353915 0.883319 0.870756 -1.254463 -1.102038 -0.155433 0.127996 1.160941 -1.465391 1.418718 0.866192 -1.532160 -1.535419 -0.611370 -0.885616 -1.462003 0.749498 1.578125 -1.610372 0.160527 0.100491 -0.949579 -0.578494 0.993196 -0.676269 -1.333877 -1.125691 0.369598 0.543409 -0.224251 -0.810097 -1.171841 0.517661 -0.028592 0.764258 -1.543893 0.001544 0.380389 -1.463435 1.342268 1.591436 -1.521221 1.182528 -0.656840 0.624514 0.261838 1.003669 1.284650 0.183581 -1.250280 0.319290 0.009072 -0.700736 0.454299 1.440199 -0.099 ...

# %%
(f_gamma_grad-gamma_mt).to_numpy().max()
# Out:
# 2.026558e-05
