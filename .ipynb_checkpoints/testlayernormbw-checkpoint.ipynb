# %%
# %%
import minitorch
from minitorch.cuda_kernel_ops import CudaKernelOps
backend = minitorch.TensorBackend(CudaKernelOps)
import time
import numpy as np

# %%
# %%
rows = 10
hidden_dim = 960

def rand(shape):
    return np.random.rand(*shape)

inp = rand((rows, hidden_dim))
out_grad = rand((rows,hidden_dim))
gamma = rand((hidden_dim,))
beta = rand((hidden_dim,))


def custom():
    inp_mt = minitorch.tensor_from_numpy(inp, backend=backend, requires_grad=True)
    gamma_mt = minitorch.tensor_from_numpy(gamma, backend=backend, requires_grad=True)
    beta_mt = minitorch.tensor_from_numpy(beta, backend=backend, requires_grad=True)
    out_grad_mt = minitorch.tensor_from_numpy(out_grad, backend=backend, requires_grad=True)

    out_mt = inp_mt.layernorm(gamma_mt, beta_mt)
    out_mt.backward(out_grad_mt)

    return inp_mt.grad, gamma_mt.grad, beta_mt.grad, inp_mt, gamma_mt, beta_mt

def baseline():
    f_input = minitorch.tensor_from_numpy(inp, backend=backend, requires_grad=True)
    f_gamma = minitorch.tensor_from_numpy(gamma, backend=backend, requires_grad=True)
    f_out_grad = minitorch.tensor_from_numpy(out_grad, backend=backend, requires_grad=True)

    f_means = f_input.mean(dim=1)
    f_vars = f_input.var(dim=1)
    f_stds = minitorch.tensor(np.sqrt(f_vars.to_numpy()).reshape(-1, 1).tolist(), backend=backend, requires_grad=True)

    xhat = (f_input - f_means) / f_stds
    print(xhat)
    dxhat = f_out_grad * f_gamma
    f_betta_grad = f_out_grad.sum(dim=0)
    f_gamma_grad = (f_out_grad * xhat).sum(dim=0)
    dinp = dxhat.sum(dim=1) + xhat * (dxhat * xhat).sum(dim=1)
    dinp = dxhat - dinp / hidden_dim
    dinp = dinp / f_stds
    return dinp, f_gamma_grad, f_betta_grad




#     return res


# %%


# %%
inp_grad_mt, gamma_mt, beta_mt, my_inp,g,b = custom()
dinp, f_gamma_grad, f_betta_grad = baseline()
# print(c-b)
# Out:
# threadIdx.x 0 threadIdx.y 2 grad 0.034777 xhat 1.546675
# threadIdx.x 1 threadIdx.y 2 grad 0.119503 xhat 1.450822
# threadIdx.x 2 threadIdx.y 2 grad 0.156209 xhat 0.803982
# threadIdx.x 3 threadIdx.y 2 grad 0.961724 xhat -1.098891
# threadIdx.x 4 threadIdx.y 2 grad 0.542171 xhat 0.320265
# threadIdx.x 5 threadIdx.y 2 grad 0.736066 xhat -1.216780
# threadIdx.x 6 threadIdx.y 2 grad 0.964330 xhat -0.109338
# threadIdx.x 7 threadIdx.y 2 grad 0.298532 xhat -0.121526
# threadIdx.x 8 threadIdx.y 2 grad 0.994314 xhat -0.569814
# threadIdx.x 9 threadIdx.y 2 grad 0.857131 xhat 0.767572
# threadIdx.x 10 threadIdx.y 2 grad 0.241567 xhat 0.931331
# threadIdx.x 11 threadIdx.y 2 grad 0.888804 xhat 0.610758
# threadIdx.x 12 threadIdx.y 2 grad 0.020139 xhat -1.425353
# threadIdx.x 13 threadIdx.y 2 grad 0.069969 xhat -0.891831
# threadIdx.x 14 threadIdx.y 2 grad 0.163875 xhat -0.271100
# threadIdx.x 15 threadIdx.y 2 grad 0.918622 xhat 1.087667
# threadIdx.x 16 threadIdx.y 2 grad 0.151154 xhat 1.100138
# threadIdx.x 17 threadIdx.y 2 grad 0.824054 xhat -0.169969
# threadIdx.x 18 threadIdx.y 2 grad 0.466619 xhat 0.897532
# threadIdx.x 19 threadIdx.y 2 grad 0.591446 xhat -0.872517
# threadIdx.x 20 threadIdx.y 2 grad 0.781543 xhat 0.183691
# threadIdx.x 21 threadIdx.y 2 grad 0.773233 xhat -0.446213
# threadIdx.x 22 threadIdx.y 2 grad 0.537617 xhat 1.406293
# threadIdx.x 23 threadIdx.y 2 grad 0.731650 xhat 1.249895
# threadIdx.x 24 threadIdx.y 2 grad 0.973725 xhat 0.991213
# threadIdx.x 25 threadIdx.y 2 grad 0.114368 xhat 0.993980
# threadIdx.x 26 threadIdx.y 2 grad 0.041743 xhat -0.259447
# threadIdx.x 27 threadIdx.y 2 grad 0.760494 xhat -1.657215
# threadIdx.x 28 threadIdx.y 2 grad 0.097343 xhat 0.163297
# threadIdx.x 29 threadIdx.y 2 grad 0.019378 xhat -0.615925
# threadIdx.x 30 threadIdx.y 2 grad 0.087597 xhat 0.900487
# threadIdx.x 31 threadIdx.y 2 grad 0.349607 xhat -1.615978
# threadIdx.x 0 threadIdx.y 2 grad 0.262329 xhat 0.127718
# threadIdx.x 1 threadIdx.y 2 grad 0.711274 xhat -1.388299
# threadIdx.x 2 threadIdx.y 2 grad 0.103833 xhat 1.188249
# threadIdx.x 3 threadIdx.y 2 grad 0.564572 xhat 1.126392
# threadIdx.x 4 threadIdx.y 2 grad 0.752712 xhat -0.373339
# threadIdx.x 5 threadIdx.y 2 grad 0.765481 xhat 0.122167
# threadIdx.x 6 threadIdx.y 2 grad 0.536040 xhat 1.209289
# threadIdx.x 7 threadIdx.y 2 grad 0.252377 xhat -0.947695
# threadIdx.x 8 threadIdx.y 2 grad 0.405072 xhat -1.296015
# threadIdx.x 9 threadIdx.y 2 grad 0.379545 xhat -1.394774
# threadIdx.x 10 threadIdx.y 2 grad 0.625641 xhat -0.350811
# threadIdx.x 11 threadIdx.y 2 grad 0.837222 xhat 1.295074
# threadIdx.x 12 threadIdx.y 2 grad 0.598010 xhat 1.070477
# threadIdx.x 13 threadIdx.y 2 grad 0.177705 xhat 1.376444
# threadIdx.x 14 threadIdx.y 2 grad 0.133839 xhat 0.920916
# threadIdx.x 15 threadIdx.y 2 grad 0.833861 xhat -0.456731
# threadIdx.x 16 threadIdx.y 2 grad 0.204093 xhat -0.726589
# threadIdx.x 17 threadIdx.y 2 grad 0.241906 xhat 1.126657
# threadIdx.x 18 threadIdx.y 2 grad 0.120452 xhat 0.234212
# threadIdx.x 19 threadIdx.y 2 grad 0.054136 xhat 0.408815
# threadIdx.x 20 threadIdx.y 2 grad 0.945990 xhat -1.070842
# threadIdx.x 21 threadIdx.y 2 grad 0.714840 xhat -1.317282
# threadIdx.x 22 threadIdx.y 2 grad 0.017311 xhat 1.410836
# threadIdx.x 23 threadIdx.y 2 grad 0.150831 xhat -0.353693
# threadIdx.x 24 threadIdx.y 2 grad 0.638031 xhat -1.723026
# threadIdx.x 25 threadIdx.y 2 grad 0.331182 xhat -1.469556
# threadIdx.x 26 threadIdx.y 2 grad 0.107925 xhat 0.573687
# threadIdx.x 27 threadIdx.y 2 grad 0.462103 xhat -1.226381
# threadIdx.x 28 threadIdx.y 2 grad 0.741908 xhat 0.562946
# threadIdx.x 29 threadIdx.y 2 grad 0.630011 xhat 0.723313
# threadIdx.x 30 threadIdx.y 2 grad 0.553992 xhat 0.254721
# threadIdx.x 31 threadIdx.y 2 grad 0.913928 xhat -1.051586
# threadIdx.x 0 threadIdx.y 6 grad 0.143154 xhat 0.971666
# threadIdx.x 1 threadIdx.y 6 grad 0.363197 xhat -1.168391
# threadIdx.x 2 threadIdx.y 6 grad 0.892381 xhat -1.269873
# threadIdx.x 3 threadIdx.y 6 grad 0.088082 xhat -1.051119
# threadIdx.x 4 threadIdx.y 6 grad 0.986065 xhat -1.504193
# threadIdx.x 5 threadIdx.y 6 grad 0.169958 xhat 0.772897
# threadIdx.x 6 threadIdx.y 6 grad 0.903594 xhat -1.522773
# threadIdx.x 7 threadIdx.y 6 grad 0.464498 xhat 0.417456
# threadIdx.x 8 threadIdx.y 6 grad 0.130931 xhat 1.458747
# threadIdx.x 9 threadIdx.y 6 grad 0.224691 xhat 0.881243
# threadIdx.x 10 threadIdx.y 6 grad 0.416912 xhat 0.096306
# threadIdx.x 11 threadIdx.y 6 grad 0.449657 xhat 1.098005
# threadIdx.x 12 threadIdx.y 6 grad 0.717696 xhat 0.323338
# threadIdx.x 13 threadIdx.y 6 grad 0.861194 xhat 1.225654
# threadIdx.x 14 threadIdx.y 6 grad 0.843904 xhat -0.939929
# threadIdx.x 15 threadIdx.y 6 grad 0.053043 xhat 1.227484
# threadIdx.x 16 threadIdx.y 6 grad 0.476510 xhat -0.025420
# threadIdx.x 17 threadIdx.y 6 grad 0.570456 xhat -1.569957
# threadIdx.x 18 threadIdx.y 6 grad 0.028959 xhat -1.673993
# threadIdx.x 19 threadIdx.y 6 grad 0.950539 xhat 0.531134
# threadIdx.x 20 threadIdx.y 6 grad 0.470137 xhat -0.317542
# threadIdx.x 21 threadIdx.y 6 grad 0.601036 xhat -0.135976
# threadIdx.x 22 threadIdx.y 6 grad 0.702300 xhat 1.063514
# threadIdx.x 23 threadIdx.y 6 grad 0.856463 xhat 0.271122
# threadIdx.x 24 threadIdx.y 6 grad 0.400071 xhat -0.026547
# threadIdx.x 25 threadIdx.y 6 grad 0.958562 xhat -0.393902
# threadIdx.x 26 threadIdx.y 6 grad 0.652196 xhat -0.889678
# threadIdx.x 27 threadIdx.y 6 grad 0.210790 xhat -0.644151
# threadIdx.x 28 threadIdx.y 6 grad 0.157426 xhat -0.552944
# threadIdx.x 29 threadIdx.y 6 grad 0.562875 xhat -1.174332
# threadIdx.x 30 threadIdx.y 6 grad 0.017510 xhat -1.391323
# threadIdx.x 31 threadIdx.y 6 grad 0.937294 xhat 0.696926
# threadIdx.x 0 threadIdx.y 6 grad 0.061328 xhat 0.935010
# threadIdx.x 1 threadIdx.y 6 grad 0.922138 xhat -0.416821
# threadIdx.x 2 threadIdx.y 6 grad 0.410350 xhat -1.072155
# threadIdx.x 3 threadIdx.y 6 grad 0.222450 xhat -1.227149
# threadIdx.x 4 threadIdx.y 6 grad 0.866179 xhat 0.021101
# threadIdx.x 5 threadIdx.y 6 grad 0.486672 xhat -1.306486
# threadIdx.x 6 threadIdx.y 6 grad 0.819798 xhat 1.136903
# threadIdx.x 7 threadIdx.y 6 grad 0.307116 xhat 0.474352
# threadIdx.x 8 threadIdx.y 6 grad 0.005039 xhat -0.462784
# threadIdx.x 9 threadIdx.y 6 grad 0.087707 xhat -0.957799
# threadIdx.x 10 threadIdx.y 6 grad 0.980161 xhat 1.282540
# threadIdx.x 11 threadIdx.y 6 grad 0.238032 xhat -0.560908
# threadIdx.x 12 threadIdx.y 6 grad 0.861285 xhat -0.504794
# threadIdx.x 13 threadIdx.y 6 grad 0.846998 xhat -0.764666
# threadIdx.x 14 threadIdx.y 6 grad 0.914308 xhat -0.419395
# threadIdx.x 15 threadIdx.y 6 grad 0.106973 xhat 0.958243
# threadIdx.x 16 threadIdx.y 6 grad 0.049794 xhat -0.336182
# threadIdx.x 17 threadIdx.y 6 grad 0.177716 xhat -0.524116
# threadIdx.x 18 threadIdx.y 6 grad 0.539458 xhat -0.276448
# threadIdx.x 19 threadIdx.y 6 grad 0.652064 xhat 0.088643
# threadIdx.x 20 threadIdx.y 6 grad 0.210197 xhat 1.106604
# threadIdx.x 21 threadIdx.y 6 grad 0.059894 xhat 0.471047
# threadIdx.x 22 threadIdx.y 6 grad 0.625792 xhat -0.270216
# threadIdx.x 23 threadIdx.y 6 grad 0.550689 xhat -0.949506
# threadIdx.x 24 threadIdx.y 6 grad 0.969271 xhat 1.511061
# threadIdx.x 25 threadIdx.y 6 grad 0.839668 xhat -0.780688
# threadIdx.x 26 threadIdx.y 6 grad 0.333220 xhat -1.526631
# threadIdx.x 27 threadIdx.y 6 grad 0.646841 xhat 1.576535
# threadIdx.x 28 threadIdx.y 6 grad 0.824130 xhat -1.390504
# threadIdx.x 29 threadIdx.y 6 grad 0.030947 xhat 1.532241
# threadIdx.x 30 threadIdx.y 6 grad 0.087605 xhat -0.271248
# threadIdx.x 31 threadIdx.y 6 grad 0.397752 xhat 1.607065
# threadIdx.x 0 threadIdx.y 6 grad 0.246491 xhat -1.577326
# threadIdx.x 1 threadIdx.y 6 grad 0.954108 xhat 0.060657
# threadIdx.x 2 threadIdx.y 6 grad 0.497481 xhat 0.446723
# threadIdx.x 3 threadIdx.y 6 grad 0.022735 xhat -1.721555
# threadIdx.x 4 threadIdx.y 6 grad 0.796495 xhat -1.471796
# threadIdx.x 5 threadIdx.y 6 grad 0.400015 xhat 1.523234
# threadIdx.x 6 threadIdx.y 6 grad 0.977414 xhat 0.383606
# threadIdx.x 7 threadIdx.y 6 grad 0.547182 xhat -0.396448
# threadIdx.x 8 threadIdx.y 6 grad 0.081065 xhat -1.329513
# threadIdx.x 9 threadIdx.y 6 grad 0.073888 xhat -1.482910
# threadIdx.x 10 threadIdx.y 6 grad 0.860559 xhat 1.424169
# threadIdx.x 11 threadIdx.y 6 grad 0.576718 xhat 0.722473
# threadIdx.x 12 threadIdx.y 6 grad 0.669091 xhat 1.150833
# threadIdx.x 13 threadIdx.y 6 grad 0.787647 xhat 0.294819
# threadIdx.x 14 threadIdx.y 6 grad 0.882927 xhat 1.596745
# threadIdx.x 15 threadIdx.y 6 grad 0.067669 xhat 0.619568
# threadIdx.x 16 threadIdx.y 6 grad 0.752871 xhat -0.981762
# threadIdx.x 17 threadIdx.y 6 grad 0.222966 xhat 0.423014
# threadIdx.x 18 threadIdx.y 6 grad 0.025555 xhat -1.006546
# threadIdx.x 19 threadIdx.y 6 grad 0.208067 xhat -0.790818
# threadIdx.x 20 threadIdx.y 6 grad 0.333494 xhat 1.605070
# threadIdx.x 21 threadIdx.y 6 grad 0.902826 xhat 0.694676
# threadIdx.x 22 threadIdx.y 6 grad 0.003566 xhat -0.939366
# threadIdx.x 23 threadIdx.y 6 grad 0.179582 xhat -1.006019
# threadIdx.x 24 threadIdx.y 6 grad 0.130278 xhat 0.845928
# threadIdx.x 25 threadIdx.y 6 grad 0.103117 xhat -0.307200
# threadIdx.x 26 threadIdx.y 6 grad 0.734092 xhat 0.764216
# threadIdx.x 27 threadIdx.y 6 grad 0.545252 xhat 0.830125
# threadIdx.x 28 threadIdx.y 6 grad 0.845405 xhat 0.864743
# threadIdx.x 29 threadIdx.y 6 grad 0.712043 xhat -0.994158
# threadIdx.x 30 threadIdx.y 6 grad 0.419662 xhat 0.926970
# threadIdx.x 31 threadIdx.y 6 grad 0.353272 xhat 0.447118
# threadIdx.x 0 threadIdx.y 3 grad 0.077299 xhat 0.969387
# threadIdx.x 1 threadIdx.y 3 grad 0.167792 xhat -0.371122
# threadIdx.x 2 threadIdx.y 3 grad 0.284736 xhat -0.080617
# threadIdx.x 3 threadIdx.y 3 grad 0.794227 xhat -0.046921
# threadIdx.x 4 threadIdx.y 3 grad 0.900563 xhat -0.243055
# threadIdx.x 5 threadIdx.y 3 grad 0.466244 xhat -0.038013
# threadIdx.x 6 threadIdx.y 3 grad 0.006102 xhat 1.472532
# threadIdx.x 7 threadIdx.y 3 grad 0.732262 xhat -0.805315
# threadIdx.x 8 threadIdx.y 3 grad 0.068051 xhat 1.224690
# threadIdx.x 9 threadIdx.y 3 grad 0.648461 xhat -1.242736
# threadIdx.x 10 threadIdx.y 3 grad 0.594892 xhat 0.627305
# threadIdx.x 11 threadIdx.y 3 grad 0.275365 xhat 1.159781
# threadIdx.x 12 threadIdx.y 3 grad 0.924821 xhat 0.071552
# threadIdx.x 13 threadIdx.y 3 grad 0.481637 xhat -1.258749
# threadIdx.x 14 threadIdx.y 3 grad 0.762557 xhat 1.124342
# threadIdx.x 15 threadIdx.y 3 grad 0.789821 xhat 0.265187
# threadIdx.x 16 threadIdx.y 3 grad 0.209945 xhat 1.005356
# threadIdx.x 17 threadIdx.y 3 grad 0.477880 xhat 0.364663
# threadIdx.x 18 threadIdx.y 3 grad 0.805278 xhat -1.274332
# threadIdx.x 19 threadIdx.y 3 grad 0.677433 xhat 1.217127
# threadIdx.x 20 threadIdx.y 3 grad 0.468155 xhat 1.398409
# threadIdx.x 21 threadIdx.y 3 grad 0.712882 xhat -0.524203
# threadIdx.x 22 threadIdx.y 3 grad 0.432070 xhat 0.649914
# threadIdx.x 23 threadIdx.y 3 grad 0.809057 xhat 0.760326
# threadIdx.x 24 threadIdx.y 3 grad 0.267066 xhat -0.382766
# threadIdx.x 25 threadIdx.y 3 grad 0.593992 xhat -1.199258
# threadIdx.x 26 threadIdx.y 3 grad 0.122720 xhat -0.786679
# threadIdx.x 27 threadIdx.y 3 grad 0.457140 xhat -0.354816
# threadIdx.x 28 threadIdx.y 3 grad 0.225209 xhat 0.137089
# threadIdx.x 29 threadIdx.y 3 grad 0.332370 xhat 1.131619
# threadIdx.x 30 threadIdx.y 3 grad 0.779435 xhat 0.657491
# threadIdx.x 31 threadIdx.y 3 grad 0.645735 xhat -0.789144
# threadIdx.x 0 threadIdx.y 2 grad 0.066406 xhat -1.541794
# threadIdx.x 1 threadIdx.y 2 grad 0.567369 xhat -0.748216
# threadIdx.x 2 threadIdx.y 2 grad 0.778113 xhat 1.302348
# threadIdx.x 3 threadIdx.y 2 grad 0.503044 xhat 0.701836
# threadIdx.x 4 threadIdx.y 2 grad 0.388187 xhat 1.369135
# threadIdx.x 5 threadIdx.y 2 grad 0.120847 xhat 1.603340
# threadIdx.x 6 threadIdx.y 2 grad 0.076173 xhat -0.988895
# threadIdx.x 7 threadIdx.y 2 grad 0.340912 xhat 0.236223
# threadIdx.x 8 threadIdx.y 2 grad 0.208210 xhat 0.459512
# threadIdx.x 9 threadIdx.y 2 grad 0.706464 xhat -0.555074
# threadIdx.x 10 threadIdx.y 2 grad 0.739121 xhat 1.078059
# threadIdx.x 11 threadIdx.y 2 grad 0.428907 xhat 1.406101
# threadIdx.x 12 threadIdx.y 2 grad 0.283921 xhat -1.021589
# threadIdx.x 13 threadIdx.y 2 grad 0.309798 xhat -0.187395
# threadIdx.x 14 threadIdx.y 2 grad 0.606352 xhat 0.988687
# threadIdx.x 15 threadIdx.y 2 grad 0.235607 xhat 0.089197
# threadIdx.x 16 threadIdx.y 2 grad 0.286996 xhat 1.185116
# threadIdx.x 17 threadIdx.y 2 grad 0.369596 xhat -0.437627
# threadIdx.x 18 threadIdx.y 2 grad 0.744097 xhat -1.403975
# threadIdx.x 19 threadIdx.y 2 grad 0.126452 xhat 1.408408
# threadIdx.x 20 threadIdx.y 2 grad 0.096495 xhat -0.864677
# threadIdx.x 21 threadIdx.y 2 grad 0.706101 xhat -0.558204
# threadIdx.x 22 threadIdx.y 2 grad 0.454983 xhat 0.169750
# threadIdx.x 23 threadIdx.y 2 grad 0.144169 xhat -0.411150
# threadIdx.x 24 threadIdx.y 2 grad 0.102540 xhat -0.900966
# threadIdx.x 25 threadIdx.y 2 grad 0.144550 xhat -0.171436
# threadIdx.x 26 threadIdx.y 2 grad 0.269051 xhat -1.696519
# threadIdx.x 27 threadIdx.y 2 grad 0.012333 xhat 0.860825
# threadIdx.x 28 threadIdx.y 2 grad 0.399498 xhat -0.040830
# threadIdx.x 29 threadIdx.y 2 grad 0.051324 xhat -0.024655
# threadIdx.x 30 threadIdx.y 2 grad 0.364261 xhat -0.093709
# threadIdx.x 31 threadIdx.y 2 grad 0.314382 xhat -0.441298
# threadIdx.x 0 threadIdx.y 7 grad 0.506847 xhat 0.750585
# threadIdx.x 1 threadIdx.y 7 grad 0.183708 xhat -0.509886
# threadIdx.x 2 threadIdx.y 7 grad 0.115363 xhat 1.697141
# threadIdx.x 3 threadIdx.y 7 grad 0.500224 xhat -0.911372
# threadIdx.x 4 threadIdx.y 7 grad 0.219839 xhat 0.485744
# threadIdx.x 5 threadIdx.y 7 grad 0.030208 xhat -0.360504
# threadIdx.x 6 threadIdx.y 7 grad 0.372965 xhat -0.543754
# threadIdx.x 7 threadIdx.y 7 grad 0.025198 xhat -0.695078
# threadIdx.x 8 threadIdx.y 7 grad 0.723145 xhat -1.778886
# threadIdx.x 9 threadIdx.y 7 grad 0.296474 xhat -1.655476
# threadIdx.x 10 threadIdx.y 7 grad 0.147122 xhat -0.072825
# threadIdx.x 11 threadIdx.y 7 grad 0.007722 xhat 1.752925
# threadIdx.x 12 threadIdx.y 7 grad 0.978802 xhat 0.016720
# threadIdx.x 13 threadIdx.y 7 grad 0.774482 xhat -1.410143
# threadIdx.x 14 threadIdx.y 7 grad 0.628445 xhat -0.558760
# threadIdx.x 15 threadIdx.y 7 grad 0.374994 xhat -0.443166
# threadIdx.x 16 threadIdx.y 7 grad 0.500824 xhat -0.376219
# threadIdx.x 17 threadIdx.y 7 grad 0.883056 xhat 0.280602
# threadIdx.x 18 threadIdx.y 7 grad 0.410387 xhat -1.096968
# threadIdx.x 19 threadIdx.y 7 grad 0.960354 xhat -0.021952
# threadIdx.x 20 threadIdx.y 7 grad 0.624299 xhat -1.660032
# threadIdx.x 21 threadIdx.y 7 grad 0.332245 xhat -1.358469
# threadIdx.x 22 threadIdx.y 7 grad 0.832596 xhat 1.443440
# threadIdx.x 23 threadIdx.y 7 grad 0.513736 xhat -0.408016
# threadIdx.x 24 threadIdx.y 7 grad 0.874544 xhat 1.462137
# threadIdx.x 25 threadIdx.y 7 grad 0.888713 xhat -0.521743
# threadIdx.x 26 threadIdx.y 7 grad 0.108472 xhat -0.396020
# threadIdx.x 27 threadIdx.y 7 grad 0.762787 xhat -0.503853
# threadIdx.x 28 threadIdx.y 7 grad 0.613905 xhat 0.968438
# threadIdx.x 29 threadIdx.y 7 grad 0.141345 xhat 1.426258
# threadIdx.x 30 threadIdx.y 7 grad 0.059025 xhat -0.385145
# threadIdx.x 31 threadIdx.y 7 grad 0.486842 xhat -0.845436
# threadIdx.x 0 threadIdx.y 9 grad 0.139227 xhat -1.195536
# threadIdx.x 1 threadIdx.y 9 grad 0.346089 xhat -0.311155
# threadIdx.x 2 threadIdx.y 9 grad 0.562623 xhat -0.410116
# threadIdx.x 3 threadIdx.y 9 grad 0.562776 xhat -1.681748
# threadIdx.x 4 threadIdx.y 9 grad 0.441586 xhat -1.667270
# threadIdx.x 5 threadIdx.y 9 grad 0.240228 xhat -1.857115
# threadIdx.x 6 threadIdx.y 9 grad 0.252935 xhat -0.246997
# threadIdx.x 7 threadIdx.y 9 grad 0.339079 xhat 0.609242
# threadIdx.x 8 threadIdx.y 9 grad 0.758323 xhat -0.417674
# threadIdx.x 9 threadIdx.y 9 grad 0.011875 xhat 0.350516
# threadIdx.x 10 threadIdx.y 9 grad 0.862479 xhat 1.341265
# threadIdx.x 11 threadIdx.y 9 grad 0.487400 xhat 1.087780
# threadIdx.x 12 threadIdx.y 9 grad 0.812299 xhat 0.281940
# threadIdx.x 13 threadIdx.y 9 grad 0.116164 xhat 1.067158
# threadIdx.x 14 threadIdx.y 9 grad 0.999607 xhat 1.381669
# threadIdx.x 15 threadIdx.y 9 grad 0.383792 xhat -0.694364
# threadIdx.x 16 threadIdx.y 9 grad 0.645950 xhat -1.491153
# threadIdx.x 17 threadIdx.y 9 grad 0.746382 xhat 0.692412
# threadIdx.x 18 threadIdx.y 9 grad 0.442232 xhat -0.480762
# threadIdx.x 19 threadIdx.y 9 grad 0.329345 xhat -0.818520
# threadIdx.x 20 threadIdx.y 9 grad 0.042608 xhat 0.558865
# threadIdx.x 21 threadIdx.y 9 grad 0.591673 xhat -0.235426
# threadIdx.x 22 threadIdx.y 9 grad 0.494282 xhat 0.370844
# threadIdx.x 23 threadIdx.y 9 grad 0.164352 xhat -1.861825
# threadIdx.x 24 threadIdx.y 9 grad 0.132220 xhat 1.423928
# threadIdx.x 25 threadIdx.y 9 grad 0.913505 xhat 0.074155
# threadIdx.x 26 threadIdx.y 9 grad 0.097780 xhat 0.309844
# threadIdx.x 27 threadIdx.y 9 grad 0.517548 xhat -0.515889
# threadIdx.x 28 threadIdx.y 9 grad 0.381797 xhat 1.008322
# threadIdx.x 29 threadIdx.y 9 grad 0.758982 xhat 0.812443
# threadIdx.x 30 threadIdx.y 9 grad 0.594025 xhat -0.941949
# threadIdx.x 31 threadIdx.y 9 grad 0.032279 xhat 0.373104
# threadIdx.x 0 threadIdx.y 3 grad 0.856512 xhat 0.700464
# threadIdx.x 1 threadIdx.y 3 grad 0.059000 xhat 0.254912
# threadIdx.x 2 threadIdx.y 3 grad 0.800880 xhat -1.390463
# threadIdx.x 3 threadIdx.y 3 grad 0.926394 xhat 1.271659
# threadIdx.x 4 threadIdx.y 3 grad 0.075823 xhat -0.201241
# threadIdx.x 5 threadIdx.y 3 grad 0.357398 xhat -1.154098
# threadIdx.x 6 threadIdx.y 3 grad 0.837281 xhat -0.620009
# threadIdx.x 7 threadIdx.y 3 grad 0.175067 xhat 0.502409
# threadIdx.x 8 threadIdx.y 3 grad 0.321837 xhat 0.742790
# threadIdx.x 9 threadIdx.y 3 grad 0.317216 xhat -0.586556
# threadIdx.x 10 threadIdx.y 3 grad 0.165444 xhat 1.430784
# threadIdx.x 11 threadIdx.y 3 grad 0.701344 xhat 0.153272
# threadIdx.x 12 threadIdx.y 3 grad 0.318029 xhat 0.417652
# threadIdx.x 13 threadIdx.y 3 grad 0.122047 xhat -1.189334
# threadIdx.x 14 threadIdx.y 3 grad 0.628634 xhat -0.883394
# threadIdx.x 15 threadIdx.y 3 grad 0.628776 xhat -0.333751
# threadIdx.x 16 threadIdx.y 3 grad 0.996862 xhat 0.421523
# threadIdx.x 17 threadIdx.y 3 grad 0.956463 xhat 1.139022
# threadIdx.x 18 threadIdx.y 3 grad 0.591154 xhat 0.724241
# threadIdx.x 19 threadIdx.y 3 grad 0.846628 xhat 1.404376
# threadIdx.x 20 threadIdx.y 3 grad 0.600588 xhat 1.409269
# threadIdx.x 21 threadIdx.y 3 grad 0.398263 xhat 0.675637
# threadIdx.x 22 threadIdx.y 3 grad 0.621327 xhat -0.320947
# threadIdx.x 23 threadIdx.y 3 grad 0.681409 xhat -0.988478
# threadIdx.x 24 threadIdx.y 3 grad 0.475120 xhat 1.658135
# threadIdx.x 25 threadIdx.y 3 grad 0.921493 xhat -1.506500
# threadIdx.x 26 threadIdx.y 3 grad 0.799327 xhat -1.533074
# threadIdx.x 27 threadIdx.y 3 grad 0.507281 xhat -1.094318
# threadIdx.x 28 threadIdx.y 3 grad 0.414685 xhat -1.217636
# threadIdx.x 29 threadIdx.y 3 grad 0.173721 xhat 1.489575
# threadIdx.x 30 threadIdx.y 3 grad 0.854547 xhat 1.408818
# threadIdx.x 31 threadIdx.y 3 grad 0.289389 xhat -1.500387
# threadIdx.x 0 threadIdx.y 7 grad 0.932418 xhat -1.439166
# threadIdx.x 1 threadIdx.y 7 grad 0.685567 xhat 0.635202
# threadIdx.x 2 threadIdx.y 7 grad 0.219778 xhat 1.470157
# threadIdx.x 3 threadIdx.y 7 grad 0.725767 xhat 0.374331
# threadIdx.x 4 threadIdx.y 7 grad 0.234824 xhat 0.621992
# threadIdx.x 5 threadIdx.y 7 grad 0.362194 xhat -0.236967
# threadIdx.x 6 threadIdx.y 7 grad 0.871133 xhat -1.743108
# threadIdx.x 7 threadIdx.y 7 grad 0.073713 xhat 1.519882
# threadIdx.x 8 threadIdx.y 7 grad 0.705421 xhat 0.333982
# threadIdx.x 9 threadIdx.y 7 grad 0.403968 xhat -0.772191
# threadIdx.x 10 threadIdx.y 7 grad 0.206969 xhat 0.654334
# threadIdx.x 11 threadIdx.y 7 grad 0.871163 xhat 0.285583
# threadIdx.x 12 threadIdx.y 7 grad 0.590118 xhat 0.230747
# threadIdx.x 13 threadIdx.y 7 grad 0.634990 xhat 1.007452
# threadIdx.x 14 threadIdx.y 7 grad 0.811698 xhat 0.026556
# threadIdx.x 15 threadIdx.y 7 grad 0.978177 xhat -0.227242
# threadIdx.x 16 threadIdx.y 7 grad 0.313492 xhat -0.324773
# threadIdx.x 17 threadIdx.y 7 grad 0.190735 xhat -0.524359
# threadIdx.x 18 threadIdx.y 7 grad 0.288307 xhat -0.971747
# threadIdx.x 19 threadIdx.y 7 grad 0.797600 xhat 1.412535
# threadIdx.x 20 threadIdx.y 7 grad 0.976778 xhat -1.410185
# threadIdx.x 21 threadIdx.y 7 grad 0.909944 xhat -0.236438
# threadIdx.x 22 threadIdx.y 7 grad 0.073314 xhat -0.071602
# threadIdx.x 23 threadIdx.y 7 grad 0.273168 xhat -1.651579
# threadIdx.x 24 threadIdx.y 7 grad 0.280482 xhat -0.426082
# threadIdx.x 25 threadIdx.y 7 grad 0.591262 xhat -0.853086
# threadIdx.x 26 threadIdx.y 7 grad 0.884235 xhat 0.436990
# threadIdx.x 27 threadIdx.y 7 grad 0.582593 xhat 0.492778
# threadIdx.x 28 threadIdx.y 7 grad 0.909593 xhat 1.237155
# threadIdx.x 29 threadIdx.y 7 grad 0.090070 xhat 0.705535
# threadIdx.x 30 threadIdx.y 7 grad 0.764735 xhat 0.032375
# threadIdx.x 31 threadIdx.y 7 grad 0.392743 xhat 0.246511
# threadIdx.x 0 threadIdx.y 6 grad 0.518981 xhat 0.938345
# threadIdx.x 1 threadIdx.y 6 grad 0.348954 xhat 1.597736
# threadIdx.x 2 threadIdx.y 6 grad 0.734943 xhat 1.133383
# threadIdx.x 3 threadIdx.y 6 grad 0.998356 xhat 1.402737
# threadIdx.x 4 threadIdx.y 6 grad 0.280808 xhat 0.317523
# threadIdx.x 5 threadIdx.y 6 grad 0.214070 xhat -1.171955
# threadIdx.x 6 threadIdx.y 6 grad 0.032615 xhat -1.146609
# threadIdx.x 7 threadIdx.y 6 grad 0.379314 xhat 1.177388
# threadIdx.x 8 threadIdx.y 6 grad 0.131158 xhat 1.543840
# threadIdx.x 9 threadIdx.y 6 grad 0.751190 xhat -0.140919
# threadIdx.x 10 threadIdx.y 6 grad 0.138175 xhat 1.249514
# threadIdx.x 11 threadIdx.y 6 grad 0.815992 xhat 0.792830
# threadIdx.x 12 threadIdx.y 6 grad 0.540893 xhat -1.690673
# threadIdx.x 13 threadIdx.y 6 grad 0.945089 xhat 1.400644
# threadIdx.x 14 threadIdx.y 6 grad 0.257033 xhat -0.775513
# threadIdx.x 15 threadIdx.y 6 grad 0.448365 xhat 0.875290
# threadIdx.x 16 threadIdx.y 6 grad 0.160527 xhat -1.749150
# threadIdx.x 17 threadIdx.y 6 grad 0.314652 xhat 0.213771
# threadIdx.x 18 threadIdx.y 6 grad 0.222442 xhat -0.796244
# threadIdx.x 19 threadIdx.y 6 grad 0.191001 xhat -0.384585
# threadIdx.x 20 threadIdx.y 6 grad 0.483563 xhat -0.665856
# threadIdx.x 21 threadIdx.y 6 grad 0.291861 xhat -0.538618
# threadIdx.x 22 threadIdx.y 6 grad 0.524519 xhat -0.898446
# threadIdx.x 23 threadIdx.y 6 grad 0.301869 xhat 0.392110
# threadIdx.x 24 threadIdx.y 6 grad 0.025472 xhat 0.286311
# threadIdx.x 25 threadIdx.y 6 grad 0.692061 xhat 0.414491
# threadIdx.x 26 threadIdx.y 6 grad 0.491648 xhat 0.097654
# threadIdx.x 27 threadIdx.y 6 grad 0.542590 xhat -0.624912
# threadIdx.x 28 threadIdx.y 6 grad 0.923570 xhat 0.873951
# threadIdx.x 29 threadIdx.y 6 grad 0.284989 xhat -1.460756
# threadIdx.x 30 threadIdx.y 6 grad 0.539830 xhat 1.594774
# threadIdx.x 31 threadIdx.y 6 grad 0.678246 xhat 0.656376
# threadIdx.x 0 threadIdx.y 7 grad 0.716647 xhat -1.380624
# threadIdx.x 1 threadIdx.y 7 grad 0.761385 xhat 0.222818
# threadIdx.x 2 threadIdx.y 7 grad 0.590572 xhat -0.432182
# threadIdx.x 3 threadIdx.y 7 grad 0.842770 xhat -0.172987
# threadIdx.x 4 threadIdx.y 7 grad 0.249093 xhat -0.635648
# threadIdx.x 5 threadIdx.y 7 grad 0.404895 xhat 1.508336
# threadIdx.x 6 threadIdx.y 7 grad 0.452435 xhat 1.770250
# threadIdx.x 7 threadIdx.y 7 grad 0.681411 xhat -0.321967
# threadIdx.x 8 threadIdx.y 7 grad 0.301007 xhat 1.353491
# threadIdx.x 9 threadIdx.y 7 grad 0.640334 xhat -0.233731
# threadIdx.x 10 threadIdx.y 7 grad 0.913170 xhat -0.216402
# threadIdx.x 11 threadIdx.y 7 grad 0.615209 xhat -1.573683
# threadIdx.x 12 threadIdx.y 7 grad 0.497515 xhat 1.471294
# threadIdx.x 13 threadIdx.y 7 grad 0.863790 xhat 0.301820
# threadIdx.x 14 threadIdx.y 7 grad 0.824285 xhat -0.862221
# threadIdx.x 15 threadIdx.y 7 grad 0.962184 xhat -1.432605
# threadIdx.x 16 threadIdx.y 7 grad 0.614373 xhat -1.731680
# threadIdx.x 17 threadIdx.y 7 grad 0.840878 xhat -1.285257
# threadIdx.x 18 threadIdx.y 7 grad 0.411800 xhat 0.026015
# threadIdx.x 19 threadIdx.y 7 grad 0.021221 xhat 0.851803
# threadIdx.x 20 threadIdx.y 7 grad 0.520922 xhat 1.545182
# threadIdx.x 21 threadIdx.y 7 grad 0.034004 xhat 1.510265
# threadIdx.x 22 threadIdx.y 7 grad 0.970063 xhat 1.736539
# threadIdx.x 23 threadIdx.y 7 grad 0.081216 xhat 0.931420
# threadIdx.x 24 threadIdx.y 7 grad 0.373696 xhat -0.132580
# threadIdx.x 25 threadIdx.y 7 grad 0.407595 xhat -1.630588
# threadIdx.x 26 threadIdx.y 7 grad 0.830957 xhat 0.098537
# threadIdx.x 27 threadIdx.y 7 grad 0.645081 xhat 0.198228
# threadIdx.x 28 threadIdx.y 7 grad 0.611905 xhat 0.141406
# threadIdx.x 29 threadIdx.y 7 grad 0.397954 xhat -1.216251
# threadIdx.x 30 threadIdx.y 7 grad 0.291948 xhat 0.750800
# threadIdx.x 31 threadIdx.y 7 grad 0.695674 xhat 0.497879
# threadIdx.x 0 threadIdx.y 8 grad 0.026433 xhat -0.782813
# threadIdx.x 1 threadIdx.y 8 grad 0.259696 xhat 1.058632
# threadIdx.x 2 threadIdx.y 8 grad 0.698338 xhat -1.693365
# threadIdx.x 3 threadIdx.y 8 grad 0.034524 xhat -0.181637
# threadIdx.x 4 threadIdx.y 8 grad 0.565049 xhat 0.254139
# threadIdx.x 5 threadIdx.y 8 grad 0.525300 xhat -0.556099
# threadIdx.x 6 threadIdx.y 8 grad 0.148868 xhat 0.313465
# threadIdx.x 7 threadIdx.y 8 grad 0.002058 xhat -1.568488
# threadIdx.x 8 threadIdx.y 8 grad 0.890648 xhat 1.032236
# threadIdx.x 9 threadIdx.y 8 grad 0.654491 xhat 0.147316
# threadIdx.x 10 threadIdx.y 8 grad 0.198991 xhat -0.394766
# threadIdx.x 11 threadIdx.y 8 grad 0.135437 xhat 0.466171
# threadIdx.x 12 threadIdx.y 8 grad 0.368620 xhat 1.662534
# threadIdx.x 13 threadIdx.y 8 grad 0.841543 xhat -1.713693
# threadIdx.x 14 threadIdx.y 8 grad 0.571280 xhat 1.354395
# threadIdx.x 15 threadIdx.y 8 grad 0.740032 xhat 0.562505
# threadIdx.x 16 threadIdx.y 8 grad 0.617759 xhat -0.357822
# threadIdx.x 17 threadIdx.y 8 grad 0.403463 xhat -1.806660
# threadIdx.x 18 threadIdx.y 8 grad 0.321127 xhat 0.436313
# threadIdx.x 19 threadIdx.y 8 grad 0.088597 xhat -1.134319
# threadIdx.x 20 threadIdx.y 8 grad 0.385511 xhat 0.246754
# threadIdx.x 21 threadIdx.y 8 grad 0.390436 xhat 0.048661
# threadIdx.x 22 threadIdx.y 8 grad 0.855473 xhat -1.404479
# threadIdx.x 23 threadIdx.y 8 grad 0.943098 xhat 1.209012
# threadIdx.x 24 threadIdx.y 8 grad 0.089229 xhat -0.466466
# threadIdx.x 25 threadIdx.y 8 grad 0.075494 xhat -0.135764
# threadIdx.x 26 threadIdx.y 8 grad 0.345071 xhat -1.900837
# threadIdx.x 27 threadIdx.y 8 grad 0.376591 xhat 0.412990
# threadIdx.x 28 threadIdx.y 8 grad 0.100283 xhat 0.633121
# threadIdx.x 29 threadIdx.y 8 grad 0.350014 xhat 1.342344
# threadIdx.x 30 threadIdx.y 8 grad 0.783860 xhat -1.896961
# threadIdx.x 31 threadIdx.y 8 grad 0.044987 xhat 1.095821
# threadIdx.x 0 threadIdx.y 2 grad 0.451006 xhat -0.048722
# threadIdx.x 1 threadIdx.y 2 grad 0.711788 xhat -0.976112
# threadIdx.x 2 threadIdx.y 2 grad 0.696192 xhat 0.116790
# threadIdx.x 3 threadIdx.y 2 grad 0.592939 xhat 0.288702
# threadIdx.x 4 threadIdx.y 2 grad 0.011571 xhat 0.728420
# threadIdx.x 5 threadIdx.y 2 grad 0.248189 xhat -0.985642
# threadIdx.x 6 threadIdx.y 2 grad 0.634610 xhat 1.399514
# threadIdx.x 7 threadIdx.y 2 grad 0.867360 xhat -1.454880
# threadIdx.x 8 threadIdx.y 2 grad 0.936395 xhat -1.687497
# threadIdx.x 9 threadIdx.y 2 grad 0.871061 xhat -1.250706
# threadIdx.x 10 threadIdx.y 2 grad 0.840263 xhat -1.299837
# threadIdx.x 11 threadIdx.y 2 grad 0.307103 xhat -1.398048
# threadIdx.x 12 threadIdx.y 2 grad 0.558412 xhat -1.330140
# threadIdx.x 13 threadIdx.y 2 grad 0.447879 xhat -1.651459
# threadIdx.x 14 threadIdx.y 2 grad 0.467799 xhat -1.575420
# threadIdx.x 15 threadIdx.y 2 grad 0.301831 xhat 0.722225
# threadIdx.x 16 threadIdx.y 2 grad 0.920539 xhat -0.870613
# threadIdx.x 17 threadIdx.y 2 grad 0.290901 xhat 0.758766
# threadIdx.x 18 threadIdx.y 2 grad 0.883627 xhat 0.723058
# threadIdx.x 19 threadIdx.y 2 grad 0.840485 xhat 1.275067
# threadIdx.x 20 threadIdx.y 2 grad 0.106744 xhat -0.937392
# threadIdx.x 21 threadIdx.y 2 grad 0.684725 xhat 1.256142
# threadIdx.x 22 threadIdx.y 2 grad 0.922058 xhat 1.334220
# threadIdx.x 23 threadIdx.y 2 grad 0.204515 xhat 1.176877
# threadIdx.x 24 threadIdx.y 2 grad 0.125011 xhat -0.246417
# threadIdx.x 25 threadIdx.y 2 grad 0.029647 xhat 1.640941
# threadIdx.x 26 threadIdx.y 2 grad 0.144537 xhat 0.989899
# threadIdx.x 27 threadIdx.y 2 grad 0.629690 xhat 1.205042
# threadIdx.x 28 threadIdx.y 2 grad 0.994981 xhat -0.543139
# threadIdx.x 29 threadIdx.y 2 grad 0.437288 xhat -0.245010
# threadIdx.x 30 threadIdx.y 2 grad 0.899042 xhat -1.036813
# threadIdx.x 31 threadIdx.y 2 grad 0.564647 xhat 0.502639
# threadIdx.x 0 threadIdx.y 8 grad 0.698717 xhat 0.914586
# threadIdx.x 1 threadIdx.y 8 grad 0.924506 xhat -1.159825
# threadIdx.x 2 threadIdx.y 8 grad 0.862833 xhat 1.551151
# threadIdx.x 3 threadIdx.y 8 grad 0.044533 xhat -0.483140
# threadIdx.x 4 threadIdx.y 8 grad 0.922393 xhat 1.578238
# threadIdx.x 5 threadIdx.y 8 grad 0.819428 xhat -0.045419
# threadIdx.x 6 threadIdx.y 8 grad 0.080244 xhat -0.383373
# threadIdx.x 7 threadIdx.y 8 grad 0.050447 xhat 1.438872
# threadIdx.x 8 threadIdx.y 8 grad 0.201580 xhat -1.625671
# threadIdx.x 9 threadIdx.y 8 grad 0.240341 xhat -0.673030
# threadIdx.x 10 threadIdx.y 8 grad 0.593684 xhat 1.416508
# threadIdx.x 11 threadIdx.y 8 grad 0.070670 xhat 0.494856
# threadIdx.x 12 threadIdx.y 8 grad 0.663326 xhat -0.367162
# threadIdx.x 13 threadIdx.y 8 grad 0.866502 xhat -0.091673
# threadIdx.x 14 threadIdx.y 8 grad 0.341859 xhat 0.226970
# threadIdx.x 15 threadIdx.y 8 grad 0.893511 xhat 0.164873
# threadIdx.x 16 threadIdx.y 8 grad 0.871488 xhat -0.013644
# threadIdx.x 17 threadIdx.y 8 grad 0.712162 xhat -1.058360
# threadIdx.x 18 threadIdx.y 8 grad 0.723301 xhat 1.624825
# threadIdx.x 19 threadIdx.y 8 grad 0.212999 xhat -0.649285
# threadIdx.x 20 threadIdx.y 8 grad 0.997485 xhat -0.764389
# threadIdx.x 21 threadIdx.y 8 grad 0.384447 xhat -0.104576
# threadIdx.x 22 threadIdx.y 8 grad 0.254440 xhat -0.017914
# threadIdx.x 23 threadIdx.y 8 grad 0.240155 xhat 0.590404
# threadIdx.x 24 threadIdx.y 8 grad 0.203774 xhat 0.822792
# threadIdx.x 25 threadIdx.y 8 grad 0.800508 xhat -0.620043
# threadIdx.x 26 threadIdx.y 8 grad 0.304447 xhat 0.938000
# threadIdx.x 27 threadIdx.y 8 grad 0.935485 xhat 0.507993
# threadIdx.x 28 threadIdx.y 8 grad 0.373897 xhat 0.588194
# threadIdx.x 29 threadIdx.y 8 grad 0.878171 xhat -0.806263
# threadIdx.x 30 threadIdx.y 8 grad 0.002092 xhat -0.159563
# threadIdx.x 31 threadIdx.y 8 grad 0.146141 xhat -1.110526
# threadIdx.x 0 threadIdx.y 1 grad 0.006035 xhat 0.422833
# threadIdx.x 1 threadIdx.y 1 grad 0.332139 xhat -0.070903
# threadIdx.x 2 threadIdx.y 1 grad 0.051152 xhat -0.839828
# threadIdx.x 3 threadIdx.y 1 grad 0.007546 xhat 1.235566
# threadIdx.x 4 threadIdx.y 1 grad 0.053984 xhat 1.651080
# threadIdx.x 5 threadIdx.y 1 grad 0.194808 xhat -0.598633
# threadIdx.x 6 threadIdx.y 1 grad 0.764577 xhat 0.298056
# threadIdx.x 7 threadIdx.y 1 grad 0.417627 xhat 0.997429
# threadIdx.x 8 threadIdx.y 1 grad 0.555158 xhat -1.006212
# threadIdx.x 9 threadIdx.y 1 grad 0.807341 xhat -0.651506
# threadIdx.x 10 threadIdx.y 1 grad 0.234638 xhat -0.595515
# threadIdx.x 11 threadIdx.y 1 grad 0.664218 xhat -1.263973
# threadIdx.x 12 threadIdx.y 1 grad 0.637148 xhat 1.187855
# threadIdx.x 13 threadIdx.y 1 grad 0.466309 xhat 0.914331
# threadIdx.x 14 threadIdx.y 1 grad 0.052283 xhat 0.214867
# threadIdx.x 15 threadIdx.y 1 grad 0.742756 xhat 0.968943
# threadIdx.x 16 threadIdx.y 1 grad 0.156713 xhat 1.153356
# threadIdx.x 17 threadIdx.y 1 grad 0.938915 xhat -0.405044
# threadIdx.x 18 threadIdx.y 1 grad 0.252006 xhat 0.049458
# threadIdx.x 19 threadIdx.y 1 grad 0.546680 xhat -0.831605
# threadIdx.x 20 threadIdx.y 1 grad 0.747941 xhat 0.050215
# threadIdx.x 21 threadIdx.y 1 grad 0.499800 xhat -1.580935
# threadIdx.x 22 threadIdx.y 1 grad 0.498576 xhat -0.836635
# threadIdx.x 23 threadIdx.y 1 grad 0.959607 xhat 0.685027
# threadIdx.x 24 threadIdx.y 1 grad 0.870146 xhat 0.386460
# threadIdx.x 25 threadIdx.y 1 grad 0.824198 xhat 0.118445
# threadIdx.x 26 threadIdx.y 1 grad 0.849105 xhat -0.945624
# threadIdx.x 27 threadIdx.y 1 grad 0.384273 xhat -0.739623
# threadIdx.x 28 threadIdx.y 1 grad 0.196570 xhat 1.702875
# threadIdx.x 29 threadIdx.y 1 grad 0.299501 xhat -0.702641
# threadIdx.x 30 threadIdx.y 1 grad 0.878884 xhat 1.174074
# threadIdx.x 31 threadIdx.y 1 grad 0.986404 xhat 1.052530
# threadIdx.x 0 threadIdx.y 3 grad 0.265356 xhat 1.555577
# threadIdx.x 1 threadIdx.y 3 grad 0.661430 xhat -1.014044
# threadIdx.x 2 threadIdx.y 3 grad 0.182003 xhat 1.491654
# threadIdx.x 3 threadIdx.y 3 grad 0.015817 xhat -1.348720
# threadIdx.x 4 threadIdx.y 3 grad 0.439351 xhat 0.986928
# threadIdx.x 5 threadIdx.y 3 grad 0.415823 xhat -0.332883
# threadIdx.x 6 threadIdx.y 3 grad 0.450641 xhat -0.208485
# threadIdx.x 7 threadIdx.y 3 grad 0.731369 xhat -0.470217
# threadIdx.x 8 threadIdx.y 3 grad 0.267167 xhat 0.818253
# threadIdx.x 9 threadIdx.y 3 grad 0.699011 xhat -0.160262
# threadIdx.x 10 threadIdx.y 3 grad 0.189151 xhat 0.887098
# threadIdx.x 11 threadIdx.y 3 grad 0.757042 xhat -0.396291
# threadIdx.x 12 threadIdx.y 3 grad 0.786517 xhat -1.555766
# threadIdx.x 13 threadIdx.y 3 grad 0.632559 xhat -1.491089
# threadIdx.x 14 threadIdx.y 3 grad 0.228794 xhat 0.973156
# threadIdx.x 15 threadIdx.y 3 grad 0.916613 xhat 0.260949
# threadIdx.x 16 threadIdx.y 3 grad 0.481501 xhat -0.883390
# threadIdx.x 17 threadIdx.y 3 grad 0.439208 xhat -0.318293
# threadIdx.x 18 threadIdx.y 3 grad 0.110257 xhat 1.569996
# threadIdx.x 19 threadIdx.y 3 grad 0.108917 xhat -1.167481
# threadIdx.x 20 threadIdx.y 3 grad 0.669969 xhat -0.173977
# threadIdx.x 21 threadIdx.y 3 grad 0.619639 xhat -0.959877
# threadIdx.x 22 threadIdx.y 3 grad 0.452106 xhat 0.410404
# threadIdx.x 23 threadIdx.y 3 grad 0.204257 xhat 1.376960
# threadIdx.x 24 threadIdx.y 3 grad 0.794808 xhat 0.013379
# threadIdx.x 25 threadIdx.y 3 grad 0.725052 xhat -1.287099
# threadIdx.x 26 threadIdx.y 3 grad 0.933168 xhat 1.111676
# threadIdx.x 27 threadIdx.y 3 grad 0.984740 xhat -1.509434
# threadIdx.x 28 threadIdx.y 3 grad 0.118846 xhat 1.407933
# threadIdx.x 29 threadIdx.y 3 grad 0.186390 xhat -0.735682
# threadIdx.x 30 threadIdx.y 3 grad 0.465687 xhat -1.552533
# threadIdx.x 31 threadIdx.y 3 grad 0.716782 xhat -1.271882
# threadIdx.x 0 threadIdx.y 5 grad 0.821841 xhat -0.723925
# threadIdx.x 1 threadIdx.y 5 grad 0.948204 xhat 1.036714
# threadIdx.x 2 threadIdx.y 5 grad 0.245574 xhat 0.239783
# threadIdx.x 3 threadIdx.y 5 grad 0.734295 xhat -0.560804
# threadIdx.x 4 threadIdx.y 5 grad 0.556994 xhat 1.263213
# threadIdx.x 5 threadIdx.y 5 grad 0.778151 xhat -0.789505
# threadIdx.x 6 threadIdx.y 5 grad 0.491074 xhat 0.219118
# threadIdx.x 7 threadIdx.y 5 grad 0.149150 xhat -1.056477
# threadIdx.x 8 threadIdx.y 5 grad 0.489035 xhat 1.520767
# threadIdx.x 9 threadIdx.y 5 grad 0.158471 xhat -0.187358
# threadIdx.x 10 threadIdx.y 5 grad 0.559439 xhat -0.522029
# threadIdx.x 11 threadIdx.y 5 grad 0.948470 xhat 0.976218
# threadIdx.x 12 threadIdx.y 5 grad 0.490850 xhat -1.094655
# threadIdx.x 13 threadIdx.y 5 grad 0.814955 xhat -1.023517
# threadIdx.x 14 threadIdx.y 5 grad 0.041147 xhat -1.070469
# threadIdx.x 15 threadIdx.y 5 grad 0.793186 xhat 0.703408
# threadIdx.x 16 threadIdx.y 5 grad 0.608396 xhat -1.605224
# threadIdx.x 17 threadIdx.y 5 grad 0.498288 xhat -0.591434
# threadIdx.x 18 threadIdx.y 5 grad 0.391182 xhat 0.409576
# threadIdx.x 19 threadIdx.y 5 grad 0.875050 xhat 1.333109
# threadIdx.x 20 threadIdx.y 5 grad 0.563944 xhat -1.054772
# threadIdx.x 21 threadIdx.y 5 grad 0.381165 xhat 0.077779
# threadIdx.x 22 threadIdx.y 5 grad 0.916442 xhat -0.640826
# threadIdx.x 23 threadIdx.y 5 grad 0.778477 xhat -1.321797
# threadIdx.x 24 threadIdx.y 5 grad 0.590554 xhat 1.498882
# threadIdx.x 25 threadIdx.y 5 grad 0.164830 xhat 0.109977
# threadIdx.x 26 threadIdx.y 5 grad 0.199408 xhat -0.966949
# threadIdx.x 27 threadIdx.y 5 grad 0.116230 xhat 0.715928
# threadIdx.x 28 threadIdx.y 5 grad 0.784077 xhat 0.734145
# threadIdx.x 29 threadIdx.y 5 grad 0.117843 xhat 0.744054
# threadIdx.x 30 threadIdx.y 5 grad 0.817202 xhat -0.814599
# threadIdx.x 31 threadIdx.y 5 grad 0.386060 xhat 0.646678
# threadIdx.x 0 threadIdx.y 8 grad 0.403568 xhat 0.027548
# threadIdx.x 1 threadIdx.y 8 grad 0.700564 xhat 0.393734
# threadIdx.x 2 threadIdx.y 8 grad 0.447776 xhat 1.329072
# threadIdx.x 3 threadIdx.y 8 grad 0.779013 xhat 1.007139
# threadIdx.x 4 threadIdx.y 8 grad 0.541096 xhat -1.784322
# threadIdx.x 5 threadIdx.y 8 grad 0.847515 xhat -1.204217
# threadIdx.x 6 threadIdx.y 8 grad 0.646705 xhat -0.981070
# threadIdx.x 7 threadIdx.y 8 grad 0.650128 xhat 0.196269
# threadIdx.x 8 threadIdx.y 8 grad 0.194029 xhat 1.379356
# threadIdx.x 9 threadIdx.y 8 grad 0.412251 xhat 0.478296
# threadIdx.x 10 threadIdx.y 8 grad 0.779997 xhat 0.790661
# threadIdx.x 11 threadIdx.y 8 grad 0.671472 xhat 0.394963
# threadIdx.x 12 threadIdx.y 8 grad 0.764376 xhat 1.222281
# threadIdx.x 13 threadIdx.y 8 grad 0.396917 xhat -1.253011
# threadIdx.x 14 threadIdx.y 8 grad 0.347102 xhat -0.119822
# threadIdx.x 15 threadIdx.y 8 grad 0.699290 xhat -0.466992
# threadIdx.x 16 threadIdx.y 8 grad 0.303896 xhat 1.095649
# threadIdx.x 17 threadIdx.y 8 grad 0.942695 xhat -0.762629
# threadIdx.x 18 threadIdx.y 8 grad 0.762547 xhat -0.527902
# threadIdx.x 19 threadIdx.y 8 grad 0.386518 xhat 1.037321
# threadIdx.x 20 threadIdx.y 8 grad 0.352243 xhat -1.590479
# threadIdx.x 21 threadIdx.y 8 grad 0.846412 xhat -1.437111
# threadIdx.x 22 threadIdx.y 8 grad 0.417549 xhat -0.116135
# threadIdx.x 23 threadIdx.y 8 grad 0.214020 xhat 0.068071
# threadIdx.x 24 threadIdx.y 8 grad 0.843209 xhat 0.283506
# threadIdx.x 25 threadIdx.y 8 grad 0.265161 xhat -0.297725
# threadIdx.x 26 threadIdx.y 8 grad 0.601903 xhat 0.776176
# threadIdx.x 27 threadIdx.y 8 grad 0.288591 xhat -0.921625
# threadIdx.x 28 threadIdx.y 8 grad 0.232698 xhat -0.094900
# threadIdx.x 29 threadIdx.y 8 grad 0.671590 xhat 0.606967
# threadIdx.x 30 threadIdx.y 8 grad 0.759849 xhat -0.848351
# threadIdx.x 31 threadIdx.y 8 grad 0.171744 xhat -1.041617
# threadIdx.x 0 threadIdx.y 4 grad 0.609750 xhat -1.008260
# threadIdx.x 1 threadIdx.y 4 grad 0.744499 xhat 1.477268
# threadIdx.x 2 threadIdx.y 4 grad 0.688280 xhat -0.145145
# threadIdx.x 3 threadIdx.y 4 grad 0.212655 xhat 0.195843
# threadIdx.x 4 threadIdx.y 4 grad 0.299634 xhat 1.434562
# threadIdx.x 5 threadIdx.y 4 grad 0.502937 xhat 1.676162
# threadIdx.x 6 threadIdx.y 4 grad 0.520108 xhat -0.164884
# threadIdx.x 7 threadIdx.y 4 grad 0.105836 xhat -0.736826
# threadIdx.x 8 threadIdx.y 4 grad 0.911668 xhat 0.207561
# threadIdx.x 9 threadIdx.y 4 grad 0.989986 xhat 1.670835
# threadIdx.x 10 threadIdx.y 4 grad 0.475970 xhat -1.115465
# threadIdx.x 11 threadIdx.y 4 grad 0.192334 xhat -1.645520
# threadIdx.x 12 threadIdx.y 4 grad 0.693775 xhat -1.446170
# threadIdx.x 13 threadIdx.y 4 grad 0.862786 xhat 0.317596
# threadIdx.x 14 threadIdx.y 4 grad 0.576301 xhat 1.443905
# threadIdx.x 15 threadIdx.y 4 grad 0.307899 xhat 0.308464
# threadIdx.x 16 threadIdx.y 4 grad 0.716662 xhat 0.370103
# threadIdx.x 17 threadIdx.y 4 grad 0.089497 xhat -0.868753
# threadIdx.x 18 threadIdx.y 4 grad 0.024845 xhat 1.567606
# threadIdx.x 19 threadIdx.y 4 grad 0.193723 xhat -0.088147
# threadIdx.x 20 threadIdx.y 4 grad 0.057585 xhat -1.555008
# threadIdx.x 21 threadIdx.y 4 grad 0.381045 xhat -0.106309
# threadIdx.x 22 threadIdx.y 4 grad 0.557260 xhat 1.568455
# threadIdx.x 23 threadIdx.y 4 grad 0.817021 xhat 0.219460
# threadIdx.x 24 threadIdx.y 4 grad 0.175741 xhat 0.760883
# threadIdx.x 25 threadIdx.y 4 grad 0.309377 xhat 0.025874
# threadIdx.x 26 threadIdx.y 4 grad 0.797895 xhat -1.296049
# threadIdx.x 27 threadIdx.y 4 grad 0.432113 xhat 1.314513
# threadIdx.x 28 threadIdx.y 4 grad 0.702008 xhat 0.401480
# threadIdx.x 29 threadIdx.y 4 grad 0.737482 xhat -1.130578
# threadIdx.x 30 threadIdx.y 4 grad 0.538009 xhat -0.903613
# threadIdx.x 31 threadIdx.y 4 grad 0.827209 xhat 1.662374
# threadIdx.x 0 threadIdx.y 3 grad 0.643283 xhat -0.018028
# threadIdx.x 1 threadIdx.y 3 grad 0.339117 xhat -1.247705
# threadIdx.x 2 threadIdx.y 3 grad 0.069872 xhat -1.573093
# threadIdx.x 3 threadIdx.y 3 grad 0.425592 xhat -1.359043
# threadIdx.x 4 threadIdx.y 3 grad 0.082913 xhat -0.244822
# threadIdx.x 5 threadIdx.y 3 grad 0.205068 xhat 0.441339
# threadIdx.x 6 threadIdx.y 3 grad 0.515398 xhat 1.429256
# threadIdx.x 7 threadIdx.y 3 grad 0.059311 xhat 1.094902
# threadIdx.x 8 threadIdx.y 3 grad 0.183107 xhat 0.238286
# threadIdx.x 9 threadIdx.y 3 grad 0.926215 xhat 0.212822
# threadIdx.x 10 threadIdx.y 3 grad 0.752669 xhat -0.087768
# threadIdx.x 11 threadIdx.y 3 grad 0.034575 xhat -1.567411
# threadIdx.x 12 threadIdx.y 3 grad 0.808923 xhat -0.968335
# threadIdx.x 13 threadIdx.y 3 grad 0.385387 xhat 0.756908
# threadIdx.x 14 threadIdx.y 3 grad 0.552056 xhat -0.160750
# threadIdx.x 15 threadIdx.y 3 grad 0.165039 xhat -1.039590
# threadIdx.x 16 threadIdx.y 3 grad 0.758614 xhat 0.470749
# threadIdx.x 17 threadIdx.y 3 grad 0.162465 xhat 0.032750
# threadIdx.x 18 threadIdx.y 3 grad 0.237988 xhat -0.455371
# threadIdx.x 19 threadIdx.y 3 grad 0.442780 xhat -0.882634
# threadIdx.x 20 threadIdx.y 3 grad 0.512861 xhat 1.439718
# threadIdx.x 21 threadIdx.y 3 grad 0.878906 xhat -1.235605
# threadIdx.x 22 threadIdx.y 3 grad 0.430323 xhat -0.894676
# threadIdx.x 23 threadIdx.y 3 grad 0.338650 xhat 1.638875
# threadIdx.x 24 threadIdx.y 3 grad 0.764463 xhat -0.648003
# threadIdx.x 25 threadIdx.y 3 grad 0.547206 xhat -0.670812
# threadIdx.x 26 threadIdx.y 3 grad 0.502286 xhat 0.797570
# threadIdx.x 27 threadIdx.y 3 grad 0.068948 xhat 1.310000
# threadIdx.x 28 threadIdx.y 3 grad 0.686700 xhat 1.662925
# threadIdx.x 29 threadIdx.y 3 grad 0.724272 xhat -1.638534
# threadIdx.x 30 threadIdx.y 3 grad 0.814400 xhat -0.189976
# threadIdx.x 31 threadIdx.y 3 grad 0.496597 xhat 1.206101
# threadIdx.x 0 threadIdx.y 8 grad 0.668679 xhat 1.245421
# threadIdx.x 1 threadIdx.y 8 grad 0.874974 xhat 1.632919
# threadIdx.x 2 threadIdx.y 8 grad 0.089824 xhat -0.165788
# threadIdx.x 3 threadIdx.y 8 grad 0.132798 xhat 0.769814
# threadIdx.x 4 threadIdx.y 8 grad 0.283077 xhat 1.195871
# threadIdx.x 5 threadIdx.y 8 grad 0.721341 xhat -1.017186
# threadIdx.x 6 threadIdx.y 8 grad 0.349059 xhat 1.652792
# threadIdx.x 7 threadIdx.y 8 grad 0.261055 xhat -1.643480
# threadIdx.x 8 threadIdx.y 8 grad 0.431678 xhat 1.680152
# threadIdx.x 9 threadIdx.y 8 grad 0.708394 xhat -1.511841
# threadIdx.x 10 threadIdx.y 8 grad 0.190221 xhat 0.233937
# threadIdx.x 11 threadIdx.y 8 grad 0.270062 xhat 0.700490
# threadIdx.x 12 threadIdx.y 8 grad 0.084394 xhat -0.233142
# threadIdx.x 13 threadIdx.y 8 grad 0.798135 xhat 1.558342
# threadIdx.x 14 threadIdx.y 8 grad 0.855512 xhat -0.909203
# threadIdx.x 15 threadIdx.y 8 grad 0.057320 xhat 0.511967
# threadIdx.x 16 threadIdx.y 8 grad 0.050779 xhat 1.596575
# threadIdx.x 17 threadIdx.y 8 grad 0.429934 xhat -0.761613
# threadIdx.x 18 threadIdx.y 8 grad 0.658731 xhat -1.903490
# threadIdx.x 19 threadIdx.y 8 grad 0.617091 xhat -0.577734
# threadIdx.x 20 threadIdx.y 8 grad 0.031360 xhat -0.050336
# threadIdx.x 21 threadIdx.y 8 grad 0.751968 xhat -0.321684
# threadIdx.x 22 threadIdx.y 8 grad 0.468120 xhat 1.180603
# threadIdx.x 23 threadIdx.y 8 grad 0.783216 xhat 0.524430
# threadIdx.x 24 threadIdx.y 8 grad 0.115633 xhat 1.248746
# threadIdx.x 25 threadIdx.y 8 grad 0.895637 xhat 1.324692
# threadIdx.x 26 threadIdx.y 8 grad 0.606394 xhat -1.636848
# threadIdx.x 27 threadIdx.y 8 grad 0.477842 xhat -0.408147
# threadIdx.x 28 threadIdx.y 8 grad 0.844650 xhat -0.971546
# threadIdx.x 29 threadIdx.y 8 grad 0.984041 xhat -1.220342
# threadIdx.x 30 threadIdx.y 8 grad 0.881909 xhat -0.971262
# threadIdx.x 31 threadIdx.y 8 grad 0.588032 xhat 0.601147
# threadIdx.x 0 threadIdx.y 4 grad 0.274916 xhat -1.273090
# threadIdx.x 1 threadIdx.y 4 grad 0.016185 xhat 0.950671
# threadIdx.x 2 threadIdx.y 4 grad 0.997247 xhat -0.247528
# threadIdx.x 3 threadIdx.y 4 grad 0.541707 xhat -1.514820
# threadIdx.x 4 threadIdx.y 4 grad 0.316552 xhat -0.558409
# threadIdx.x 5 threadIdx.y 4 grad 0.069041 xhat 1.189625
# threadIdx.x 6 threadIdx.y 4 grad 0.600587 xhat 0.828417
# threadIdx.x 7 threadIdx.y 4 grad 0.747387 xhat -0.659548
# threadIdx.x 8 threadIdx.y 4 grad 0.665086 xhat 1.118699
# threadIdx.x 9 threadIdx.y 4 grad 0.837811 xhat -0.539578
# threadIdx.x 10 threadIdx.y 4 grad 0.130781 xhat 0.916937
# threadIdx.x 11 threadIdx.y 4 grad 0.622034 xhat -0.168664
# threadIdx.x 12 threadIdx.y 4 grad 0.247715 xhat -1.186457
# threadIdx.x 13 threadIdx.y 4 grad 0.445883 xhat 0.708938
# threadIdx.x 14 threadIdx.y 4 grad 0.165448 xhat -0.823436
# threadIdx.x 15 threadIdx.y 4 grad 0.968426 xhat 1.140162
# threadIdx.x 16 threadIdx.y 4 grad 0.834611 xhat 1.395923
# threadIdx.x 17 threadIdx.y 4 grad 0.981041 xhat 0.656732
# threadIdx.x 18 threadIdx.y 4 grad 0.041274 xhat -0.928732
# threadIdx.x 19 threadIdx.y 4 grad 0.212009 xhat 0.205896
# threadIdx.x 20 threadIdx.y 4 grad 0.793252 xhat -0.920130
# threadIdx.x 21 threadIdx.y 4 grad 0.839623 xhat 1.197545
# threadIdx.x 22 threadIdx.y 4 grad 0.385003 xhat -0.532755
# threadIdx.x 23 threadIdx.y 4 grad 0.542000 xhat 0.446739
# threadIdx.x 24 threadIdx.y 4 grad 0.551612 xhat 1.419241
# threadIdx.x 25 threadIdx.y 4 grad 0.245908 xhat -0.592144
# threadIdx.x 26 threadIdx.y 4 grad 0.596011 xhat -0.178585
# threadIdx.x 27 threadIdx.y 4 grad 0.210709 xhat -0.683300
# threadIdx.x 28 threadIdx.y 4 grad 0.740519 xhat 0.101232
# threadIdx.x 29 threadIdx.y 4 grad 0.738987 xhat -0.881591
# threadIdx.x 30 threadIdx.y 4 grad 0.489220 xhat 0.578487
# threadIdx.x 31 threadIdx.y 4 grad 0.283049 xhat -0.725315
# threadIdx.x 0 threadIdx.y 7 grad 0.944628 xhat -0.154888
# threadIdx.x 1 threadIdx.y 7 grad 0.630048 xhat -0.073754
# threadIdx.x 2 threadIdx.y 7 grad 0.445639 xhat 0.525236
# threadIdx.x 3 threadIdx.y 7 grad 0.656967 xhat 0.508234
# threadIdx.x 4 threadIdx.y 7 grad 0.442040 xhat -1.104416
# threadIdx.x 5 threadIdx.y 7 grad 0.472221 xhat 0.174741
# threadIdx.x 6 threadIdx.y 7 grad 0.755701 xhat 0.413860
# threadIdx.x 7 threadIdx.y 7 grad 0.285581 xhat 0.525111
# threadIdx.x 8 threadIdx.y 7 grad 0.059713 xhat 0.799535
# threadIdx.x 9 threadIdx.y 7 grad 0.736746 xhat -1.575815
# threadIdx.x 10 threadIdx.y 7 grad 0.576007 xhat 1.384704
# threadIdx.x 11 threadIdx.y 7 grad 0.437530 xhat 1.253787
# threadIdx.x 12 threadIdx.y 7 grad 0.397562 xhat 1.494293
# threadIdx.x 13 threadIdx.y 7 grad 0.635208 xhat -1.448276
# threadIdx.x 14 threadIdx.y 7 grad 0.642937 xhat -0.719800
# threadIdx.x 15 threadIdx.y 7 grad 0.067777 xhat -1.757685
# threadIdx.x 16 threadIdx.y 7 grad 0.876679 xhat 0.286514
# threadIdx.x 17 threadIdx.y 7 grad 0.547473 xhat 0.438668
# threadIdx.x 18 threadIdx.y 7 grad 0.002223 xhat -0.331447
# threadIdx.x 19 threadIdx.y 7 grad 0.497843 xhat 0.373736
# threadIdx.x 20 threadIdx.y 7 grad 0.034810 xhat 0.758912
# threadIdx.x 21 threadIdx.y 7 grad 0.361449 xhat -1.841879
# threadIdx.x 22 threadIdx.y 7 grad 0.336830 xhat -0.377343
# threadIdx.x 23 threadIdx.y 7 grad 0.681838 xhat 1.645138
# threadIdx.x 24 threadIdx.y 7 grad 0.714515 xhat 1.697667
# threadIdx.x 25 threadIdx.y 7 grad 0.945555 xhat 1.698921
# threadIdx.x 26 threadIdx.y 7 grad 0.852416 xhat -0.525822
# threadIdx.x 27 threadIdx.y 7 grad 0.334090 xhat -1.177440
# threadIdx.x 28 threadIdx.y 7 grad 0.725439 xhat -1.040405
# threadIdx.x 29 threadIdx.y 7 grad 0.179633 xhat 0.876616
# threadIdx.x 30 threadIdx.y 7 grad 0.687057 xhat -0.207109
# threadIdx.x 31 threadIdx.y 7 grad 0.008351 xhat 1.216858
# threadIdx.x 0 threadIdx.y 5 grad 0.613010 xhat -0.209324
# threadIdx.x 1 threadIdx.y 5 grad 0.611938 xhat -0.420296
# threadIdx.x 2 threadIdx.y 5 grad 0.192082 xhat -1.583679
# threadIdx.x 3 threadIdx.y 5 grad 0.145165 xhat -0.782640
# threadIdx.x 4 threadIdx.y 5 grad 0.476077 xhat 0.886716
# threadIdx.x 5 threadIdx.y 5 grad 0.718722 xhat -0.394871
# threadIdx.x 6 threadIdx.y 5 grad 0.750944 xhat 0.982626
# threadIdx.x 7 threadIdx.y 5 grad 0.117962 xhat -1.050133
# threadIdx.x 8 threadIdx.y 5 grad 0.310206 xhat 1.502651
# threadIdx.x 9 threadIdx.y 5 grad 0.729593 xhat -0.792849
# threadIdx.x 10 threadIdx.y 5 grad 0.998532 xhat -1.395721
# threadIdx.x 11 threadIdx.y 5 grad 0.430269 xhat -1.570957
# threadIdx.x 12 threadIdx.y 5 grad 0.034308 xhat -1.033690
# threadIdx.x 13 threadIdx.y 5 grad 0.139556 xhat -1.304137
# threadIdx.x 14 threadIdx.y 5 grad 0.498164 xhat 1.136933
# threadIdx.x 15 threadIdx.y 5 grad 0.545124 xhat 1.457579
# threadIdx.x 16 threadIdx.y 5 grad 0.553195 xhat 0.808043
# threadIdx.x 17 threadIdx.y 5 grad 0.621191 xhat -0.109911
# threadIdx.x 18 threadIdx.y 5 grad 0.732089 xhat 0.812786
# threadIdx.x 19 threadIdx.y 5 grad 0.349145 xhat -1.161518
# threadIdx.x 20 threadIdx.y 5 grad 0.208094 xhat 0.884794
# threadIdx.x 21 threadIdx.y 5 grad 0.650667 xhat 0.577190
# threadIdx.x 22 threadIdx.y 5 grad 0.319308 xhat -0.660589
# threadIdx.x 23 threadIdx.y 5 grad 0.144090 xhat -0.784131
# threadIdx.x 24 threadIdx.y 5 grad 0.974377 xhat -1.028677
# threadIdx.x 25 threadIdx.y 5 grad 0.808257 xhat 1.514205
# threadIdx.x 26 threadIdx.y 5 grad 0.427978 xhat -1.518392
# threadIdx.x 27 threadIdx.y 5 grad 0.607941 xhat -0.352519
# threadIdx.x 28 threadIdx.y 5 grad 0.206353 xhat 0.801938
# threadIdx.x 29 threadIdx.y 5 grad 0.714326 xhat -1.158784
# threadIdx.x 30 threadIdx.y 5 grad 0.676466 xhat -0.578670
# threadIdx.x 31 threadIdx.y 5 grad 0.062838 xhat 0.335869
# threadIdx.x 0 threadIdx.y 9 grad 0.877809 xhat 0.667773
# threadIdx.x 1 threadIdx.y 9 grad 0.316811 xhat 1.131832
# threadIdx.x 2 threadIdx.y 9 grad 0.945111 xhat -0.471447
# threadIdx.x 3 threadIdx.y 9 grad 0.150019 xhat -0.878362
# threadIdx.x 4 threadIdx.y 9 grad 0.798493 xhat 0.397290
# threadIdx.x 5 threadIdx.y 9 grad 0.498834 xhat -1.645172
# threadIdx.x 6 threadIdx.y 9 grad 0.518281 xhat -1.585907
# ...
# betta_grad 4.129963 gamma_grad -1.922821 dest 40
# betta_grad 4.580585 gamma_grad 2.127266 dest 63
# betta_grad 3.578334 gamma_grad 0.889328 dest 116
# betta_grad 5.684012 gamma_grad -2.542442 dest 46
# betta_grad 4.460560 gamma_grad 2.330304 dest 104
# betta_grad 3.547786 gamma_grad -0.524305 dest 123
# betta_grad 5.072751 gamma_grad -0.554334 dest 44
# betta_grad 4.382825 gamma_grad -1.302334 dest 96
# betta_grad 6.045492 gamma_grad -1.401670 dest 54
# betta_grad 4.794816 gamma_grad -0.842016 dest 111
# betta_grad 3.997964 gamma_grad -0.358127 dest 125
# betta_grad 5.018250 gamma_grad 1.511530 dest 107
# betta_grad 4.811780 gamma_grad -0.274257 dest 59
# betta_grad 4.086078 gamma_grad 1.767709 dest 42
# betta_grad 4.339666 gamma_grad -0.380341 dest 99
# betta_grad 3.075598 gamma_grad 2.322615 dest 120
# betta_grad 5.378419 gamma_grad -2.324095 dest 112
# betta_grad 3.195589 gamma_grad -0.406345 dest 103
# betta_grad 5.539888 gamma_grad 1.835348 dest 38
# betta_grad 5.169665 gamma_grad -2.258651 dest 62
# betta_grad 5.078807 gamma_grad 5.445388 dest 56
# betta_grad 4.698589 gamma_grad -0.366827 dest 39
# betta_grad 3.517874 gamma_grad -0.942728 dest 35
# betta_grad 4.544277 gamma_grad 0.935750 dest 34
# betta_grad 4.944319 gamma_grad -0.181120 dest 51
# betta_grad 4.705054 gamma_grad -0.038626 dest 43
# betta_grad 4.935992 gamma_grad -1.327915 dest 117
# betta_grad 6.885455 gamma_grad 1.470033 dest 118
# betta_grad 4.527688 gamma_grad -0.979280 dest 101
# betta_grad 5.123102 gamma_grad -1.115378 dest 108
# betta_grad 6.030409 gamma_grad -1.669304 dest 119
# betta_grad 4.937451 gamma_grad -1.434732 dest 113
# betta_grad 3.865621 gamma_grad -0.927700 dest 114
# betta_grad 4.746266 gamma_grad -0.005012 dest 105
# betta_grad 5.288659 gamma_grad 0.604530 dest 97
# betta_grad 5.989871 gamma_grad -4.155015 dest 98
# betta_grad 4.570071 gamma_grad -3.872706 dest 122
# betta_grad 4.913288 gamma_grad -3.801601 dest 121
# betta_grad 5.285671 gamma_grad 1.123171 dest 106
# betta_grad 4.891741 gamma_grad -2.059006 dest 126
# betta_grad 6.021491 gamma_grad -1.766433 dest 109
# betta_grad 6.676263 gamma_grad 1.457607 dest 110
# betta_grad 4.797345 gamma_grad 0.188211 dest 102
# betta_grad 4.695751 gamma_grad 0.419521 dest 100
# betta_grad 4.286698 gamma_grad 0.454758 dest 124
# betta_grad 5.016273 gamma_grad -2.777990 dest 20
# betta_grad 4.584937 gamma_grad -1.214547 dest 4
# betta_grad 4.817944 gamma_grad -0.544554 dest 12
# betta_grad 6.156577 gamma_grad 1.244303 dest 17
# betta_grad 5.762738 gamma_grad -1.168770 dest 18
# betta_grad 5.332838 gamma_grad 2.106857 dest 8
# betta_grad 5.191665 gamma_grad 1.500032 dest 24
# betta_grad 6.609347 gamma_grad -0.316899 dest 25
# betta_grad 4.286644 gamma_grad -2.325162 dest 21
# betta_grad 4.954851 gamma_grad -1.010535 dest 16
# betta_grad 3.263878 gamma_grad 0.521674 dest 26
# betta_grad 4.328032 gamma_grad 1.754486 dest 0
# betta_grad 6.029221 gamma_grad 2.437450 dest 22
# betta_grad 4.248533 gamma_grad -0.842636 dest 30
# betta_grad 5.167966 gamma_grad 2.340250 dest 28
# betta_grad 4.060297 gamma_grad -0.881343 dest 14
# betta_grad 3.820509 gamma_grad 0.682201 dest 23
# betta_grad 4.683002 gamma_grad -0.005783 dest 27
# betta_grad 4.760731 gamma_grad 0.148958 dest 13
# betta_grad 4.095003 gamma_grad -1.875184 dest 6
# betta_grad 4.824161 gamma_grad 0.893023 dest 15
# betta_grad 4.029972 gamma_grad -0.471414 dest 7
# betta_grad 3.921679 gamma_grad -0.813688 dest 29
# betta_grad 6.046544 gamma_grad -0.463421 dest 3
# betta_grad 4.992992 gamma_grad -0.802622 dest 10
# betta_grad 5.726249 gamma_grad -0.674917 dest 9
# betta_grad 4.569675 gamma_grad -0.400608 dest 31
# betta_grad 4.271444 gamma_grad 0.236367 dest 19
# betta_grad 4.317657 gamma_grad 0.943650 dest 1
# betta_grad 5.568589 gamma_grad -5.290054 dest 5
# betta_grad 5.355803 gamma_grad 3.763397 dest 2
# betta_grad 4.206466 gamma_grad 2.128658 dest 11
#
# [
# 	[-1.678389 -0.274921 1.161410 -0.886182 1.323363 -1.769238 -0.582096 1.308604 0.956149 -1.266837 -0.609353 -0.227525 -0.294464 -0.609203 0.943297 0.034710 -0.503658 0.761043 -0.856854 0.400136 -1.160184 0.270503 -0.044640 -0.927353 -0.444669 1.566403 -1.722714 -1.598049 0.215992 0.526034 -0.575725 0.213382 0.560208 -0.743372 0.670126 -0.310380 -1.074401 0.706632 0.207056 0.046613 -0.309653 -0.795964 -0.874472 0.465368 1.138629 0.763970 0.350308 1.448243 0.611701 0.520327 0.997048 0.476786 -0.396690 -1.138891 1.713107 -1.093033 1.739480 0.993260 -1.301790 -0.715801 1.523802 0.934997 0.915473 1.325806 -1.243541 1.610594 1.262805 0.517439 0.018637 -1.064062 1.685170 1.295773 -1.768397 1.640317 -0.949617 0.935280 -0.656190 -0.402816 0.964020 -1.516160 -1.201659 0.580871 1.032902 1.296188 0.987489 0.484569 0.228839 1.522541 -1.858799 -1.214115 -0.832165 -0.716578 -1.407424 -1.162247 0.636199 0.090739 1.497685 -1.117765 -1.876260 -0.763598 -0.486174 -1.688300 1.461505 -0.984869 -0.340740 -1.166470 0.136805 0.143029 1.358501 -0.177502 0.192424 0.197903 0.437892 0.066194 -0.011391 0.106252 1.363129 -1.876962 0.037151 -1.187237 1.458015 -0.561256 0.762289 -0.337814 0.750675 -0.208272 0.193532 -1.178490]
# 	[0.819129 -1.369903 1.427528 -0.392100 -1.364089 -1.285401 1.464678 -0.313590 1.152310 -1.406359 1.639879 -0.921418 0.605283 -0.903878 0.240910 1.323509 -0.045175 -1.205605 1.197887 1.618822 -0.503116 0.793960 -1.065038 -0.102254 -0.751442 -1.578558 -1.521698 0.835465 0.902403 1.001104 -0.257341 -1.391919 0.431537 0.403804 0.297684 0.829169 1.222239 0.866694 -0.230439 -1.306512 -1.123964 1.191775 -1.347561 -0.384562 0.190462 -0.471800 -1.131954 -1.320783 0.764042 0.226819 0.761565 -0.633636 1.535467 1.642647 -1.460978 0.839714 1.646412 0.917577 -0.088520 1.377648 1.170477 0.305961 1.331836 -1.634822 0.422833 -0.070903 -0.839828 1.235566 1.651080 -0.598633 0.298056 0.997429 -1.006211 -0.651506 -0.595514 -1.263972 1.187855 0.914331 0.214867 0.968943 1.153356 -0.405043 0.049458 -0.831604 0.050215 -1.580934 -0.836635 0.685027 0.386460 0.118445 -0.945624 -0.739623 1.702874 -0.702641 1.174074 1.052530 0.240729 -0.567710 -1.582983 -0.959342 1.693048 -0.202296 0.573025 0.875798 0.317541 -1.060590 -0.268238 -0.476099 -1.530495 -1.372616 -0.142704 -0.493878 -1.479119 0.453689 -0.463967 1.584049 -0.840389 1.700750 -0.322472 -0.278702 -0.639526 -1.499527 -0.339211 -0.820379 -1.537141 0.319079 -0.477462 0.940452]
# 	[1.546674 1.450821 0.803982 -1.098890 0.320265 -1.216779 -0.109337 -0.121525 -0.569813 0.767572 0.931331 0.610758 -1.425352 -0.891830 -0.271099 1.087667 1.100138 -0.169968 0.897532 -0.872516 0.183691 -0.446213 1.406292 1.249895 0.991213 0.993980 -0.259446 -1.657214 0.163298 -0.615925 0.900487 -1.615977 -0.048722 -0.976111 0.116790 0.288702 0.728420 -0.985641 1.399514 -1.454878 -1.687496 -1.250705 -1.299836 -1.398047 -1.330138 -1.651458 -1.575419 0.722225 -0.870612 0.758766 0.723058 1.275066 -0.937391 1.256142 1.334220 1.176877 -0.246417 1.640940 0.989899 1.205042 -0.543138 -0.245009 -1.036811 0.502640 0.127718 -1.388298 1.188249 1.126391 -0.373338 0.122167 1.209289 -0.947694 -1.296014 -1.394773 -0.350810 1.295074 1.070477 1.376444 0.920916 -0.456731 -0.726588 1.126656 0.234212 0.408815 -1.070842 -1.317281 1.410835 -0.353693 -1.723025 -1.469555 0.573687 -1.226380 0.562947 0.723314 0.254722 -1.051585 -1.541793 -0.748215 1.302348 0.701836 1.369135 1.603340 -0.988894 0.236224 0.459513 -0.555073 1.078059 1.406101 -1.021587 -0.187395 0.988687 0.089197 1.185116 -0.437626 -1.403974 1.408407 -0.864676 -0.558203 0.169750 -0.411149 -0.900966 -0.171435 -1.696518 0.860825 -0.040830 -0.024655 -0.093709 -0.441298]
# 	[-0.018028 -1.247705 -1.573094 -1.359044 -0.244822 0.441339 1.429256 1.094902 0.238286 0.212822 -0.087768 -1.567412 -0.968335 0.756907 -0.160750 -1.039590 0.470749 0.032750 -0.455372 -0.882635 1.439718 -1.235606 -0.894676 1.638875 -0.648003 -0.670813 0.797570 1.310000 1.662925 -1.638534 -0.189976 1.206101 1.555577 -1.014044 1.491654 -1.348720 0.986928 -0.332884 -0.208485 -0.470218 0.818252 -0.160263 0.887098 -0.396291 -1.555766 -1.491089 0.973156 0.260949 -0.883391 -0.318294 1.569996 -1.167481 -0.173977 -0.959878 0.410404 1.376960 0.013379 -1.287099 1.111676 -1.509434 1.407933 -0.735682 -1.552533 -1.271882 0.969387 -0.371122 -0.080617 -0.046921 -0.243055 -0.038013 1.472532 -0.805315 1.224690 -1.242736 0.627305 1.159781 0.071552 -1.258749 1.124342 0.265187 1.005356 0.364663 -1.274332 1.217128 1.398409 -0.524203 0.649913 0.760326 -0.382766 -1.199258 -0.786679 -0.354816 0.137089 1.131619 0.657491 -0.789144 0.700464 0.254912 -1.390463 1.271659 -0.201241 -1.154099 -0.620009 0.502409 0.742789 -0.586557 1.430784 0.153272 0.417651 -1.189334 -0.883394 -0.333751 0.421523 1.139022 0.724241 1.404376 1.409268 0.675637 -0.320947 -0.988478 1.658135 -1.506500 -1.533074 -1.094318 -1.217636 1.489575 1.408818 -1.500388]
# 	[-0.076796 0.844842 0.425113 -0.557869 -0.969430 -0.475095 -1.154538 -1.440348 1.676153 1.266749 -1.612741 1.037087 -0.414393 0.883762 1.193280 -0.840691 -0.710358 1.638423 -0.549826 -0.049386 -1.170413 0.511457 0.375130 -0.899002 -1.417174 0.478657 -1.362785 0.694866 -0.952535 -0.856509 1.118846 1.265679 0.931316 -0.945838 1.556343 -1.514885 -0.314553 1.531687 -1.593693 -0.844893 0.699543 -0.532457 -1.421099 -0.212791 -0.438512 0.512843 0.775139 0.159136 -0.537851 -0.441817 0.899416 -1.475096 1.065755 -0.231498 -1.497372 0.812424 1.699829 1.164325 -0.877358 0.403378 -1.401924 1.209388 -0.728206 -1.164203 -1.273090 0.950671 -0.247528 -1.514820 -0.558409 1.189626 0.828418 -0.659548 1.118700 -0.539578 0.916938 -0.168663 -1.186456 0.708939 -0.823436 1.140162 1.395923 0.656733 -0.928732 0.205896 -0.920130 1.197545 -0.532755 0.446739 1.419241 -0.592144 -0.178585 -0.683300 0.101232 -0.881591 0.578487 -0.725315 -1.008260 1.477268 -0.145145 0.195843 1.434562 1.676163 -0.164883 -0.736826 0.207561 1.670835 -1.115465 -1.645520 -1.446170 0.317596 1.443905 0.308465 0.370104 -0.868753 1.567607 -0.088147 -1.555008 -0.106309 1.568455 0.219460 0.760883 0.025875 -1.296049 1.314514 0.401480 -1.130578 -0.903612 1.662374]
# 	[1.112772 1.012405 0.514824 0.362199 -0.309092 0.477533 1.277014 -0.559344 1.143873 -1.356879 -1.538400 0.720058 0.998780 -0.194442 -1.320897 1.041620 -0.316474 -1.592650 0.502159 0.252862 1.494626 0.924779 1.463567 -0.789758 -0.925117 -1.356260 1.415765 1.126642 0.257498 1.499091 -1.525989 0.992500 -1.582477 -1.429486 0.783099 1.456460 1.079846 0.420735 1.478085 0.420735 0.314370 0.176534 0.775577 1.446501 -0.218340 0.166894 -0.036228 0.522917 -1.164982 0.534459 -1.095490 1.449924 -0.224071 0.996529 -1.555039 -0.237078 -1.579455 -1.591668 0.623204 -1.502265 -0.424796 0.619281 -0.725539 1.281659 -0.209323 -0.420295 -1.583679 -0.782640 0.886716 -0.394871 0.982626 -1.050133 1.502651 -0.792849 -1.395721 -1.570957 -1.033690 -1.304137 1.136933 1.457579 0.808043 -0.109911 0.812786 -1.161518 0.884795 0.577190 -0.660589 -0.784131 -1.028677 1.514205 -1.518392 -0.352519 0.801938 -1.158784 -0.578670 0.335869 -0.723925 1.036714 0.239784 -0.560804 1.263213 -0.789505 0.219118 -1.056477 1.520768 -0.187358 -0.522029 0.976218 -1.094654 -1.023517 -1.070469 0.703408 -1.605224 -0.591434 0.409576 1.333110 -1.054772 0.077779 -0.640826 -1.321797 1.498882 0.109977 -0.966948 0.715928 0.734145 0.744054 -0.814599 0.646678]
# 	[0.938346 1.597736 1.133384 1.402738 0.317523 -1.171955 -1.146609 1.177389 1.543841 -0.140919 1.249515 0.792830 -1.690673 1.400645 -0.775513 0.875290 -1.749151 0.213771 -0.796244 -0.384585 -0.665856 -0.538618 -0.898446 0.392111 0.286311 0.414491 0.097654 -0.624912 0.873952 -1.460756 1.594775 0.656376 0.935010 -0.416821 -1.072155 -1.227149 0.021101 -1.306487 1.136903 0.474352 -0.462784 -0.957799 1.282541 -0.560908 -0.504794 -0.764666 -0.419395 0.958244 -0.336182 -0.524116 -0.276448 0.088643 1.106604 0.471047 -0.270216 -0.949506 1.511062 -0.780688 -1.526631 1.576536 -1.390504 1.532242 -0.271248 1.607065 -1.577326 0.060657 0.446723 -1.721555 -1.471796 1.523234 0.383606 -0.396448 -1.329513 -1.482910 1.424169 0.722474 1.150833 0.294819 1.596746 0.619569 -0.981762 0.423014 -1.006546 -0.790818 1.605071 0.694675 -0.939366 -1.006019 0.845929 -0.307200 0.764216 0.830125 0.864743 -0.994158 0.926970 0.447118 0.971666 -1.168391 -1.269873 -1.051119 -1.504193 0.772897 -1.522773 0.417457 1.458748 0.881244 0.096306 1.098005 0.323338 1.225654 -0.939928 1.227484 -0.025420 -1.569958 -1.673993 0.531134 -0.317541 -0.135976 1.063514 0.271122 -0.026547 -0.393901 -0.889678 -0.644151 -0.552944 -1.174332 -1.391323 0.696927]
# 	[0.750584 -0.509886 1.697140 -0.911373 0.485744 -0.360505 -0.543755 -0.695079 -1.778887 -1.655476 -0.072825 1.752924 0.016720 -1.410143 -0.558760 -0.443167 -0.376219 0.280602 -1.096968 -0.021952 -1.660033 -1.358469 1.443439 -0.408016 1.462137 -0.521743 -0.396021 -0.503854 0.968437 1.426257 -0.385145 -0.845436 -0.154889 -0.073754 0.525235 0.508234 -1.104416 0.174740 0.413859 0.525111 0.799535 -1.575815 1.384704 1.253786 1.494293 -1.448276 -0.719801 -1.757685 0.286514 0.438668 -0.331447 0.373736 0.758912 -1.841879 -0.377344 1.645137 1.697666 1.698920 -0.525822 -1.177441 -1.040405 0.876615 -0.207110 1.216858 -1.439166 0.635201 1.470156 0.374331 0.621992 -0.236967 -1.743108 1.519881 0.333982 -0.772192 0.654334 0.285583 0.230747 1.007452 0.026556 -0.227242 -0.324773 -0.524360 -0.971748 1.412534 -1.410184 -0.236437 -0.071602 -1.651579 -0.426083 -0.853087 0.436990 0.492777 1.237155 0.705535 0.032374 0.246511 -1.380625 0.222818 -0.432182 -0.172987 -0.635648 1.508336 1.770249 -0.321968 1.353491 -0.233731 -0.216402 -1.573683 1.471294 0.301820 -0.862222 -1.432606 -1.731680 -1.285258 0.026014 0.851802 1.545182 1.510265 1.736538 0.931420 -0.132581 -1.630588 0.098536 0.198227 0.141405 -1.216251 0.750799 0.497879]
# 	[0.027547 0.393733 1.329072 1.007139 -1.784323 -1.204217 -0.981070 0.196269 1.379356 0.478296 0.790661 0.394963 1.222281 -1.253012 -0.119822 -0.466992 1.095648 -0.762629 -0.527902 1.037321 -1.590480 -1.437111 -0.116135 0.068071 0.283506 -0.297725 0.776176 -0.921625 -0.094900 0.606966 -0.848351 -1.041618 1.245422 1.632920 -0.165788 0.769814 1.195871 -1.017186 1.652792 -1.643481 1.680152 -1.511842 0.233937 0.700490 -0.233142 1.558342 -0.909203 0.511967 1.596576 -0.761613 -1.903491 -0.577734 -0.050336 -0.321684 1.180603 0.524430 1.248747 1.324692 -1.636848 -0.408147 -0.971546 -1.220342 -0.971263 0.601147 0.914586 -1.159825 1.551151 -0.483141 1.578238 -0.045419 -0.383374 1.438872 -1.625672 -0.673030 1.416508 0.494856 -0.367162 -0.091673 0.226970 0.164873 -0.013644 -1.058360 1.624825 -0.649286 -0.764389 -0.104574 -0.017914 0.590403 0.822792 -0.620043 0.938000 0.507993 0.588194 -0.806263 -0.159562 -1.110527 -0.782813 1.058632 -1.693366 -0.181637 0.254139 -0.556099 0.313465 -1.568488 1.032236 0.147316 -0.394766 0.466171 1.662534 -1.713694 1.354395 0.562505 -0.357822 -1.806661 0.436313 -1.134320 0.246754 0.048660 -1.404479 1.209013 -0.466466 -0.135764 -1.900837 0.412990 0.633121 1.342345 -1.896962 1.095821]
# 	[0.667773 1.131832 -0.471447 -0.878362 0.397290 -1.645172 -1.585907 -0.351804 0.300185 0.149204 1.015336 0.082575 -0.729743 -0.058769 0.467468 -1.368514 -1.402831 1.297621 -1.390127 0.223322 -1.223794 1.121312 1.485789 -0.038188 1.251324 1.522760 1.548627 1.297677 1.548199 -0.208949 -0.226470 0.242759 -1.713658 -0.156580 -0.909678 -0.581231 0.663297 -0.608963 -1.738789 1.721225 -1.057967 0.710850 1.411494 -0.199089 0.598423 0.935720 0.149005 0.219648 0.007192 -0.770113 1.070265 -0.430990 -0.006522 0.355064 -0.516006 0.891375 -0.855412 -1.105082 0.526406 1.234181 0.660076 0.773467 -0.692824 1.161979 -0.532007 -1.273484 -1.648294 0.410005 0.709489 -0.979657 0.460059 0.003447 0.955209 -1.119825 1.695328 -1.551804 -0.918109 -1.328367 0.993551 0.770091 -0.864558 0.854759 0.907432 -0.156407 -1.829923 1.607705 0.769374 0.554437 -1.657658 0.937764 -1.061742 -0.217749 -1.850667 1.081703 0.082290 1.363869 -1.195536 -0.311155 -0.410116 -1.681748 -1.667270 -1.857115 -0.246997 0.609242 -0.417674 0.350516 1.341265 1.087780 0.281940 1.067158 1.381669 -0.694365 -1.491153 0.692412 -0.480762 -0.818520 0.558864 -0.235427 0.370844 -1.861825 1.423928 0.074155 0.309844 -0.515889 1.008322 0.812443 -0.941949 0.373104]]

# %%
(f_gamma_grad-gamma_mt).sum()
# Out:
# [-0.000016]
