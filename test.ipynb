# %%
# %%
import minitorch
from minitorch.cuda_kernel_ops import CudaKernelOps
backend = minitorch.TensorBackend(CudaKernelOps)
import time
import numpy as np

# %%
# %%
batch_size = 2
nhead = 10
from_len = 3
to_len = 3

def rand(shape):
    return np.random.rand(*shape)

out_grad = rand((batch_size, nhead, from_len, to_len))
inp = rand((batch_size, nhead, from_len, to_len))


def custom():
    out_grad_mt = minitorch.tensor_from_numpy(out_grad, backend=backend, requires_grad=True)
    inp_mt = minitorch.tensor_from_numpy(inp, backend=backend, requires_grad=True)
    mask_mt = minitorch.tensor_from_numpy(np.zeros((batch_size, 1, 1, to_len)), backend=backend, requires_grad=True)
    soft_inp_mt = inp_mt.attn_softmax(mask_mt)

    start_time = time.time()
    soft_inp_mt.backward(out_grad_mt)
    end_time = time.time()

    return inp_mt.grad

def baseline():
    out_grad_mt = minitorch.tensor_from_numpy(out_grad, backend=backend, requires_grad=True)
    inp_mt = minitorch.tensor_from_numpy(inp, backend=backend, requires_grad=True)
    soft_inp_mt = minitorch.nn.softmax(inp_mt, dim=3)

    start_time = time.time()
    tsum = out_grad_mt * soft_inp_mt
    tsum = tsum.sum(dim=3).view(tsum.shape[0], tsum.shape[1], tsum.shape[2], 1)
    res = soft_inp_mt * (out_grad_mt - tsum)
    end_time = time.time()

    return res


# %%


# %%
c = custom()
b = baseline()
print(c-b)
# Out:
# [
# 	[
# 		[
# 			[-0.000000 -0.000000 -0.000000]
# 			[0.000000 -0.000000 0.000000]
# 			[0.000000 0.000000 0.000000]]
# 		[
# 			[-0.000000 -0.000000 -0.000000]
# 			[0.000000 0.000000 0.000000]
# 			[0.000000 0.000000 0.000000]]
# 		[
# 			[0.000000 0.000000 0.000000]
# 			[0.000000 0.000000 0.000000]
# 			[0.000000 0.000000 0.000000]]
# 		[
# 			[0.000000 0.000000 -0.000000]
# 			[0.000000 0.000000 0.000000]
# 			[-0.000000 0.000000 0.000000]]
# 		[
# 			[-0.000000 -0.000000 -0.000000]
# 			[-0.000000 -0.000000 -0.000000]
# 			[0.000000 0.000000 0.000000]]
# 		[
# 			[0.721597 0.566672 0.598053]
# 			[0.571790 0.769677 0.625965]
# 			[0.801660 0.147156 0.522489]]
# 		[
# 			[0.842549 0.354289 0.716168]
# 			[0.822028 0.842531 0.950860]
# 			[0.271600 0.768335 0.311524]]
# 		[
# 			[0.194882 0.589023 0.612221]
# 			[0.524637 0.711209 0.629774]
# 			[0.343755 0.597789 0.492936]]
# 		[
# 			[0.762153 0.705383 0.674406]
# 			[0.818306 0.314732 0.409038]
# 			[0.203483 0.445408 0.247176]]
# 		[
# 			[0.601995 0.341825 0.651116]
# 			[0.510397 0.394909 0.215705]
# 			[0.169301 0.633328 0.508118]]]
# 	[
# 		[
# 			[0.221876 0.795995 0.347178]
# 			[0.379064 0.329738 0.305689]
# 			[0.508923 0.372986 0.801039]]
# 		[
# 			[0.715588 0.556860 0.262926]
# 			[0.733042 0.325983 0.458967]
# 			[0.708356 0.311274 0.845399]]
# 		[
# 			[0.510143 0.370730 0.676640]
# 			[0.624375 0.459473 0.377903]
# 			[0.742349 0.314510 0.540026]]
# 		[
# 			[0.613284 0.307321 0.463114]
# 			[0.910491 0.256611 0.153839]
# 			[0.668156 0.963140 0.824265]
# 			[0.522834 0.540510 0.846019]]
# 		[
# 			[0.602912 0.064271 0.294722]
# 			[0.653529 0.207589 0.621984]
# 			[0.890207 0.881271 0.379292]]
# 		[
# 			[0.691061 0.632519 0.907427]
# 			[0.737880 0.688196 0.160595]
# 			[0.203842 0.454747 0.842096]]]]

# %%
print(b)
# Out:
# [
# 	[
# 		[
# 			[0.093648 -0.042401 -0.051246]
# 			[0.154206 0.005562 -0.159768]
# 			[-0.070276 0.016667 0.053608]]
# 		[
# 			[0.002756 -0.116612 0.113856]
# 			[-0.014992 0.008304 0.006688]
# 			[-0.037054 -0.099148 0.136202]]
# 		[
# 			[-0.038111 0.055119 -0.017008]
# 			[-0.059021 0.128074 -0.069053]
# 			[-0.061120 0.114608 -0.053488]]
# 		[
# 			[0.156593 -0.028268 -0.128325]
# 			[0.146208 -0.079415 -0.066793]
# 			[0.104886 -0.044499 -0.060387]]
# 		[
# 			[0.044440 -0.053384 0.008944]
# 			[0.017815 0.073496 -0.091310]
# 			[-0.070405 -0.055941 0.126346]]
# 		[
# 			[0.057088 -0.044599 -0.012489]
# 			[-0.051168 0.052684 -0.001515]
# 			[0.122029 -0.140628 0.018599]]
# 		[
# 			[0.078718 -0.123673 0.044955]
# 			[-0.035036 -0.003204 0.038240]
# 			[-0.123890 0.186772 -0.062882]]
# 		[
# 			[-0.111127 0.017638 0.093489]
# 			[-0.049645 0.052821 -0.003176]
# 			[-0.061652 0.061218 0.000434]]
# 		[
# 			[0.022484 -0.008347 -0.014137]
# 			[0.146443 -0.093470 -0.052973]
# 			[-0.044027 0.053531 -0.009503]]
# 		[
# 			[0.041239 -0.087287 0.046047]
# 			[0.074243 0.021636 -0.095880]
# 			[-0.126432 0.085614 0.040819]]]
# 	[
# 		[
# 			[-0.067516 0.114244 -0.046728]
# 			[0.022323 -0.010940 -0.011383]
# 			[-0.020593 -0.082356 0.102949]]
# 		[
# 			[0.095378 0.024332 -0.119710]
# 			[0.131128 -0.095129 -0.035999]
# 			[0.000926 -0.100291 0.099365]]
# 		[
# 			[-0.019610 -0.063192 0.082802]
# 			[0.071793 -0.012812 -0.058981]
# 			[0.092250 -0.117257 0.025006]]
# 		[
# 			[0.074100 -0.083213 0.009113]
# 			[0.063216 -0.088008 0.024792]
# 			[-0.013958 0.052320 -0.038362]]
# 		[
# 			[0.123070 -0.097386 -0.025684]
# 			[-0.081302 0.075964 0.005338]
# 			[0.003302 -0.016487 0.013185]]
# 		[
# 			[-0.064023 0.128810 -0.064787]
# 			[0.092881 0.016478 -0.109359]
# 			[0.012261 -0.101757 0.089495]]
# 		[
# 			[-0.001788 -0.120626 0.122414]
# 			[-0.077569 -0.030538 0.108108]
# 			[0.136019 -0.091194 -0.044825]]
# 		[
# 			[0.169099 -0.033868 -0.135231]
# 			[-0.048454 0.048740 -0.000286]
# 			[-0.040093 -0.037185 0.077278]]
# 		[
# 			[0.097411 -0.081093 -0.016318]
# 			[0.050658 -0.096733 0.046075]
# 			[0.042089 0.072761 -0.114850]]
# 		[
# 			[-0.021148 -0.022014 0.043161]
# 			[0.069677 0.060785 -0.130461]
# 			[-0.095912 -0.024507 0.120419]]]]

# %%
out_grad
# Out:
# array([[[[0.826692  , 0.42501557, 0.32643509],
#          [0.86724875, 0.50863343, 0.03402741],
#          [0.06320287, 0.35797317, 0.45547104]],
#
#         [[0.70406347, 0.24502249, 0.91608756],
#          [0.64116942, 0.70829526, 0.69915332],
#          [0.54065158, 0.14768044, 0.94104431]],
#
#         [[0.19407281, 0.47843891, 0.26112177],
#          [0.41166961, 0.92352441, 0.33378362],
#          [0.19019248, 0.69262059, 0.2542264 ]],
#
#         [[0.9028423 , 0.20929412, 0.02227044],
#          [0.90050573, 0.3043901 , 0.30495891],
#          [0.64043848, 0.24961443, 0.06529399]],
#
#         [[0.79096915, 0.46086897, 0.71466107],
#          [0.36927911, 0.56008467, 0.10113949],
#          [0.27048538, 0.32680441, 0.95796152]],
#
#         [[0.77868484, 0.52207278, 0.58556422],
#          [0.52062171, 0.82236135, 0.62444911],
#          [0.9236888 , 0.00652799, 0.54108831]],
#
#         [[0.92126713, 0.23061561, 0.76112342],
#          [0.78699225, 0.83932684, 0.98909979],
#          [0.14770976, 0.95510754, 0.24864225]],
#
#         [[0.08375453, 0.60666124, 0.70570993],
#          [0.47499191, 0.76403032, 0.62659802],
#          [0.28210298, 0.65900663, 0.49336996]],
#
#         [[0.78463774, 0.6970365 , 0.66026826],
#          [0.96474856, 0.22126191, 0.35606464],
#          [0.15945623, 0.49893873, 0.2376725 ]],
#
#         [[0.64323406, 0.25453876, 0.69716331],
#          [0.58464003, 0.41654517, 0.11982526],
#          [0.04286923, 0.71894118, 0.548937  ]]],
#
#
#        [[[0.15435975, 0.91023903, 0.30045011],
#          [0.40138635, 0.31879795, 0.29430635],
#          [0.4883294 , 0.2906302 , 0.90398846]],
#
#         [[0.81096603, 0.58119175, 0.14321527],
#          [0.86417075, 0.23085448, 0.4229673 ],
#          [0.70928201, 0.21098226, 0.94476353]],
#
#         [[0.49053241, 0.30753801, 0.75944131],
#          [0.69616837, 0.44666025, 0.31892237],
#          [0.83459971, 0.19725342, 0.56503264]],
#
#         [[0.68738415, 0.22410776, 0.47222754],
#          [0.93470276, 0.45186798, 0.81641538],
#          [0.5082287 , 0.84196544, 0.4454846 ]],
#
#         [[0.80290946, 0.16925962, 0.33251682],
#          [0.42368578, 0.91073535, 0.70603343],
#          [0.62172175, 0.55712017, 0.63841614]],
#
#         [[0.39218685, 0.85010615, 0.17508036],
#          [0.71073662, 0.47565994, 0.02791246],
#          [0.77590236, 0.46119163, 0.9341091 ]],
#
#         [[0.61405088, 0.32337679, 0.9593672 ],
#          [0.21412778, 0.35634143, 0.7871263 ],
#          [0.99264948, 0.20813535, 0.26318459]],
#
#         [[0.9104907 , 0.25661137, 0.15383871],
#          [0.66815632, 0.96314022, 0.82426512],
#          [0.52283445, 0.54050951, 0.84601906]],
#
#         [[0.60291207, 0.06427112, 0.29472231],
#          [0.65352899, 0.20758922, 0.62198402],
#          [0.89020686, 0.88127051, 0.37929164]],
#
#         [[0.69106124, 0.6325189 , 0.90742682],
#          [0.73788041, 0.68819632, 0.16059512],
#          [0.20384169, 0.45474724, 0.84209594]]]])

# %%
out_grad.shape
# Out:
# (2, 10, 3, 3)
